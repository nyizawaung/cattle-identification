# %%
import os
import json
from pathlib import Path
from collections import defaultdict, Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score
from tqdm import tqdm
import timm
from helpers.helper import Helper
from torch.optim.lr_scheduler import CosineAnnealingLR
from PIL import Image
from datetime import datetime
import pandas as pd

import cv2
import numpy as np


class ProtoInfer:
    def __init__(self, model, device, proto_ckpt_path, class_mapping_path=None):
        """
        class_mapping_path: path to class_mappings.json (optional)
        Supports:
          - dict index->name  (keys int or numeric strings)
          - list              (index->name)
          - dict protoLabel->name (keys are strings that match checkpoint proto_labels)
        """
        self.model = model.eval().to(device)
        self.device = device
        ckpt = torch.load(proto_ckpt_path, map_location=device)

        self.prototypes  = ckpt["prototypes"].to(device)   # [K,D] L2-normalized
        self.proto_labels = ckpt["proto_labels"]           # list[str]
        self.tau = 4.0#float(ckpt["tau"])
        print("tau : ",self.tau)
        emb_dim = ckpt.get("embedding_dim", None)

        if emb_dim is not None and self.prototypes.shape[1] != emb_dim:
            raise ValueError(
                f"Embedding dim mismatch: ckpt={emb_dim}, prototypes D={self.prototypes.shape[1]}"
            )

        # ---- Load optional class mapping
        self.idx_to_name = None         # list or dict[int]->str
        self.label_to_name = None       # dict[str]->str

        if class_mapping_path is not None:
            with open(class_mapping_path, "r", encoding="utf-8") as f:
                mapping = json.load(f)

            # list -> index mapping
            if isinstance(mapping, list):
                self.idx_to_name = list(mapping)

            # dict -> either index->name or protoLabel->name
            elif isinstance(mapping, dict):
                # detect if keys are index-like (ints or numeric strings)
                def _is_int_like(k):
                    if isinstance(k, int): return True
                    if isinstance(k, str) and k.isdigit(): return True
                    return False

                if all(_is_int_like(k) for k in mapping.keys()):
                    # build int-keyed dict (normalize str keys -> int)
                    self.idx_to_name = {int(k): v for k, v in mapping.items()}
                else:
                    # assume keys are proto label strings
                    self.label_to_name = dict(mapping)

        # Precompute a set for quick membership
        self._have_idx_map = self.idx_to_name is not None
        self._have_lbl_map = self.label_to_name is not None

    @torch.no_grad()
    def predict_stack(self, images_tensors, tau=None):
        """
        images_tensors: list[Tensor[C,H,W]] transformed like val_transform
        returns: list[[class_name, count], ...] (includes 'unknown')
        """
        if tau is None:
            tau = self.tau

        x = torch.stack(images_tensors).to(self.device)  # [B,C,H,W]
        feats = get_embeddings(self.model, x)            # [B,D]
        sims  = feats @ self.prototypes.T                # [B,K]
        max_sims, idxs = sims.max(dim=1)

        labels = []
        for s, i in zip(max_sims.tolist(), idxs.tolist()):
            if s >= tau:
                # try index mapping first
                if self._have_idx_map and i in self.idx_to_name:
                    name = self.idx_to_name[i]
                else:
                    # try proto-label mapping
                    proto_lbl = self.proto_labels[i]
                    if self._have_lbl_map and proto_lbl in self.label_to_name:
                        name = self.label_to_name[proto_lbl]
                    else:
                        # fallback to original proto label
                        name = proto_lbl
                labels.append(name)
            else:
                labels.append("unknown")

        counts = Counter(labels)
        return [[k, v] for k, v in counts.items()]


# =========================
# EMBEDDINGS / PROTOTYPES
# =========================
@torch.no_grad()
def get_embeddings(model, x):
    """
    Get L2-normalized pre-logits embeddings from ConvNeXtV2.
    timm convnextv2: forward_features -> forward_head(pre_logits=True).
    """
    feats = model.forward_features(x)                  # pre-classifier features
    emb  = model.forward_head(feats, pre_logits=True)  # pooled pre-logits
    return F.normalize(emb, dim=1)  
@torch.no_grad()
def extract_foreground_mask(x, pixel_thresh=4):
    """
    x: [B, 3, H, W] normalized tensor
    returns: [B, 1, H, W] boolean mask
    """
    t = (pixel_thresh / 255.0) / 0.229
    mag = x.abs().sum(dim=1, keepdim=True)
    return mag > t


@torch.no_grad()
def get_region_embeddings_masked(
    model,
    x,
    num_regions=3,
    min_fg_ratio=0.12
):
    feats = model.forward_features(x)   # [B, C, Hf, Wf]
    B, C, Hf, Wf = feats.shape

    fg_mask = extract_foreground_mask(x)
    fg_mask = F.interpolate(
        fg_mask.float(),
        size=(Hf, Wf),
        mode="nearest"
    ).bool()

    feat_splits = torch.chunk(feats, num_regions, dim=2)
    mask_splits = torch.chunk(fg_mask, num_regions, dim=2)

    region_embs = []
    valid_regions = []

    for f, m in zip(feat_splits, mask_splits):
        fg_pixels = m.sum(dim=[2, 3])
        total_pixels = m.shape[2] * m.shape[3]
        fg_ratio = fg_pixels / total_pixels

        valid = (fg_ratio.squeeze(1) >= min_fg_ratio)
        valid_regions.append(valid)

        pooled = (f * m).sum(dim=[2, 3]) / (fg_pixels + 1e-6)
        pooled = F.normalize(pooled, dim=1)

        region_embs.append(pooled)

    return (
        torch.stack(region_embs, dim=1),   # [B, R, D]
        torch.stack(valid_regions, dim=1)  # [B, R]
    )


class CATTLE_IDENTIFICATION():

    data_transforms = {
        'train': transforms.Compose([
    
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'validation': transforms.Compose([
            #transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }
    def get_files_from_folder_scan_sort(self,path, limitX=20,Need_ReCheck = False):
    # Use os.scandir() for faster directory scanning
    
        with os.scandir(path) as entries:
        # Collect all filenames into a list
            files = [entry.name for entry in entries if entry.is_file()]
            # Sort the files based on the numeric part of the filenames (assuming filenames contain numbers)
            files.sort(key=lambda x: int(x.split('_')[0]), reverse=False)  # Adjust as needed for your filenames
            RECHECK_FILES = []
            if Need_ReCheck: #file name that include RC_TRUE at the end
                RECHECK_FILES = [f for f in files if 'RC_TRUE' in f][-50:]
            # Return the top 'limitX' files
            return files [:limitX] + RECHECK_FILES
    

    #SAVE_PATH = Path("identification_models_KNP") / "KNP_CONVNEXT_ARCFACE_22_Jan_2026_fixed" #KNP_CONVNEXT_ARCFACE_22_Jan_2026_fixed KNP_CONVNEXT_ARCFACE_Jan_2026_fixed
    SAVE_PATH = Path("identification_models_KNP") / "KNP_CONVNEXT_ARCFACE_22_Jan_2026_fixed_02" #KNP_CONVNEXT_ARCFACE_22_Jan_2026_fixed KNP_CONVNEXT_ARCFACE_Jan_2026_fixed
   
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    class_mapping_path = f'{SAVE_PATH}\\class_mappings.json'
    
    # Load model + weights (ALIGNED WITH TRAINING)
    NUM_CLASSES = len(json.load(open(SAVE_PATH / "class_mappings.json")))  # dynamic
    
    # Backbone only, NO classifier (matches training num_classes=0)
    model = timm.create_model('convnextv2_base.fcmae_ft_in22k_in1k',
                            pretrained=False, num_classes=0).to(device)

    # Load backbone weights (matches training's LAST_MODEL_SAVE_PATH)
    state = torch.load(SAVE_PATH / "best_backbone.pth", map_location=device)
    model.load_state_dict(state, strict=True)  # strict=True since architecture matches
    model.eval()
    
    # Load prototypes (matches training's LAST_PROTOS_PATH)
    infer = ProtoInfer(model, device, proto_ckpt_path=SAVE_PATH / "best_prototypes.pt", class_mapping_path=class_mapping_path)

    val_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                            [0.229, 0.224, 0.225]),
    ])

    def batch_identification(self,save_dir,tracking_id,FORCE_MISSED_DETECTION = False,path = None, batch_size = 50, showCon = False, Need_ReCheck = False, has_len_restriction = True):
        start_time = datetime.now()
        
        save_path = path
        #global batch_size 
        if path is None:
            save_path = f"{save_dir}//{tracking_id}"
        
        images = self.get_files_from_folder_scan_sort(save_path,batch_size,Need_ReCheck)
        if len(images) < 20 and has_len_restriction:
            return []
        stacked_images = []
        
        for image in images:
            #if counter < 1:
                #break
            #print(image)
            img_path = os.path.join(save_path, image)
            frame = cv2.imread(img_path)
         
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            input_tensor = self.data_transforms["validation"](frame).unsqueeze(0)  # Add batch dimension
            input_tensor = input_tensor.to(self.device)

            # Append the processed image tensor to the list
            stacked_images.append(input_tensor[0])  # Append the first element to keep it as (C, H, W)
            #counter -= 1
        
        return self.infer.predict_stack(stacked_images,0.3)
    
begin_identification = CATTLE_IDENTIFICATION()
# Out:
# tau :  4.0

# %%
batch_result = begin_identification.batch_identification(
    #r"H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1\Ch007_Camera 007_E2\2025-12-24_0023_part 1",    
    r"H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1\Ch002_Camera 002_E2\2025-12-24_0220_part 1",    
    "11", batch_size = 50,showCon = False, 
    Need_ReCheck=True, has_len_restriction = False)

max_result = max(batch_result, key=lambda x:x[1])
print(batch_result)
print(max_result)

#begin_identification.batch_identification(r'G:\Output\runs\KUNNEPPU_identification\KNP_Merge_and_Batch_identification\1 Sept Report 2025\reuse tetris_Sumiyoshi-44\Base_rtx8000_June_15000_v2\testris_Ch007_Camera 007_E2\2025-08-27_0514_part 2',"2", batch_size = 100)
# Out:
# [['4567', 29], ['3875', 1], ['4990', 1], ['A18', 7], ['A10', 12]]
# ['4567', 29]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#base_dir = r'E:\Output\runs\KUNNEPPU_identification\EF_vector 8 Jan 2026\KNP\Base_rtx8000_December_2025_20000_v2'
base_dir = r'H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1'
cameras = [
    '/Ch001_Camera 001_E2/2025-12-24_0023_part 1/',
     '/Ch002_Camera 002_E2/2025-12-24_0023_part 1/',
     '/Ch003_Camera 003_E2/2025-12-24_0023_part 1/',
    '/Ch004_Camera 004_E2/2025-12-24_0023_part 1/',
     '/Ch005_Camera 005_E2/2025-12-24_0023_part 1/',
     '/Ch006_Camera 006_E2/2025-12-24_0023_part 1/',
     '/Ch007_Camera 007_E2/2025-12-24_0023_part 1/',
    ]
for camera in cameras:
        
    path = base_dir + camera
    result = []
    for subfolder in os.listdir(path):
        subfolder_path = os.path.join(path, subfolder)
        if os.path.isdir(subfolder_path):
            # Process each subfolder
            print(f"Processing subfolder: {subfolder}")
            # Call your function here with the subfolder path
            #begin_identification.batch_identification(subfolder_path)
            #break
            try:

                batch_result = begin_identification.batch_identification(path,subfolder,batch_size = 50,Need_ReCheck=True) #for RC_TRUE
                print(batch_result)
                if(len(batch_result)>0):
                    maxResult = max(batch_result,key=lambda x:x[1])
                    print(maxResult)
                    result.append([subfolder,maxResult[0]]) 

            except Exception as e:
                print(f"Error processing subfolder {subfolder}: {e}")
        else:
            print(f"{subfolder} is not a directory.")

    def resultToCsv(result):
        # Create a DataFrame from the result list
        df = pd.DataFrame(result, columns=['TrackingID', 'Cattle ID'])
        
        # Save the DataFrame to a CSV file
        
        csv_path = os.path.join(path, 'ConvNextV2_Arcface_Result.csv')
        df.to_csv(csv_path, index=False)
        
        print(f"Results saved to {csv_path}")


    resultToCsv(result)
# Out:
# 0023_identification.mp4 is not a directory.
# Processing subfolder: 1
# [['4979', 52]]
# ['4979', 52]
# Processing subfolder: 100
# [['L7', 51], ['4413', 1]]
# ['L7', 51]
# Processing subfolder: 103
# [['4554', 1], ['4307', 1], ['L5', 50]]
# ['L5', 50]
# Processing subfolder: 105
# [['4525', 12], ['L11', 6], ['4979', 7], ['4413', 2]]
# ['4525', 12]
# Processing subfolder: 106
# [['4413', 9], ['4525', 42], ['4979', 11], ['4803', 3], ['4161', 1]]
# ['4525', 42]
# Processing subfolder: 107
# [['4979', 2], ['L11', 1], ['4416', 1], ['4413', 44], ['4990', 1], ['4525', 1]]
# ['4413', 44]
# Processing subfolder: 108
# [['L5', 20]]
# ['L5', 20]
# Processing subfolder: 109
# [['4993', 52]]
# ['4993', 52]
# Processing subfolder: 110
# []
# Processing subfolder: 111
# [['4979', 52]]
# ['4979', 52]
# Processing subfolder: 112
# [['1374', 45], ['L6', 5], ['L7', 6]]
# ['1374', 45]
# Processing subfolder: 114
# []
# Processing subfolder: 115
# [['4815', 50]]
# ['4815', 50]
# Processing subfolder: 119
# [['4628', 1], ['L9', 2], ['4416', 1], ['4627', 1], ['4381', 19], ['4413', 7]]
# ['4381', 19]
# Processing subfolder: 125
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 126
# [['L7', 55], ['4826', 1]]
# ['L7', 55]
# Processing subfolder: 127
# []
# Processing subfolder: 128
# []
# Processing subfolder: 129
# [['1374', 38]]
# ['1374', 38]
# Processing subfolder: 136
# [['4975', 1], ['4608', 1], ['4872', 7], ['4773', 15], ['4104', 1], ['9697', 2], ['L11', 25]]
# ['L11', 25]
# Processing subfolder: 14
# []
# Processing subfolder: 140
# [['4826', 1], ['4608', 6], ['4627', 3], ['4845', 39]]
# ['4845', 39]
# Processing subfolder: 141
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 145
# []
# Processing subfolder: 153
# []
# Processing subfolder: 155
# []
# Processing subfolder: 157
# []
# Processing subfolder: 158
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 159
# [['5000', 2], ['A10', 48], ['L6', 2]]
# ['A10', 48]
# Processing subfolder: 160
# [['4845', 26]]
# ['4845', 26]
# Processing subfolder: 161
# [['4845', 50]]
# ['4845', 50]
# Processing subfolder: 162
# []
# Processing subfolder: 163
# []
# Processing subfolder: 164
# [['L3', 37]]
# ['L3', 37]
# Processing subfolder: 166
# []
# Processing subfolder: 170
# []
# Processing subfolder: 171
# []
# Processing subfolder: 172
# []
# Processing subfolder: 175
# [['L6', 1], ['4974', 19], ['4420', 9], ['4872', 17], ['4608', 10]]
# ['4974', 19]
# Processing subfolder: 177
# [['4608', 1], ['L3', 50], ['4548', 1]]
# ['L3', 50]
# Processing subfolder: 182
# [['3875', 13], ['4416', 20], ['4838', 17], ['4567', 1], ['4420', 1]]
# ['4416', 20]
# Processing subfolder: 186
# [['4773', 49], ['4872', 1], ['4816', 2]]
# ['4773', 49]
# Processing subfolder: 190
# [['A37', 50]]
# ['A37', 50]
# Processing subfolder: 191
# []
# Processing subfolder: 192
# [['9697', 32], ['4161', 1]]
# ['9697', 32]
# Processing subfolder: 198
# []
# Processing subfolder: 199
# [['4416', 51]]
# ['4416', 51]
# Processing subfolder: 2
# [['4525', 77]]
# ['4525', 77]
# Processing subfolder: 20
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 201
# [['4975', 1], ['4382', 1], ['4773', 49], ['4826', 1]]
# ['4773', 49]
# Processing subfolder: 205
# [['L6', 50]]
# ['L6', 50]
# Processing subfolder: 214
# [['4416', 51], ['4420', 1]]
# ['4416', 51]
# Processing subfolder: 217
# [['9697', 46], ['4803', 6]]
# ['9697', 46]
# Processing subfolder: 219
# [['4551', 52]]
# ['4551', 52]
# Processing subfolder: 22
# [['4872', 7], ['4608', 10], ['4842', 2], ['4993', 25]]
# ['4993', 25]
# Processing subfolder: 229
# [['4783', 49], ['4650', 3]]
# ['4783', 49]
# Processing subfolder: 234
# [['4307', 50]]
# ['4307', 50]
# Processing subfolder: 235
# []
# Processing subfolder: 236
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 237
# [['L1', 1], ['4990', 1], ['4999', 47], ['4548', 1], ['5000', 1], ['L3', 1]]
# ['4999', 47]
# Processing subfolder: 239
# [['4628', 12], ['4872', 38], ['4842', 1], ['L11', 1]]
# ['4872', 38]
# Processing subfolder: 24
# [['4781', 2], ['A37', 36], ['L3', 16]]
# ['A37', 36]
# Processing subfolder: 240
# [['L5', 39]]
# ['L5', 39]
# Processing subfolder: 241
# [['4548', 50]]
# ['4548', 50]
# Processing subfolder: 250
# [['L5', 51], ['4635', 1]]
# ['L5', 51]
# Processing subfolder: 251
# [['L11', 51], ['4773', 1]]
# ['L11', 51]
# Processing subfolder: 257
# [['4608', 47], ['4872', 1], ['4104', 4]]
# ['4608', 47]
# Processing subfolder: 258
# []
# Processing subfolder: 259
# [['4161', 47], ['4990', 1], ['L1', 1], ['4104', 1]]
# ['4161', 47]
# Processing subfolder: 260
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 261
# []
# Processing subfolder: 265
# []
# Processing subfolder: 266
# []
# Processing subfolder: 267
# [['4816', 52]]
# ['4816', 52]
# Processing subfolder: 268
# [['4608', 24], ['4391', 19], ['4872', 8], ['4551', 1]]
# ['4608', 24]
# Processing subfolder: 27
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 274
# [['4826', 1], ['4845', 47], ['4979', 1], ['4627', 2]]
# ['4845', 47]
# Processing subfolder: 282
# []
# Processing subfolder: 284
# [['L1', 50]]
# ['L1', 50]
# Processing subfolder: 291
# [['4161', 23], ['3875', 13], ['4598', 12], ['4541', 2]]
# ['4161', 23]
# Processing subfolder: 293
# [['4420', 1], ['4538', 1], ['L3', 47], ['4548', 2], ['5000', 1]]
# ['L3', 47]
# Processing subfolder: 295
# []
# Processing subfolder: 299
# [['L1', 50]]
# ['L1', 50]
# Processing subfolder: 3
# [['4816', 52]]
# ['4816', 52]
# Processing subfolder: 301
# []
# Processing subfolder: 302
# [['4975', 7], ['4176', 3], ['4420', 23], ['4872', 8], ['4533', 3], ['4608', 8]]
# ['4420', 23]
# Processing subfolder: 303
# []
# Processing subfolder: 31
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 316
# [['L1', 43]]
# ['L1', 43]
# Processing subfolder: 318
# []
# Processing subfolder: 319
# [['4845', 46], ['4337', 4]]
# ['4845', 46]
# Processing subfolder: 32
# [['4575', 50], ['4781', 1], ['L1', 1]]
# ['4575', 50]
# Processing subfolder: 320
# [['4975', 36], ['4420', 7], ['4176', 2], ['4974', 1]]
# ['4975', 36]
# Processing subfolder: 321
# [['4538', 45]]
# ['4538', 45]
# Processing subfolder: 324
# [['4999', 49], ['3875', 1], ['L9', 2]]
# ['4999', 49]
# Processing subfolder: 327
# [['4627', 46]]
# ['4627', 46]
# Processing subfolder: 33
# [['4382', 1], ['4805', 49]]
# ['4805', 49]
# Processing subfolder: 332
# [['4551', 38], ['4987', 1]]
# ['4551', 38]
# Processing subfolder: 336
# []
# Processing subfolder: 337
# []
# Processing subfolder: 338
# []
# Processing subfolder: 339
# []
# Processing subfolder: 340
# []
# Processing subfolder: 342
# []
# Processing subfolder: 347
# [['4826', 9], ['4608', 3], ['4872', 18], ['4975', 15], ['4420', 6]]
# ['4872', 18]
# Processing subfolder: 348
# []
# Processing subfolder: 350
# [['4176', 6], ['4773', 2], ['4608', 1], ['4993', 6], ['4826', 9]]
# ['4826', 9]
# Processing subfolder: 351
# []
# Processing subfolder: 352
# [['4420', 5], ['4856', 1], ['4361', 4], ['4581', 2], ['4975', 15], ['4845', 1], ['4974', 9], ['4628', 10]]
# ['4975', 15]
# Processing subfolder: 353
# []
# Processing subfolder: 354
# [['4416', 50]]
# ['4416', 50]
# Processing subfolder: 355
# [['4311', 2], ['4416', 55]]
# ['4416', 55]
# Processing subfolder: 357
# [['4872', 3], ['4975', 5], ['4599', 1], ['4581', 2], ['4826', 41]]
# ['4826', 41]
# Processing subfolder: 358
# [['4781', 12], ['4590', 38], ['4413', 6]]
# ['4590', 38]
# Processing subfolder: 359
# [['4993', 7], ['4826', 14], ['4773', 4], ['4608', 1], ['4176', 1]]
# ['4826', 14]
# Processing subfolder: 36
# [['4993', 31]]
# ['4993', 31]
# Processing subfolder: 360
# []
# Processing subfolder: 361
# [['4826', 27], ['4176', 3], ['4773', 3], ['4608', 5]]
# ['4826', 27]
# Processing subfolder: 362
# [['4872', 12], ['4176', 2], ['4420', 18], ['4975', 1], ['4805', 18], ['4581', 1]]
# ['4420', 18]
# Processing subfolder: 364
# [['4533', 4], ['4975', 7], ['4420', 5], ['4872', 4], ['4176', 2], ['4590', 1], ['4161', 29]]
# ['4161', 29]
# Processing subfolder: 365
# []
# Processing subfolder: 366
# []
# Processing subfolder: 367
# [['1374', 52]]
# ['1374', 52]
# Processing subfolder: 368
# [['4856', 52]]
# ['4856', 52]
# Processing subfolder: 369
# [['4816', 52]]
# ['4816', 52]
# Processing subfolder: 37
# []
# Processing subfolder: 371
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 372
# [['4551', 55]]
# ['4551', 55]
# Processing subfolder: 373
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 374
# [['A37', 52]]
# ['A37', 52]
# Processing subfolder: 375
# []
# Processing subfolder: 376
# [['4845', 52]]
# ['4845', 52]
# Processing subfolder: 377
# [['4773', 50]]
# ['4773', 50]
# Processing subfolder: 378
# [['4413', 1], ['4628', 1], ['4525', 48], ['4416', 2]]
# ['4525', 48]
# Processing subfolder: 379
# [['4993', 52]]
# ['4993', 52]
# Processing subfolder: 380
# [['4551', 3], ['4608', 31]]
# ['4608', 31]
# Processing subfolder: 381
# [['4548', 4], ['4413', 20], ['A37', 2], ['4161', 19], ['L3', 2]]
# ['4413', 20]
# Processing subfolder: 382
# [['L12', 1], ['4382', 2], ['4826', 30], ['4975', 10], ['4350', 3], ['4872', 1], ['4104', 1], ['4581', 2]]
# ['4826', 30]
# Processing subfolder: 383
# [['4993', 50]]
# ['4993', 50]
# Processing subfolder: 384
# [['4816', 6], ['4624', 4], ['4382', 6], ['4567', 2], ['4416', 1], ['4420', 2]]
# ['4816', 6]
# Processing subfolder: 385
# []
# Processing subfolder: 386
# [['4773', 5], ['4816', 47]]
# ['4816', 47]
# Processing subfolder: 397
# [['4748', 1], ['4575', 51]]
# ['4575', 51]
# Processing subfolder: 399
# [['4598', 12], ['4523', 5], ['A37', 6], ['4624', 24], ['4413', 5]]
# ['4624', 24]
# Processing subfolder: 40
# [['4608', 1], ['4792', 2], ['4781', 5], ['L3', 7], ['A37', 6], ['5000', 3], ['4548', 6], ['4815', 17], ['4527', 5]]
# ['4815', 17]
# Processing subfolder: 400
# [['L9', 2], ['4999', 50]]
# ['4999', 50]
# Processing subfolder: 401
# [['4816', 1], ['4979', 40], ['4650', 1]]
# ['4979', 40]
# Processing subfolder: 403
# [['4525', 4], ['3875', 1], ['4420', 2], ['4416', 41], ['A10', 1], ['4781', 1], ['L9', 1], ['4598', 1]]
# ['4416', 41]
# Processing subfolder: 404
# [['5000', 1], ['4635', 2], ['1374', 47], ['4551', 2]]
# ['1374', 47]
# Processing subfolder: 407
# [['L3', 52]]
# ['L3', 52]
# Processing subfolder: 410
# [['4999', 50], ['3875', 2]]
# ['4999', 50]
# Processing subfolder: 411
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 412
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 413
# [['4975', 3], ['4872', 39]]
# ['4872', 39]
# Processing subfolder: 414
# []
# Processing subfolder: 416
# [['4382', 3], ['4773', 48], ['4975', 1]]
# ['4773', 48]
# Processing subfolder: 417
# []
# Processing subfolder: 419
# [['4533', 1], ['4872', 31], ['4176', 3], ['4104', 1], ['4974', 1], ['4975', 2]]
# ['4872', 31]
# Processing subfolder: 42
# [['4872', 49], ['4382', 2], ['4826', 1]]
# ['4872', 49]
# Processing subfolder: 421
# []
# Processing subfolder: 423
# [['4979', 52]]
# ['4979', 52]
# Processing subfolder: 427
# [['4872', 2], ['4773', 46]]
# ['4773', 46]
# Processing subfolder: 429
# [['4975', 6], ['4872', 6], ['4974', 30], ['4104', 8]]
# ['4974', 30]
# Processing subfolder: 43
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 430
# [['L1', 50]]
# ['L1', 50]
# Processing subfolder: 432
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 435
# [['4381', 52]]
# ['4381', 52]
# Processing subfolder: 438
# [['4993', 52]]
# ['4993', 52]
# Processing subfolder: 440
# [['4382', 1], ['4816', 49], ['4176', 1], ['L12', 2], ['L3', 4]]
# ['4816', 49]
# Processing subfolder: 441
# [['4856', 41], ['4176', 1], ['4872', 3], ['L3', 5]]
# ['4856', 41]
# Processing subfolder: 442
# [['L3', 48], ['4176', 3], ['L12', 1]]
# ['L3', 48]
# Processing subfolder: 443
# [['4872', 1], ['4381', 46], ['4142', 1], ['4815', 1], ['4533', 1]]
# ['4381', 46]
# Processing subfolder: 444
# [['4533', 4], ['1374', 1], ['5000', 2], ['L6', 57]]
# ['L6', 57]
# Processing subfolder: 445
# [['4993', 52]]
# ['4993', 52]
# Processing subfolder: 446
# [['4533', 2], ['L6', 8], ['4792', 24], ['1374', 2], ['4816', 14], ['L3', 1]]
# ['4792', 24]
# Processing subfolder: 447
# [['9697', 1], ['4805', 49]]
# ['4805', 49]
# Processing subfolder: 448
# [['4999', 50], ['4979', 1], ['4533', 1], ['4608', 4]]
# ['4999', 50]
# Processing subfolder: 449
# [['9697', 15], ['4993', 2], ['4420', 6], ['L11', 3], ['4872', 19], ['4826', 2], ['4533', 3], ['4608', 1], ['4773', 1]]
# ['4872', 19]
# Processing subfolder: 450
# []
# Processing subfolder: 451
# [['4826', 52]]
# ['4826', 52]
# Processing subfolder: 452
# [['4872', 20], ['4533', 1], ['4420', 1]]
# ['4872', 20]
# Processing subfolder: 454
# [['4391', 3], ['4872', 45], ['4842', 4]]
# ['4872', 45]
# Processing subfolder: 455
# [['L1', 5], ['4792', 8], ['4548', 8], ['unknown', 3], ['4608', 4], ['4993', 9]]
# ['4993', 9]
# Processing subfolder: 456
# []
# Processing subfolder: 457
# []
# Processing subfolder: 458
# []
# Processing subfolder: 461
# [['L1', 51], ['4533', 1], ['4872', 1]]
# ['L1', 51]
# Processing subfolder: 463
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 464
# []
# Processing subfolder: 465
# []
# Processing subfolder: 466
# [['4554', 2], ['4551', 3], ['L5', 2], ['4635', 1], ['4974', 1], ['L9', 2], ['3875', 8], ['unknown', 6], ['4350', 1], ['4654', 1], ['4650', 4], ['4416', 21]]
# ['4416', 21]
# Processing subfolder: 467
# [['9697', 45], ['4773', 5]]
# ['9697', 45]
# Processing subfolder: 470
# [['4413', 52]]
# ['4413', 52]
# Processing subfolder: 473
# []
# Processing subfolder: 475
# []
# Processing subfolder: 476
# []
# Processing subfolder: 477
# []
# Processing subfolder: 479
# []
# Processing subfolder: 48
# []
# Processing subfolder: 481
# [['4367', 1], ['3875', 1], ['4792', 19], ['4979', 1], ['unknown', 3], ['4987', 1], ['L3', 1], ['A18', 24], ['L1', 1]]
# ['A18', 24]
# Processing subfolder: 482
# []
# Processing subfolder: 483
# []
# Processing subfolder: 489
# [['4628', 15], ['L9', 3], ['4416', 5], ['4381', 27]]
# ['4381', 27]
# Processing subfolder: 49
# []
# Processing subfolder: 491
# [['4627', 1], ['4792', 1], ['L1', 46], ['4838', 4]]
# ['L1', 46]
# Processing subfolder: 492
# [['4805', 52]]
# ['4805', 52]
# Processing subfolder: 493
# []
# Processing subfolder: 494
# [['4815', 52]]
# ['4815', 52]
# Processing subfolder: 496
# [['4350', 2], ['4816', 38], ['4826', 3], ['4993', 1], ['9697', 1]]
# ['4816', 38]
# Processing subfolder: 497
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 498
# [['4590', 33], ['4792', 18], ['L3', 1]]
# ['4590', 33]
# Processing subfolder: 5
# [['L5', 51], ['4554', 1]]
# ['L5', 51]
# Processing subfolder: 50
# []
# Processing subfolder: 503
# [['4816', 50]]
# ['4816', 50]
# Processing subfolder: 509
# [['3875', 23], ['4838', 1], ['4538', 3], ['4990', 25]]
# ['4990', 25]
# Processing subfolder: 511
# [['4650', 1], ['L1', 1], ['3875', 1], ['L9', 49]]
# ['L9', 49]
# Processing subfolder: 516
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 519
# [['4590', 52]]
# ['4590', 52]
# Processing subfolder: 520
# [['4381', 25], ['4856', 1], ['L12', 1], ['L9', 5], ['4525', 17], ['4413', 3]]
# ['4381', 25]
# Processing subfolder: 521
# [['4990', 51], ['L11', 1]]
# ['4990', 51]
# Processing subfolder: 522
# [['4993', 23], ['4773', 22], ['4826', 4], ['4608', 1]]
# ['4993', 23]
# Processing subfolder: 53
# [['4654', 11], ['4551', 38], ['4816', 1], ['4987', 1], ['L5', 1]]
# ['4551', 38]
# Processing subfolder: 530
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 54
# [['4872', 52]]
# ['4872', 52]
# Processing subfolder: 546
# []
# Processing subfolder: 547
# [['4872', 1], ['4773', 5], ['4993', 27], ['4608', 1]]
# ['4993', 27]
# Processing subfolder: 548
# [['4872', 5], ['4993', 41], ['4773', 2], ['4533', 5], ['4608', 2], ['4391', 1]]
# ['4993', 41]
# Processing subfolder: 549
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 550
# []
# Processing subfolder: 551
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 552
# []
# Processing subfolder: 553
# []
# Processing subfolder: 554
# []
# Processing subfolder: 555
# []
# Processing subfolder: 559
# []
# Processing subfolder: 56
# []
# Processing subfolder: 563
# []
# Processing subfolder: 566
# [['4815', 10], ['4307', 5], ['L3', 5], ['L6', 1], ['4987', 3], ['4104', 1], ['4590', 2], ['4533', 4], ['4548', 11], ['4527', 9], ['unknown', 1]]
# ['4548', 11]
# Processing subfolder: 567
# []
# Processing subfolder: 568
# []
# Processing subfolder: 569
# [['4872', 100]]
# ['4872', 100]
# Processing subfolder: 570
# []
# Processing subfolder: 573
# [['4993', 2], ['4979', 27], ['4391', 1], ['4816', 19], ['3875', 1]]
# ['4979', 27]
# Processing subfolder: 575
# [['4872', 7], ['4993', 2], ['4975', 1], ['4773', 3], ['4842', 5], ['unknown', 2], ['4533', 1], ['L3', 1], ['4420', 28], ['4974', 4]]
# ['4420', 28]
# Processing subfolder: 576
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 580
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 588
# [['L3', 45], ['4990', 3], ['4548', 1], ['A37', 1]]
# ['L3', 45]
# Processing subfolder: 589
# []
# Processing subfolder: 590
# [['A37', 35], ['L3', 15]]
# ['A37', 35]
# Processing subfolder: 6
# [['4416', 81], ['4838', 1]]
# ['4416', 81]
# Processing subfolder: 61
# [['L5', 51], ['L6', 1]]
# ['L5', 51]
# Processing subfolder: 63
# []
# Processing subfolder: 65
# [['4993', 23], ['4990', 4], ['4381', 23]]
# ['4993', 23]
# Processing subfolder: 66
# [['4856', 50]]
# ['4856', 50]
# Processing subfolder: 67
# [['4381', 3], ['4845', 4], ['4413', 12], ['4525', 1], ['4627', 2], ['L9', 1]]
# ['4413', 12]
# Processing subfolder: 7
# [['A37', 52], ['4416', 1], ['L9', 9]]
# ['A37', 52]
# Processing subfolder: 70
# []
# Processing subfolder: 75
# [['L3', 51], ['4608', 1]]
# ['L3', 51]
# Processing subfolder: 79
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 8
# [['4999', 18], ['3875', 2]]
# ['4999', 18]
# Processing subfolder: 82
# [['4993', 39], ['4608', 5], ['4773', 1]]
# ['4993', 39]
# Processing subfolder: 84
# [['4979', 50]]
# ['4979', 50]
# Processing subfolder: 86
# [['4381', 50]]
# ['4381', 50]
# Processing subfolder: 88
# []
# Processing subfolder: 9
# [['L9', 50]]
# ['L9', 50]
# Processing subfolder: 92
# [['4856', 50], ['4381', 2]]
# ['4856', 50]
# Processing subfolder: 93
# [['4979', 50]]
# ['4979', 50]
# Processing subfolder: 94
# [['4816', 1], ['4783', 51]]
# ['4783', 51]
# finalized_pdf.csv is not a directory.
# frame_data.json is not a directory.
# missed_count.csv is not a directory.
# program_accuracy.csv is not a directory.
# Results saved to H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch001_Camera 001_E2/2025-12-24_0023_part 1/ConvNextV2_Arcface_Result.csv
# 0023_identification.mp4 is not a directory.
# Processing subfolder: 1
# [['4856', 12], ['L12', 33], ['4382', 4], ['4525', 1], ['4816', 1], ['4420', 1]]
# ['L12', 33]
# Processing subfolder: 101
# [['L5', 36]]
# ['L5', 36]
# Processing subfolder: 102
# [['4993', 52]]
# ['4993', 52]
# Processing subfolder: 104
# [['4979', 51]]
# ['4979', 51]
# Processing subfolder: 106
# [['4654', 2], ['1374', 1], ['4104', 2], ['4533', 11], ['4993', 14], ['4608', 1], ['4826', 1], ['4842', 3], ['L5', 1], ['4420', 1], ['4872', 1], ['4979', 3], ['4391', 1]]
# ['4993', 14]
# Processing subfolder: 107
# []
# Processing subfolder: 11
# [['L9', 14], ['3875', 11]]
# ['L9', 14]
# Processing subfolder: 111
# [['L9', 50]]
# ['L9', 50]
# Processing subfolder: 112
# [['4990', 1], ['4381', 48], ['4416', 3]]
# ['4381', 48]
# Processing subfolder: 115
# [['4979', 49], ['4650', 3]]
# ['4979', 49]
# Processing subfolder: 116
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 117
# [['L7', 52]]
# ['L7', 52]
# Processing subfolder: 118
# [['1374', 52]]
# ['1374', 52]
# Processing subfolder: 119
# [['4307', 4], ['4654', 2], ['4826', 7], ['4635', 3], ['L5', 2], ['4975', 2], ['4575', 1], ['1374', 4], ['4311', 1], ['4979', 13], ['unknown', 1], ['4974', 3]]
# ['4979', 13]
# Processing subfolder: 12
# []
# Processing subfolder: 123
# []
# Processing subfolder: 124
# [['4783', 1], ['4413', 3], ['L7', 48]]
# ['L7', 48]
# Processing subfolder: 125
# []
# Processing subfolder: 126
# [['4533', 2], ['4104', 1], ['L7', 16], ['L9', 4], ['3875', 7], ['A10', 3], ['4538', 3], ['4979', 5], ['unknown', 2], ['4783', 1], ['4548', 3], ['4748', 3]]
# ['L7', 16]
# Processing subfolder: 128
# [['4803', 5], ['L11', 45]]
# ['L11', 45]
# Processing subfolder: 129
# [['4627', 52]]
# ['4627', 52]
# Processing subfolder: 130
# [['4826', 1], ['4773', 1], ['4845', 48]]
# ['4845', 48]
# Processing subfolder: 131
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 132
# [['4845', 50]]
# ['4845', 50]
# Processing subfolder: 134
# []
# Processing subfolder: 135
# [['L5', 1], ['unknown', 2], ['4548', 1], ['4979', 46]]
# ['4979', 46]
# Processing subfolder: 136
# []
# Processing subfolder: 137
# [['L12', 2], ['4773', 1], ['4391', 1], ['L11', 49]]
# ['L11', 49]
# Processing subfolder: 139
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 14
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 140
# []
# Processing subfolder: 142
# [['A10', 51], ['L5', 1]]
# ['A10', 51]
# Processing subfolder: 143
# [['4845', 46]]
# ['4845', 46]
# Processing subfolder: 145
# [['L3', 52]]
# ['L3', 52]
# Processing subfolder: 147
# [['L11', 62]]
# ['L11', 62]
# Processing subfolder: 15
# [['L3', 1], ['4548', 5], ['A37', 43], ['5000', 1], ['4781', 2]]
# ['A37', 43]
# Processing subfolder: 156
# [['4554', 4], ['4654', 19], ['4548', 1], ['4420', 1], ['4361', 15], ['4987', 1], ['L3', 16]]
# ['4654', 19]
# Processing subfolder: 157
# []
# Processing subfolder: 158
# []
# Processing subfolder: 159
# [['4974', 24], ['4420', 10], ['4872', 9], ['4975', 8], ['4608', 1]]
# ['4974', 24]
# Processing subfolder: 16
# [['4993', 44], ['4842', 1]]
# ['4993', 44]
# Processing subfolder: 161
# [['4872', 1], ['4589', 18], ['L12', 24], ['4979', 2], ['4608', 2], ['4382', 3]]
# ['L12', 24]
# Processing subfolder: 162
# []
# Processing subfolder: 164
# []
# Processing subfolder: 170
# [['4627', 52]]
# ['4627', 52]
# Processing subfolder: 171
# [['L6', 2], ['4627', 47]]
# ['4627', 47]
# Processing subfolder: 173
# []
# Processing subfolder: 174
# [['4311', 1], ['4627', 47], ['4548', 1], ['3875', 1]]
# ['4627', 47]
# Processing subfolder: 175
# [['L9', 7], ['L5', 1], ['4567', 1], ['4627', 24], ['4548', 17]]
# ['4627', 24]
# Processing subfolder: 177
# []
# Processing subfolder: 178
# [['A10', 21], ['4567', 29]]
# ['4567', 29]
# Processing subfolder: 182
# [['L12', 13], ['4589', 37], ['4816', 5], ['4104', 1]]
# ['4589', 37]
# Processing subfolder: 183
# [['4974', 27]]
# ['4974', 27]
# Processing subfolder: 184
# []
# Processing subfolder: 194
# []
# Processing subfolder: 195
# []
# Processing subfolder: 198
# [['4654', 1], ['4627', 51]]
# ['4627', 51]
# Processing subfolder: 2
# [['L6', 32]]
# ['L6', 32]
# Processing subfolder: 200
# []
# Processing subfolder: 201
# []
# Processing subfolder: 202
# []
# Processing subfolder: 203
# [['4773', 22], ['4533', 7], ['4382', 7], ['unknown', 2], ['4104', 10], ['4350', 4]]
# ['4773', 22]
# Processing subfolder: 219
# [['A37', 50]]
# ['A37', 50]
# Processing subfolder: 221
# [['4416', 52]]
# ['4416', 52]
# Processing subfolder: 230
# [['4311', 1], ['9697', 51]]
# ['9697', 51]
# Processing subfolder: 236
# [['4654', 12], ['4533', 6], ['4551', 16], ['4104', 1], ['L5', 4], ['4525', 3]]
# ['4551', 16]
# Processing subfolder: 237
# [['L5', 15], ['unknown', 1], ['4548', 10], ['4533', 7], ['4551', 3], ['A10', 1], ['L7', 2], ['4420', 1], ['4104', 2], ['4635', 1]]
# ['L5', 15]
# Processing subfolder: 238
# [['4773', 51], ['4382', 1]]
# ['4773', 51]
# Processing subfolder: 239
# [['4551', 12], ['4420', 5], ['4548', 2], ['4654', 1]]
# ['4551', 12]
# Processing subfolder: 241
# []
# Processing subfolder: 243
# [['4416', 49], ['4781', 1]]
# ['4416', 49]
# Processing subfolder: 244
# []
# Processing subfolder: 246
# []
# Processing subfolder: 247
# [['4773', 3], ['4416', 50]]
# ['4416', 50]
# Processing subfolder: 248
# []
# Processing subfolder: 256
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 257
# [['4551', 54], ['1374', 1]]
# ['4551', 54]
# Processing subfolder: 258
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 259
# []
# Processing subfolder: 26
# [['4990', 53]]
# ['4990', 53]
# Processing subfolder: 260
# []
# Processing subfolder: 261
# []
# Processing subfolder: 262
# []
# Processing subfolder: 263
# [['4816', 50]]
# ['4816', 50]
# Processing subfolder: 264
# []
# Processing subfolder: 266
# []
# Processing subfolder: 267
# [['4533', 21], ['1374', 9], ['4654', 4], ['L5', 3], ['4551', 5], ['L7', 1], ['4548', 1], ['4635', 3], ['4104', 3]]
# ['4533', 21]
# Processing subfolder: 268
# []
# Processing subfolder: 269
# [['4628', 1], ['L12', 2], ['L1', 1], ['L11', 42], ['4773', 3], ['4533', 1], ['4391', 1], ['4420', 1]]
# ['L11', 42]
# Processing subfolder: 27
# []
# Processing subfolder: 270
# [['4554', 1], ['4815', 13], ['L1', 2], ['5000', 2], ['L6', 14], ['4590', 11], ['4307', 9]]
# ['L6', 14]
# Processing subfolder: 271
# [['4416', 56]]
# ['4416', 56]
# Processing subfolder: 272
# [['4551', 1], ['4773', 1], ['4979', 1], ['4311', 1], ['L11', 47], ['unknown', 1]]
# ['L11', 47]
# Processing subfolder: 273
# [['4551', 14], ['4533', 27], ['4635', 11]]
# ['4533', 27]
# Processing subfolder: 274
# [['4307', 50]]
# ['4307', 50]
# Processing subfolder: 276
# [['4999', 52]]
# ['4999', 52]
# Processing subfolder: 279
# [['4382', 13], ['4975', 7], ['4872', 32]]
# ['4872', 32]
# Processing subfolder: 281
# [['4416', 16], ['4554', 1], ['4311', 2], ['L12', 2], ['9697', 10], ['L9', 8], ['4990', 15], ['4382', 2]]
# ['4416', 16]
# Processing subfolder: 282
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 284
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 285
# [['4650', 2], ['4567', 1], ['A18', 49]]
# ['A18', 49]
# Processing subfolder: 286
# [['4533', 10], ['L5', 4], ['4104', 7], ['4838', 1], ['4654', 6], ['4548', 1], ['1374', 5], ['4635', 4], ['4826', 1], ['4554', 1], ['4975', 2], ['4551', 1]]
# ['4533', 10]
# Processing subfolder: 288
# [['4872', 1], ['A18', 12], ['3875', 16], ['4654', 2], ['A10', 1], ['4548', 7], ['L9', 1], ['L1', 10]]
# ['3875', 16]
# Processing subfolder: 29
# []
# Processing subfolder: 290
# []
# Processing subfolder: 291
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 292
# [['4654', 4], ['4635', 3], ['4872', 1], ['4533', 24], ['4382', 3], ['4826', 9], ['L5', 2]]
# ['4533', 24]
# Processing subfolder: 293
# []
# Processing subfolder: 296
# [['4161', 43], ['4783', 5], ['3875', 2]]
# ['4161', 43]
# Processing subfolder: 3
# [['A37', 50]]
# ['A37', 50]
# Processing subfolder: 302
# []
# Processing subfolder: 305
# [['4416', 8], ['4608', 34], ['4872', 9], ['4382', 1]]
# ['4608', 34]
# Processing subfolder: 307
# [['4975', 2], ['4382', 1], ['4816', 48], ['4104', 1]]
# ['4816', 48]
# Processing subfolder: 308
# []
# Processing subfolder: 309
# []
# Processing subfolder: 31
# []
# Processing subfolder: 310
# [['L5', 45], ['4554', 7]]
# ['L5', 45]
# Processing subfolder: 311
# []
# Processing subfolder: 313
# [['4872', 3], ['4420', 1], ['4816', 48]]
# ['4816', 48]
# Processing subfolder: 314
# [['4608', 52]]
# ['4608', 52]
# Processing subfolder: 315
# [['4826', 1], ['4337', 2], ['unknown', 1], ['4990', 2], ['4420', 2], ['4845', 44]]
# ['4845', 44]
# Processing subfolder: 316
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 317
# [['4838', 1], ['L1', 52]]
# ['L1', 52]
# Processing subfolder: 318
# []
# Processing subfolder: 320
# []
# Processing subfolder: 322
# []
# Processing subfolder: 323
# [['4104', 35], ['4608', 16]]
# ['4104', 35]
# Processing subfolder: 325
# []
# Processing subfolder: 326
# []
# Processing subfolder: 327
# [['4104', 26], ['4608', 22], ['4382', 1], ['L3', 1]]
# ['4104', 26]
# Processing subfolder: 329
# []
# Processing subfolder: 33
# []
# Processing subfolder: 330
# [['1374', 17], ['4104', 2], ['4791', 6], ['L12', 1], ['4554', 1], ['4993', 3], ['4608', 20], ['4564', 1]]
# ['4608', 20]
# Processing subfolder: 331
# []
# Processing subfolder: 332
# []
# Processing subfolder: 334
# [['4420', 50]]
# ['4420', 50]
# Processing subfolder: 338
# []
# Processing subfolder: 34
# [['4816', 1], ['4783', 1], ['L9', 1], ['L1', 1], ['4990', 45], ['3875', 3]]
# ['4990', 45]
# Processing subfolder: 341
# [['4420', 2], ['4554', 3], ['4608', 12], ['4993', 1], ['4979', 1], ['4382', 7], ['4599', 1], ['4527', 1], ['4104', 3]]
# ['4608', 12]
# Processing subfolder: 342
# []
# Processing subfolder: 344
# []
# Processing subfolder: 347
# [['L11', 1], ['A18', 1], ['4627', 6], ['4856', 1], ['4367', 1], ['4979', 5], ['L7', 3], ['4420', 5], ['4311', 28], ['unknown', 1]]
# ['4311', 28]
# Processing subfolder: 351
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 360
# [['4856', 52]]
# ['4856', 52]
# Processing subfolder: 362
# [['4845', 50], ['9697', 1]]
# ['4845', 50]
# Processing subfolder: 363
# [['4974', 5], ['4975', 26], ['4581', 1], ['4104', 1], ['4176', 2], ['4872', 3], ['4420', 9]]
# ['4975', 26]
# Processing subfolder: 364
# [['4999', 32], ['4624', 1], ['3875', 11], ['L9', 1]]
# ['4999', 32]
# Processing subfolder: 366
# [['4538', 52]]
# ['4538', 52]
# Processing subfolder: 367
# []
# Processing subfolder: 368
# [['4627', 52]]
# ['4627', 52]
# Processing subfolder: 37
# [['L1', 1], ['4575', 47], ['L11', 2]]
# ['4575', 47]
# Processing subfolder: 371
# [['4551', 52]]
# ['4551', 52]
# Processing subfolder: 372
# []
# Processing subfolder: 373
# []
# Processing subfolder: 374
# []
# Processing subfolder: 376
# []
# Processing subfolder: 378
# []
# Processing subfolder: 379
# []
# Processing subfolder: 38
# [['3875', 1], ['4990', 35]]
# ['4990', 35]
# Processing subfolder: 382
# []
# Processing subfolder: 384
# []
# Processing subfolder: 385
# []
# Processing subfolder: 386
# [['4975', 3], ['4872', 10], ['4420', 39], ['4350', 1]]
# ['4420', 39]
# Processing subfolder: 387
# [['4608', 8], ['4872', 1], ['4826', 39], ['4176', 3], ['4993', 1]]
# ['4826', 39]
# Processing subfolder: 388
# [['4974', 7], ['4975', 8], ['L11', 1], ['4420', 17], ['4650', 1], ['4608', 4], ['4104', 7], ['4773', 1], ['4382', 6], ['4176', 1], ['L12', 1], ['4872', 2]]
# ['4420', 17]
# Processing subfolder: 389
# [['4416', 23], ['4845', 5], ['4979', 6], ['4589', 3], ['4805', 16], ['L9', 1], ['4161', 2]]
# ['4416', 23]
# Processing subfolder: 391
# [['4311', 1], ['4416', 54]]
# ['4416', 54]
# Processing subfolder: 392
# [['4590', 48], ['4781', 2]]
# ['4590', 48]
# Processing subfolder: 393
# [['4608', 4], ['4773', 1], ['4176', 2], ['4842', 2], ['4826', 43]]
# ['4826', 43]
# Processing subfolder: 394
# [['4176', 2], ['4420', 45], ['4608', 2], ['4872', 3]]
# ['4420', 45]
# Processing subfolder: 395
# [['4975', 35], ['4176', 2], ['4608', 2], ['4872', 2], ['4842', 2], ['4533', 3], ['4420', 4], ['4382', 2]]
# ['4975', 35]
# Processing subfolder: 396
# [['4525', 50]]
# ['4525', 50]
# Processing subfolder: 397
# [['4391', 2], ['4816', 12], ['4999', 7], ['L9', 1], ['4993', 28], ['4979', 2]]
# ['4993', 28]
# Processing subfolder: 398
# [['4599', 8], ['4382', 7], ['4311', 2], ['4420', 13], ['4581', 2], ['4176', 6], ['4816', 13], ['4987', 1]]
# ['4420', 13]
# Processing subfolder: 399
# [['A37', 54]]
# ['A37', 54]
# Processing subfolder: 4
# [['L9', 52]]
# ['L9', 52]
# Processing subfolder: 40
# [['4382', 2], ['4805', 48]]
# ['4805', 48]
# Processing subfolder: 400
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 401
# [['4872', 3], ['4805', 3], ['4826', 46]]
# ['4826', 46]
# Processing subfolder: 402
# []
# Processing subfolder: 403
# [['4413', 35], ['4525', 1], ['4420', 1], ['L3', 5], ['4161', 3], ['4541', 1], ['A37', 3]]
# ['4413', 35]
# Processing subfolder: 404
# [['L6', 1], ['1374', 51]]
# ['1374', 51]
# Processing subfolder: 409
# [['4413', 50]]
# ['4413', 50]
# Processing subfolder: 410
# [['4311', 7], ['4979', 1], ['3875', 4], ['4575', 39], ['L9', 1]]
# ['4575', 39]
# Processing subfolder: 412
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 413
# []
# Processing subfolder: 414
# [['A37', 7], ['4598', 7], ['4564', 8], ['4624', 18], ['4523', 1], ['4413', 6], ['4627', 2]]
# ['4624', 18]
# Processing subfolder: 415
# [['4413', 51]]
# ['4413', 51]
# Processing subfolder: 416
# [['3875', 1], ['L9', 1], ['4999', 50]]
# ['4999', 50]
# Processing subfolder: 417
# [['4979', 48], ['4367', 3]]
# ['4979', 48]
# Processing subfolder: 418
# [['4975', 22], ['4420', 2], ['4993', 3], ['L11', 3]]
# ['4975', 22]
# Processing subfolder: 419
# [['L11', 5], ['4975', 4], ['4420', 6], ['4993', 1], ['4525', 2], ['4598', 4], ['4416', 34]]
# ['4416', 34]
# Processing subfolder: 421
# [['4413', 50]]
# ['4413', 50]
# Processing subfolder: 422
# [['A10', 52]]
# ['A10', 52]
# Processing subfolder: 424
# [['4413', 50]]
# ['4413', 50]
# Processing subfolder: 425
# []
# Processing subfolder: 426
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 428
# [['4872', 38], ['4533', 1]]
# ['4872', 38]
# Processing subfolder: 43
# [['L5', 3], ['4420', 1], ['4554', 2], ['3875', 3], ['4548', 9], ['L1', 34]]
# ['L1', 34]
# Processing subfolder: 430
# [['4413', 50]]
# ['4413', 50]
# Processing subfolder: 436
# [['4382', 18], ['4350', 2], ['4872', 24], ['4773', 3], ['4816', 8], ['4599', 1], ['4975', 1]]
# ['4872', 24]
# Processing subfolder: 437
# [['4872', 46], ['4975', 4], ['4104', 1], ['4974', 5]]
# ['4872', 46]
# Processing subfolder: 440
# []
# Processing subfolder: 441
# [['4533', 1], ['4420', 1], ['4382', 2], ['4805', 46]]
# ['4805', 46]
# Processing subfolder: 444
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 447
# [['4805', 50]]
# ['4805', 50]
# Processing subfolder: 450
# [['4381', 49]]
# ['4381', 49]
# Processing subfolder: 454
# [['4993', 30]]
# ['4993', 30]
# Processing subfolder: 455
# [['4420', 2], ['4872', 1], ['4381', 46], ['5000', 3]]
# ['4381', 46]
# Processing subfolder: 456
# [['A10', 51], ['4872', 1]]
# ['A10', 51]
# Processing subfolder: 457
# [['3875', 1], ['4872', 10], ['4413', 41]]
# ['4413', 41]
# Processing subfolder: 458
# [['4993', 51], ['4413', 1]]
# ['4993', 51]
# Processing subfolder: 459
# []
# Processing subfolder: 46
# [['L11', 10], ['4990', 4], ['4993', 25], ['4773', 2]]
# ['4993', 25]
# Processing subfolder: 460
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 461
# [['4826', 50]]
# ['4826', 50]
# Processing subfolder: 462
# [['4350', 17], ['4104', 4], ['4872', 1], ['4805', 27], ['4413', 3]]
# ['4805', 27]
# Processing subfolder: 463
# []
# Processing subfolder: 465
# [['4533', 15], ['4872', 33], ['4176', 1], ['4420', 2], ['4975', 1]]
# ['4872', 33]
# Processing subfolder: 468
# [['4554', 1], ['4987', 1], ['4815', 50]]
# ['4815', 50]
# Processing subfolder: 469
# [['4533', 48], ['4635', 1], ['4826', 1]]
# ['4533', 48]
# Processing subfolder: 474
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 476
# []
# Processing subfolder: 478
# []
# Processing subfolder: 480
# [['4533', 38], ['4635', 12]]
# ['4533', 38]
# Processing subfolder: 481
# [['4872', 34], ['4420', 4], ['4628', 3], ['L12', 1], ['4773', 1], ['4993', 1], ['4533', 5], ['4176', 1]]
# ['4872', 34]
# Processing subfolder: 482
# []
# Processing subfolder: 484
# []
# Processing subfolder: 486
# [['4872', 37], ['4176', 1], ['4975', 1]]
# ['4872', 37]
# Processing subfolder: 490
# []
# Processing subfolder: 491
# [['L3', 36]]
# ['L3', 36]
# Processing subfolder: 492
# [['4533', 26], ['4635', 24]]
# ['4533', 26]
# Processing subfolder: 493
# [['4654', 1], ['4551', 1], ['4635', 1], ['4311', 1], ['4381', 5], ['L9', 11]]
# ['L9', 11]
# Processing subfolder: 494
# []
# Processing subfolder: 496
# [['4872', 1], ['4381', 43], ['4783', 5], ['4990', 1]]
# ['4381', 43]
# Processing subfolder: 5
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 500
# [['5000', 4], ['4816', 46]]
# ['4816', 46]
# Processing subfolder: 501
# [['4773', 3], ['4805', 48], ['4382', 1]]
# ['4805', 48]
# Processing subfolder: 502
# [['L1', 50]]
# ['L1', 50]
# Processing subfolder: 503
# []
# Processing subfolder: 504
# [['4816', 47], ['4826', 2], ['4350', 1], ['4872', 2]]
# ['4816', 47]
# Processing subfolder: 505
# []
# Processing subfolder: 506
# []
# Processing subfolder: 507
# []
# Processing subfolder: 509
# []
# Processing subfolder: 510
# [['4533', 1], ['unknown', 4], ['4816', 24], ['4748', 3]]
# ['4816', 24]
# Processing subfolder: 514
# [['L9', 8], ['4990', 1], ['4999', 43]]
# ['4999', 43]
# Processing subfolder: 519
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 520
# []
# Processing subfolder: 521
# []
# Processing subfolder: 522
# []
# Processing subfolder: 523
# []
# Processing subfolder: 524
# []
# Processing subfolder: 525
# []
# Processing subfolder: 526
# [['4590', 52]]
# ['4590', 52]
# Processing subfolder: 528
# [['4628', 45], ['4413', 3], ['4420', 2]]
# ['4628', 45]
# Processing subfolder: 529
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 53
# [['L6', 50]]
# ['L6', 50]
# Processing subfolder: 530
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 532
# []
# Processing subfolder: 534
# [['4990', 50]]
# ['4990', 50]
# Processing subfolder: 539
# [['4816', 50]]
# ['4816', 50]
# Processing subfolder: 540
# []
# Processing subfolder: 541
# []
# Processing subfolder: 543
# [['4781', 2], ['4307', 50]]
# ['4307', 50]
# Processing subfolder: 544
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 548
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 55
# [['4872', 51], ['4382', 1]]
# ['4872', 51]
# Processing subfolder: 550
# []
# Processing subfolder: 553
# [['4590', 52]]
# ['4590', 52]
# Processing subfolder: 554
# [['4872', 5], ['4533', 3], ['4420', 3], ['4826', 6], ['4773', 2], ['4993', 31]]
# ['4993', 31]
# Processing subfolder: 555
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 556
# [['4975', 6], ['4176', 7], ['4872', 3], ['4420', 7]]
# ['4176', 7]
# Processing subfolder: 557
# [['L5', 1], ['4856', 2], ['4413', 49]]
# ['4413', 49]
# Processing subfolder: 558
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 559
# [['L11', 1], ['4993', 49]]
# ['4993', 49]
# Processing subfolder: 56
# [['4979', 52]]
# ['4979', 52]
# Processing subfolder: 560
# [['4979', 48], ['4650', 2]]
# ['4979', 48]
# Processing subfolder: 561
# [['4420', 52]]
# ['4420', 52]
# Processing subfolder: 562
# [['L5', 50], ['4551', 2]]
# ['L5', 50]
# Processing subfolder: 565
# [['L6', 26], ['1374', 2]]
# ['L6', 26]
# Processing subfolder: 566
# []
# Processing subfolder: 57
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 58
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 59
# [['4307', 1], ['L5', 51]]
# ['L5', 51]
# Processing subfolder: 60
# []
# Processing subfolder: 61
# [['4628', 45], ['4548', 4], ['A10', 1]]
# ['4628', 45]
# Processing subfolder: 65
# [['4551', 58], ['4554', 2]]
# ['4551', 58]
# Processing subfolder: 66
# [['4856', 52]]
# ['4856', 52]
# Processing subfolder: 67
# []
# Processing subfolder: 68
# [['4872', 52]]
# ['4872', 52]
# Processing subfolder: 69
# [['4872', 51], ['4975', 1]]
# ['4872', 51]
# Processing subfolder: 7
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 70
# []
# Processing subfolder: 71
# []
# Processing subfolder: 72
# [['L5', 53]]
# ['L5', 53]
# Processing subfolder: 73
# [['4781', 2], ['A37', 50]]
# ['A37', 50]
# Processing subfolder: 76
# [['L3', 30], ['L9', 2]]
# ['L3', 30]
# Processing subfolder: 77
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 78
# []
# Processing subfolder: 79
# [['L3', 41], ['4413', 4]]
# ['L3', 41]
# Processing subfolder: 81
# [['unknown', 1], ['4845', 1], ['4979', 56], ['4650', 1]]
# ['4979', 56]
# Processing subfolder: 82
# [['L5', 2], ['4650', 1], ['A18', 1], ['3875', 14], ['L1', 4], ['4548', 20], ['4541', 1], ['4792', 2], ['4990', 1], ['unknown', 5], ['A37', 1]]
# ['4548', 20]
# Processing subfolder: 83
# [['4381', 50]]
# ['4381', 50]
# Processing subfolder: 85
# [['4993', 38], ['4872', 3], ['4104', 1], ['4773', 1], ['4533', 3], ['4420', 4]]
# ['4993', 38]
# Processing subfolder: 86
# []
# Processing subfolder: 87
# [['4381', 52]]
# ['4381', 52]
# Processing subfolder: 88
# [['4856', 52]]
# ['4856', 52]
# Processing subfolder: 90
# [['4554', 1], ['L1', 1], ['4525', 8], ['4993', 1], ['unknown', 2], ['4773', 25], ['4975', 1], ['4627', 1], ['4990', 3], ['4367', 6], ['L11', 1]]
# ['4773', 25]
# Processing subfolder: 91
# [['4783', 51], ['4413', 1]]
# ['4783', 51]
# Processing subfolder: 92
# []
# Processing subfolder: 93
# [['L7', 51], ['4575', 1]]
# ['L7', 51]
# Processing subfolder: 94
# []
# Processing subfolder: 95
# [['L5', 42]]
# ['L5', 42]
# Processing subfolder: 96
# []
# Processing subfolder: 97
# []
# Processing subfolder: 98
# [['4416', 5], ['4525', 12], ['L11', 2], ['4413', 31]]
# ['4413', 31]
# Processing subfolder: 99
# [['4815', 22], ['4548', 13], ['4538', 1], ['5000', 1], ['L1', 17]]
# ['4815', 22]
# finalized_pdf.csv is not a directory.
# frame_data.json is not a directory.
# missed_count.csv is not a directory.
# program_accuracy.csv is not a directory.
# Results saved to H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch002_Camera 002_E2/2025-12-24_0023_part 1/ConvNextV2_Arcface_Result.csv
# 0023_identification.mp4 is not a directory.
# Processing subfolder: 1
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 10
# [['L6', 45], ['5000', 6], ['A10', 1]]
# ['L6', 45]
# Processing subfolder: 104
# [['4781', 1], ['4413', 49]]
# ['4413', 49]
# Processing subfolder: 105
# [['4381', 52]]
# ['4381', 52]
# Processing subfolder: 11
# []
# Processing subfolder: 12
# []
# Processing subfolder: 121
# [['4361', 1], ['4990', 49]]
# ['4990', 49]
# Processing subfolder: 126
# []
# Processing subfolder: 127
# [['L11', 25]]
# ['L11', 25]
# Processing subfolder: 129
# [['L9', 1], ['L7', 51]]
# ['L7', 51]
# Processing subfolder: 13
# [['4993', 50], ['4608', 1]]
# ['4993', 50]
# Processing subfolder: 138
# [['1374', 52]]
# ['1374', 52]
# Processing subfolder: 14
# [['4416', 20], ['4654', 2], ['4538', 18], ['4554', 6], ['4420', 4]]
# ['4416', 20]
# Processing subfolder: 145
# [['4783', 1], ['4413', 1], ['L7', 50]]
# ['L7', 50]
# Processing subfolder: 148
# [['L7', 49], ['4525', 1], ['4628', 1]]
# ['L7', 49]
# Processing subfolder: 149
# [['4627', 50], ['4826', 2]]
# ['4627', 50]
# Processing subfolder: 15
# []
# Processing subfolder: 150
# [['4845', 46], ['4781', 6]]
# ['4845', 46]
# Processing subfolder: 151
# [['4990', 27]]
# ['4990', 27]
# Processing subfolder: 152
# [['4990', 50]]
# ['4990', 50]
# Processing subfolder: 154
# [['4627', 40], ['L5', 3], ['4381', 5], ['4990', 2]]
# ['4627', 40]
# Processing subfolder: 155
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 156
# [['4990', 2], ['4627', 1], ['4413', 47], ['4416', 2]]
# ['4413', 47]
# Processing subfolder: 157
# [['4845', 46]]
# ['4845', 46]
# Processing subfolder: 158
# [['4838', 1], ['4781', 1], ['A10', 25]]
# ['A10', 25]
# Processing subfolder: 159
# [['A10', 52]]
# ['A10', 52]
# Processing subfolder: 16
# [['4627', 1], ['4525', 1], ['4783', 3], ['4416', 4], ['4598', 1], ['5000', 1], ['4781', 28], ['A10', 13]]
# ['4781', 28]
# Processing subfolder: 160
# [['4773', 2], ['L3', 44], ['4826', 3], ['4104', 3]]
# ['L3', 44]
# Processing subfolder: 161
# [['4627', 50]]
# ['4627', 50]
# Processing subfolder: 162
# [['4856', 3], ['4845', 1], ['4654', 1], ['4416', 7], ['L11', 11]]
# ['L11', 11]
# Processing subfolder: 163
# []
# Processing subfolder: 164
# [['4872', 1], ['4974', 49], ['4975', 2]]
# ['4974', 49]
# Processing subfolder: 166
# [['4627', 43], ['4990', 2], ['4781', 2]]
# ['4627', 43]
# Processing subfolder: 167
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 168
# [['A10', 36], ['4567', 7], ['4548', 7]]
# ['A10', 36]
# Processing subfolder: 169
# [['A37', 36], ['4781', 12], ['4815', 2]]
# ['A37', 36]
# Processing subfolder: 17
# [['4538', 50]]
# ['4538', 50]
# Processing subfolder: 170
# [['4974', 47], ['4420', 4]]
# ['4974', 47]
# Processing subfolder: 171
# [['A10', 48], ['4554', 2], ['L1', 2]]
# ['A10', 48]
# Processing subfolder: 173
# [['4627', 52]]
# ['4627', 52]
# Processing subfolder: 174
# [['4382', 3], ['4872', 5], ['4420', 3], ['4773', 58], ['4990', 1]]
# ['4773', 58]
# Processing subfolder: 175
# [['4420', 1], ['4311', 1], ['4416', 57], ['4990', 1]]
# ['4416', 57]
# Processing subfolder: 176
# [['L9', 4], ['4650', 14], ['4608', 32]]
# ['4608', 32]
# Processing subfolder: 179
# [['4416', 50], ['9697', 4], ['4413', 1], ['4773', 2]]
# ['4416', 50]
# Processing subfolder: 180
# [['4551', 18], ['4635', 1], ['L5', 12], ['1374', 7], ['4608', 1], ['L12', 1], ['4654', 1], ['4548', 1], ['4307', 8], ['A18', 2]]
# ['4551', 18]
# Processing subfolder: 183
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 189
# [['4551', 48], ['4654', 1], ['L5', 1], ['L6', 1], ['L7', 1]]
# ['4551', 48]
# Processing subfolder: 191
# []
# Processing subfolder: 192
# [['4551', 50]]
# ['4551', 50]
# Processing subfolder: 194
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 196
# [['4872', 5], ['4816', 20], ['4805', 1]]
# ['4816', 20]
# Processing subfolder: 197
# [['A10', 52]]
# ['A10', 52]
# Processing subfolder: 199
# [['L12', 28], ['4416', 1], ['4773', 1], ['4382', 6], ['4872', 1], ['4311', 1], ['L11', 14]]
# ['L12', 28]
# Processing subfolder: 2
# [['4856', 52]]
# ['4856', 52]
# Processing subfolder: 20
# [['1374', 5], ['4654', 2], ['L6', 19]]
# ['L6', 19]
# Processing subfolder: 200
# [['4307', 51], ['4538', 1]]
# ['4307', 51]
# Processing subfolder: 201
# [['4551', 45], ['4635', 2]]
# ['4551', 45]
# Processing subfolder: 202
# [['unknown', 1], ['4773', 16], ['4382', 4], ['L7', 9], ['4872', 2], ['4533', 1], ['4781', 1], ['4999', 9], ['4567', 3], ['A10', 3], ['L9', 2]]
# ['4773', 16]
# Processing subfolder: 203
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 204
# [['4872', 37], ['4975', 13], ['4176', 1], ['4533', 1]]
# ['4872', 37]
# Processing subfolder: 205
# []
# Processing subfolder: 206
# [['4650', 1], ['L1', 1], ['4337', 1], ['4548', 49]]
# ['4548', 49]
# Processing subfolder: 207
# []
# Processing subfolder: 208
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 209
# [['L11', 43]]
# ['L11', 43]
# Processing subfolder: 21
# [['L1', 1], ['4575', 49]]
# ['4575', 49]
# Processing subfolder: 211
# [['4856', 13], ['4350', 6], ['unknown', 1], ['4990', 2], ['5000', 1], ['4416', 1], ['4311', 1], ['A10', 3], ['4567', 1]]
# ['4856', 13]
# Processing subfolder: 214
# [['4161', 52]]
# ['4161', 52]
# Processing subfolder: 218
# []
# Processing subfolder: 219
# []
# Processing subfolder: 22
# [['4979', 2], ['4990', 48]]
# ['4990', 48]
# Processing subfolder: 220
# [['4382', 3], ['4599', 1], ['4816', 48]]
# ['4816', 48]
# Processing subfolder: 221
# []
# Processing subfolder: 224
# [['4993', 3], ['4608', 42], ['4382', 6], ['4872', 1]]
# ['4608', 42]
# Processing subfolder: 225
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 23
# [['4990', 41]]
# ['4990', 41]
# Processing subfolder: 236
# []
# Processing subfolder: 239
# [['4533', 2], ['4382', 2], ['4816', 45]]
# ['4816', 45]
# Processing subfolder: 24
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 241
# [['4608', 48], ['4104', 4]]
# ['4608', 48]
# Processing subfolder: 244
# [['4176', 2], ['4533', 1], ['4845', 17], ['4781', 9], ['4979', 2], ['4856', 1], ['4635', 1], ['4391', 1], ['4608', 1], ['4990', 1], ['4420', 2], ['4993', 12]]
# ['4845', 17]
# Processing subfolder: 248
# [['4650', 6], ['3875', 7], ['4990', 2], ['L1', 35]]
# ['L1', 35]
# Processing subfolder: 257
# [['4856', 52]]
# ['4856', 52]
# Processing subfolder: 271
# [['4420', 48], ['4975', 4]]
# ['4420', 48]
# Processing subfolder: 273
# [['L9', 29], ['L7', 4], ['4627', 1]]
# ['L9', 29]
# Processing subfolder: 28
# [['4805', 50]]
# ['4805', 50]
# Processing subfolder: 280
# [['4548', 1], ['L1', 48], ['4990', 1]]
# ['L1', 48]
# Processing subfolder: 286
# [['4845', 46]]
# ['4845', 46]
# Processing subfolder: 287
# [['4999', 52]]
# ['4999', 52]
# Processing subfolder: 289
# [['4627', 42]]
# ['4627', 42]
# Processing subfolder: 29
# [['4538', 52]]
# ['4538', 52]
# Processing subfolder: 291
# [['4551', 52]]
# ['4551', 52]
# Processing subfolder: 293
# []
# Processing subfolder: 294
# []
# Processing subfolder: 295
# []
# Processing subfolder: 296
# []
# Processing subfolder: 297
# []
# Processing subfolder: 298
# []
# Processing subfolder: 299
# []
# Processing subfolder: 3
# [['L7', 52]]
# ['L7', 52]
# Processing subfolder: 30
# [['4416', 3], ['L1', 49]]
# ['L1', 49]
# Processing subfolder: 300
# []
# Processing subfolder: 302
# []
# Processing subfolder: 304
# []
# Processing subfolder: 308
# [['4826', 50]]
# ['4826', 50]
# Processing subfolder: 309
# [['4420', 11], ['4975', 23], ['4581', 6], ['4872', 7], ['4533', 4], ['4974', 1]]
# ['4975', 23]
# Processing subfolder: 31
# []
# Processing subfolder: 310
# [['4872', 20], ['4176', 1], ['4420', 27], ['4533', 1], ['L6', 2], ['4975', 1]]
# ['4420', 27]
# Processing subfolder: 312
# []
# Processing subfolder: 313
# [['4420', 2], ['4525', 1], ['4416', 49]]
# ['4416', 49]
# Processing subfolder: 314
# []
# Processing subfolder: 316
# [['4176', 4], ['4872', 16], ['4420', 32]]
# ['4420', 32]
# Processing subfolder: 317
# [['4872', 4], ['4176', 1], ['4826', 47]]
# ['4826', 47]
# Processing subfolder: 318
# [['4420', 2], ['4975', 37], ['4872', 12], ['4382', 1]]
# ['4975', 37]
# Processing subfolder: 319
# [['4538', 50]]
# ['4538', 50]
# Processing subfolder: 32
# [['L6', 37], ['4307', 1], ['4533', 9], ['1374', 1], ['4635', 2]]
# ['L6', 37]
# Processing subfolder: 320
# [['4307', 50]]
# ['4307', 50]
# Processing subfolder: 321
# [['4416', 50], ['4525', 2]]
# ['4416', 50]
# Processing subfolder: 322
# [['9697', 52]]
# ['9697', 52]
# Processing subfolder: 324
# [['4781', 2], ['4413', 13], ['4161', 8], ['4979', 8], ['4628', 4], ['4564', 6], ['4803', 2], ['4541', 3], ['4805', 1], ['4534', 3]]
# ['4413', 13]
# Processing subfolder: 326
# [['4575', 51], ['4816', 1]]
# ['4575', 51]
# Processing subfolder: 328
# [['A37', 33], ['4413', 1], ['4627', 1], ['4523', 3], ['4548', 1], ['4564', 11], ['4598', 1], ['4816', 1]]
# ['A37', 33]
# Processing subfolder: 33
# [['4872', 49], ['4975', 3]]
# ['4872', 49]
# Processing subfolder: 331
# [['4627', 1], ['4979', 22], ['4367', 22], ['4650', 5], ['4628', 2]]
# ['4979', 22]
# Processing subfolder: 34
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 342
# [['A18', 34], ['4628', 2], ['4548', 7], ['4525', 1], ['L1', 1]]
# ['A18', 34]
# Processing subfolder: 343
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 344
# [['4176', 3], ['4420', 1], ['4872', 37]]
# ['4872', 37]
# Processing subfolder: 345
# [['4872', 47], ['4842', 1], ['4975', 2]]
# ['4872', 47]
# Processing subfolder: 347
# [['4382', 3], ['4872', 4], ['4773', 38], ['9697', 1]]
# ['4773', 38]
# Processing subfolder: 348
# []
# Processing subfolder: 349
# [['L5', 33]]
# ['L5', 33]
# Processing subfolder: 35
# [['4979', 48]]
# ['4979', 48]
# Processing subfolder: 351
# []
# Processing subfolder: 352
# [['4416', 6], ['4311', 23], ['4990', 1], ['L12', 12], ['4598', 3], ['4783', 2], ['4856', 2], ['4567', 1], ['4161', 2]]
# ['4311', 23]
# Processing subfolder: 353
# []
# Processing subfolder: 357
# [['4792', 1], ['4161', 41], ['4176', 1], ['4872', 4], ['4420', 1], ['4416', 5]]
# ['4161', 41]
# Processing subfolder: 358
# [['4538', 42], ['4872', 4], ['4420', 2], ['L6', 2]]
# ['4538', 42]
# Processing subfolder: 359
# [['5000', 9], ['4872', 6], ['4176', 6], ['4527', 2], ['4307', 28], ['4533', 1]]
# ['4307', 28]
# Processing subfolder: 362
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 366
# [['4382', 25], ['4975', 1], ['4805', 8], ['4628', 1], ['4416', 14], ['L12', 3]]
# ['4382', 25]
# Processing subfolder: 369
# [['A18', 2], ['4551', 2], ['4416', 1], ['4654', 3], ['A10', 43]]
# ['A10', 43]
# Processing subfolder: 370
# [['4872', 17], ['4420', 18], ['4975', 5], ['4176', 5]]
# ['4420', 18]
# Processing subfolder: 371
# [['4551', 3], ['4654', 1], ['L3', 52]]
# ['L3', 52]
# ...
# Processing subfolder: 365
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 37
# []
# Processing subfolder: 377
# [['L12', 2], ['4382', 2], ['4805', 36]]
# ['4805', 36]
# Processing subfolder: 379
# []
# Processing subfolder: 38
# []
# Processing subfolder: 381
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 388
# [['4420', 7], ['4872', 1], ['4805', 27]]
# ['4805', 27]
# Processing subfolder: 39
# []
# Processing subfolder: 391
# [['4815', 34]]
# ['4815', 34]
# Processing subfolder: 4
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 41
# [['4654', 25], ['4551', 22], ['4538', 1], ['L1', 2]]
# ['4654', 25]
# Processing subfolder: 412
# [['4628', 3], ['A10', 20]]
# ['A10', 20]
# Processing subfolder: 42
# []
# Processing subfolder: 422
# [['4650', 1], ['4999', 51]]
# ['4999', 51]
# Processing subfolder: 430
# [['4551', 50]]
# ['4551', 50]
# Processing subfolder: 433
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 436
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 44
# []
# Processing subfolder: 454
# [['L12', 1], ['4382', 2], ['4816', 32]]
# ['4816', 32]
# Processing subfolder: 455
# [['L6', 35]]
# ['L6', 35]
# Processing subfolder: 456
# [['4420', 50]]
# ['4420', 50]
# Processing subfolder: 457
# []
# Processing subfolder: 458
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 459
# [['L1', 1], ['4781', 3], ['4307', 47]]
# ['4307', 47]
# Processing subfolder: 466
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 48
# []
# Processing subfolder: 5
# [['4575', 52]]
# ['4575', 52]
# Processing subfolder: 51
# []
# Processing subfolder: 52
# []
# Processing subfolder: 56
# [['4548', 51]]
# ['4548', 51]
# Processing subfolder: 58
# []
# Processing subfolder: 6
# [['4161', 52]]
# ['4161', 52]
# Processing subfolder: 66
# [['4979', 45], ['4548', 2], ['3875', 1], ['4624', 2]]
# ['4979', 45]
# Processing subfolder: 68
# [['4420', 1], ['4872', 99]]
# ['4872', 99]
# Processing subfolder: 7
# [['4815', 52]]
# ['4815', 52]
# Processing subfolder: 71
# []
# Processing subfolder: 72
# [['4826', 2], ['4979', 48]]
# ['4979', 48]
# Processing subfolder: 73
# [['4979', 2], ['4856', 48]]
# ['4856', 48]
# Processing subfolder: 76
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 8
# [['L11', 50]]
# ['L11', 50]
# Processing subfolder: 80
# [['4993', 49], ['4533', 1]]
# ['4993', 49]
# Processing subfolder: 9
# [['4551', 50]]
# ['4551', 50]
# Processing subfolder: 93
# [['4845', 4], ['4381', 24], ['4413', 19], ['L9', 1], ['4525', 1], ['4990', 1]]
# ['4381', 24]
# Processing subfolder: 95
# [['L5', 44], ['4554', 7], ['4307', 1]]
# ['L5', 44]
# Processing subfolder: 96
# [['4993', 52]]
# ['4993', 52]
# finalized_pdf.csv is not a directory.
# frame_data.json is not a directory.
# missed_count.csv is not a directory.
# program_accuracy.csv is not a directory.
# Results saved to H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch005_Camera 005_E2/2025-12-24_0023_part 1/ConvNextV2_Arcface_Result.csv
# 0023_identification.mp4 is not a directory.
# Processing subfolder: 1
# [['4627', 52]]
# ['4627', 52]
# Processing subfolder: 10
# [['L1', 8], ['4815', 25], ['4838', 2], ['4307', 15], ['L6', 2]]
# ['4815', 25]
# Processing subfolder: 105
# [['4554', 1], ['4979', 50], ['L7', 1]]
# ['4979', 50]
# Processing subfolder: 11
# [['4382', 3], ['4805', 47]]
# ['4805', 47]
# Processing subfolder: 111
# [['A18', 51]]
# ['A18', 51]
# Processing subfolder: 113
# []
# Processing subfolder: 114
# [['4525', 19], ['4803', 1], ['4413', 32]]
# ['4413', 32]
# Processing subfolder: 115
# [['4979', 1], ['4805', 1], ['4627', 28]]
# ['4627', 28]
# Processing subfolder: 12
# [['4842', 1], ['4872', 45], ['4575', 3], ['5000', 2]]
# ['4872', 45]
# Processing subfolder: 137
# []
# Processing subfolder: 140
# [['L7', 52]]
# ['L7', 52]
# Processing subfolder: 141
# [['4974', 10], ['4420', 21], ['unknown', 1], ['4842', 1], ['4872', 19], ['4975', 6]]
# ['4420', 21]
# Processing subfolder: 145
# [['4979', 11], ['4845', 40], ['4781', 1]]
# ['4845', 40]
# Processing subfolder: 154
# [['4773', 1], ['L11', 51]]
# ['L11', 51]
# Processing subfolder: 156
# [['L3', 1], ['A37', 51]]
# ['A37', 51]
# Processing subfolder: 157
# []
# Processing subfolder: 158
# []
# Processing subfolder: 159
# [['4872', 1], ['4176', 1], ['4382', 2], ['L12', 2], ['4533', 1], ['L11', 35], ['4773', 9]]
# ['L11', 35]
# Processing subfolder: 160
# []
# Processing subfolder: 161
# [['A10', 49], ['4979', 1]]
# ['A10', 49]
# Processing subfolder: 164
# [['A10', 49], ['3875', 1]]
# ['A10', 49]
# Processing subfolder: 170
# [['A37', 52]]
# ['A37', 52]
# Processing subfolder: 175
# [['4783', 52]]
# ['4783', 52]
# Processing subfolder: 176
# [['3875', 1], ['A10', 51]]
# ['A10', 51]
# Processing subfolder: 178
# [['A10', 52]]
# ['A10', 52]
# Processing subfolder: 187
# []
# Processing subfolder: 19
# [['4575', 52]]
# ['4575', 52]
# Processing subfolder: 195
# []
# Processing subfolder: 2
# [['4420', 98], ['4856', 1], ['4628', 1]]
# ['4420', 98]
# Processing subfolder: 203
# []
# Processing subfolder: 204
# [['4608', 1], ['4979', 42], ['4816', 1], ['4856', 11], ['4803', 1]]
# ['4979', 42]
# Processing subfolder: 209
# [['A10', 43], ['4816', 2], ['4838', 4], ['3875', 1]]
# ['A10', 43]
# Processing subfolder: 21
# [['4872', 49], ['L3', 1], ['4993', 1]]
# ['4872', 49]
# Processing subfolder: 211
# [['4872', 4], ['4979', 5], ['L12', 1], ['4816', 39], ['4805', 1]]
# ['4816', 39]
# Processing subfolder: 215
# [['4382', 2], ['4872', 2], ['4816', 48]]
# ['4816', 48]
# Processing subfolder: 216
# [['4805', 2], ['4872', 14], ['4773', 11], ['unknown', 5], ['4975', 1], ['4533', 2], ['L11', 15]]
# ['L11', 15]
# Processing subfolder: 217
# [['4748', 1], ['A18', 51]]
# ['A18', 51]
# Processing subfolder: 218
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 221
# []
# Processing subfolder: 222
# [['4975', 7], ['4872', 42], ['4420', 1]]
# ['4872', 42]
# Processing subfolder: 223
# [['9697', 1], ['4161', 51]]
# ['4161', 51]
# Processing subfolder: 224
# [['L9', 1], ['4548', 51]]
# ['4548', 51]
# Processing subfolder: 225
# [['4628', 1], ['4548', 60]]
# ['4548', 60]
# Processing subfolder: 227
# []
# Processing subfolder: 228
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 229
# [['L5', 52]]
# ['L5', 52]
# Processing subfolder: 233
# [['4816', 12], ['4993', 7], ['4773', 30], ['4608', 1]]
# ['4773', 30]
# Processing subfolder: 234
# []
# Processing subfolder: 235
# []
# Processing subfolder: 236
# [['4979', 29], ['4872', 4]]
# ['4979', 29]
# Processing subfolder: 237
# [['4816', 40], ['4979', 3], ['4805', 2], ['4872', 3], ['4420', 1], ['4975', 2], ['4781', 1]]
# ['4816', 40]
# Processing subfolder: 239
# [['L9', 3], ['L3', 45], ['4654', 2]]
# ['L3', 45]
# Processing subfolder: 241
# []
# Processing subfolder: 242
# []
# Processing subfolder: 252
# []
# Processing subfolder: 257
# []
# Processing subfolder: 259
# []
# Processing subfolder: 26
# [['4783', 50]]
# ['4783', 50]
# Processing subfolder: 260
# []
# Processing subfolder: 266
# []
# Processing subfolder: 267
# []
# Processing subfolder: 268
# []
# Processing subfolder: 269
# []
# Processing subfolder: 27
# [['4815', 33], ['4307', 8], ['4590', 9], ['L1', 1]]
# ['4815', 33]
# Processing subfolder: 270
# []
# Processing subfolder: 277
# [['A10', 31], ['4413', 2], ['L9', 2], ['4979', 2], ['4176', 1], ['4525', 1]]
# ['A10', 31]
# Processing subfolder: 278
# [['4627', 52]]
# ['4627', 52]
# Processing subfolder: 279
# [['L12', 50], ['4420', 2]]
# ['L12', 50]
# Processing subfolder: 28
# [['4993', 50]]
# ['4993', 50]
# Processing subfolder: 280
# [['4872', 52]]
# ['4872', 52]
# Processing subfolder: 281
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 287
# []
# Processing subfolder: 29
# []
# Processing subfolder: 296
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 298
# [['A18', 8], ['4548', 36], ['L1', 4], ['4525', 2]]
# ['4548', 36]
# Processing subfolder: 3
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 30
# []
# Processing subfolder: 303
# []
# Processing subfolder: 305
# [['4872', 6], ['4420', 1], ['4176', 1], ['4627', 44]]
# ['4627', 44]
# Processing subfolder: 306
# [['4872', 2], ['4420', 6], ['4816', 1], ['L11', 44]]
# ['L11', 44]
# Processing subfolder: 307
# [['4872', 4], ['L12', 2], ['4420', 46]]
# ['4420', 46]
# Processing subfolder: 31
# [['4548', 21], ['4554', 29], ['4781', 2]]
# ['4554', 29]
# Processing subfolder: 310
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 314
# [['4815', 51]]
# ['4815', 51]
# Processing subfolder: 317
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 320
# []
# Processing subfolder: 321
# [['4872', 1], ['4805', 45], ['4773', 4], ['4628', 2]]
# ['4805', 45]
# Processing subfolder: 329
# [['4815', 39]]
# ['4815', 39]
# Processing subfolder: 368
# []
# Processing subfolder: 369
# [['1374', 2], ['L6', 44]]
# ['L6', 44]
# Processing subfolder: 37
# [['4872', 2], ['4975', 1], ['4987', 2], ['4974', 33], ['4608', 8], ['4420', 5], ['4104', 1]]
# ['4974', 33]
# Processing subfolder: 373
# [['4307', 8], ['4635', 28]]
# ['4635', 28]
# Processing subfolder: 375
# [['4307', 52]]
# ['4307', 52]
# Processing subfolder: 39
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 392
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 393
# [['4987', 2], ['4816', 27]]
# ['4816', 27]
# Processing subfolder: 395
# [['4420', 48], ['4872', 4]]
# ['4420', 48]
# Processing subfolder: 399
# [['4382', 4], ['L12', 5], ['4816', 43]]
# ['4816', 43]
# Processing subfolder: 4
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 40
# [['4872', 42], ['4420', 9], ['4608', 1]]
# ['4872', 42]
# Processing subfolder: 418
# [['4816', 50], ['4176', 2]]
# ['4816', 50]
# Processing subfolder: 423
# [['3875', 1], ['4990', 51]]
# ['4990', 51]
# Processing subfolder: 424
# []
# Processing subfolder: 426
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 427
# [['L1', 1], ['4815', 4], ['4307', 45], ['L6', 1]]
# ['4307', 45]
# Processing subfolder: 46
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 49
# [['4872', 48], ['L3', 2]]
# ['4872', 48]
# Processing subfolder: 5
# [['4974', 52]]
# ['4974', 52]
# Processing subfolder: 56
# [['L1', 50]]
# ['L1', 50]
# Processing subfolder: 59
# []
# Processing subfolder: 6
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 60
# [['4979', 42]]
# ['4979', 42]
# Processing subfolder: 63
# []
# Processing subfolder: 68
# [['4990', 27], ['4567', 23]]
# ['4990', 27]
# Processing subfolder: 7
# [['4538', 49], ['4311', 1]]
# ['4538', 49]
# Processing subfolder: 75
# [['4993', 32], ['4608', 2], ['4773', 14], ['4533', 2]]
# ['4993', 32]
# Processing subfolder: 76
# [['4554', 3], ['L6', 1], ['L5', 17], ['4987', 3]]
# ['L5', 17]
# Processing subfolder: 77
# [['4815', 52]]
# ['4815', 52]
# Processing subfolder: 78
# [['4990', 2], ['4845', 1], ['4381', 13], ['4999', 33], ['unknown', 1]]
# ['4999', 33]
# Processing subfolder: 79
# [['4993', 52]]
# ['4993', 52]
# Processing subfolder: 8
# []
# Processing subfolder: 81
# []
# Processing subfolder: 84
# []
# Processing subfolder: 9
# [['4990', 1], ['4575', 51]]
# ['4575', 51]
# Processing subfolder: 92
# [['4420', 12], ['4974', 54], ['4975', 2], ['4842', 1], ['4872', 9], ['L12', 15], ['4104', 2], ['L3', 5]]
# ['4974', 54]
# Processing subfolder: 93
# [['L11', 46], ['4533', 4]]
# ['L11', 46]
# Processing subfolder: 94
# [['L1', 1], ['4990', 49]]
# ['4990', 49]
# Processing subfolder: 97
# []
# finalized_pdf.csv is not a directory.
# frame_data.json is not a directory.
# missed_count.csv is not a directory.
# program_accuracy.csv is not a directory.
# Results saved to H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch006_Camera 006_E2/2025-12-24_0023_part 1/ConvNextV2_Arcface_Result.csv
# 0023_identification.mp4 is not a directory.
# Processing subfolder: 1
# [['4805', 52]]
# ['4805', 52]
# Processing subfolder: 10
# [['L3', 48], ['4826', 2]]
# ['L3', 48]
# Processing subfolder: 100
# [['4872', 4], ['4420', 48]]
# ['4420', 48]
# Processing subfolder: 104
# [['4816', 2], ['3875', 2], ['L9', 1], ['4990', 46], ['9697', 1], ['4350', 4]]
# ['4990', 46]
# Processing subfolder: 105
# []
# Processing subfolder: 106
# [['4307', 33], ['4791', 2], ['1374', 8], ['4635', 6], ['4815', 4], ['4554', 1], ['L6', 2]]
# ['4307', 33]
# Processing subfolder: 12
# [['L3', 51], ['L1', 1]]
# ['L3', 51]
# Processing subfolder: 13
# [['4974', 50], ['4872', 35], ['4975', 15]]
# ['4974', 50]
# Processing subfolder: 14
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 15
# [['L1', 52]]
# ['L1', 52]
# Processing subfolder: 16
# [['4979', 52]]
# ['4979', 52]
# Processing subfolder: 18
# [['4826', 2], ['4872', 33], ['4842', 2], ['4420', 13], ['4993', 2]]
# ['4872', 33]
# Processing subfolder: 19
# [['5000', 1], ['4815', 51]]
# ['4815', 51]
# Processing subfolder: 2
# [['4979', 1], ['L1', 4], ['L5', 1], ['5000', 1], ['4650', 1], ['4575', 44]]
# ['4575', 44]
# Processing subfolder: 20
# [['4872', 3], ['4525', 34], ['L11', 4], ['4845', 9], ['4381', 2]]
# ['4525', 34]
# Processing subfolder: 21
# [['4974', 46], ['4872', 9]]
# ['4974', 46]
# Processing subfolder: 22
# [['L11', 52]]
# ['L11', 52]
# Processing subfolder: 25
# [['4990', 52]]
# ['4990', 52]
# Processing subfolder: 27
# [['A18', 52]]
# ['A18', 52]
# Processing subfolder: 29
# [['4773', 1], ['4627', 39], ['4979', 4], ['4805', 8]]
# ['4627', 39]
# Processing subfolder: 3
# [['L1', 4], ['4307', 47], ['4781', 1]]
# ['4307', 47]
# Processing subfolder: 30
# []
# Processing subfolder: 31
# []
# Processing subfolder: 32
# [['9697', 5], ['4413', 47]]
# ['4413', 47]
# Processing subfolder: 34
# [['4872', 20], ['4420', 22], ['L12', 1], ['4974', 9]]
# ['4420', 22]
# Processing subfolder: 35
# [['4773', 1], ['4533', 1], ['4391', 1], ['4845', 46], ['4826', 3]]
# ['4845', 46]
# Processing subfolder: 36
# [['4628', 2], ['L11', 50]]
# ['L11', 50]
# Processing subfolder: 37
# [['A37', 52]]
# ['A37', 52]
# Processing subfolder: 38
# [['A10', 50], ['4548', 1]]
# ['A10', 50]
# Processing subfolder: 39
# []
# Processing subfolder: 4
# [['4608', 5], ['4872', 27], ['L3', 3], ['L9', 11], ['3875', 2], ['L6', 2]]
# ['4872', 27]
# Processing subfolder: 46
# [['L3', 2], ['4773', 1], ['4872', 3], ['4816', 5], ['4792', 1], ['4627', 2], ['9697', 1], ['4979', 8], ['3875', 26], ['4783', 1]]
# ['3875', 26]
# Processing subfolder: 47
# [['5000', 1], ['A10', 51]]
# ['A10', 51]
# Processing subfolder: 59
# [['4805', 1], ['4554', 6], ['4987', 3], ['4307', 41], ['L6', 1]]
# ['4307', 41]
# Processing subfolder: 6
# [['4575', 21], ['5000', 6], ['4979', 1]]
# ['4575', 21]
# Processing subfolder: 62
# [['4816', 48], ['4979', 2], ['4872', 2]]
# ['4816', 48]
# Processing subfolder: 66
# [['4987', 1], ['4979', 1], ['L3', 4], ['4538', 2], ['L1', 3], ['A18', 41]]
# ['A18', 41]
# Processing subfolder: 67
# [['4872', 26], ['L12', 1], ['4420', 6], ['4773', 2], ['4533', 2], ['4805', 3], ['4842', 1], ['4382', 1], ['unknown', 8], ['L11', 6]]
# ['4872', 26]
# Processing subfolder: 68
# [['4161', 50], ['9697', 2]]
# ['4161', 50]
# Processing subfolder: 69
# [['4548', 52]]
# ['4548', 52]
# Processing subfolder: 7
# [['4872', 98], ['4420', 2]]
# ['4872', 98]
# Processing subfolder: 70
# [['4872', 1], ['4987', 1], ['L5', 50]]
# ['L5', 50]
# Processing subfolder: 71
# [['4872', 3], ['4608', 1], ['4816', 43], ['4805', 4], ['4420', 1]]
# ['4816', 43]
# Processing subfolder: 72
# [['4816', 48], ['4551', 3], ['4416', 1]]
# ['4816', 48]
# Processing subfolder: 73
# []
# Processing subfolder: 74
# []
# Processing subfolder: 75
# []
# Processing subfolder: 76
# []
# Processing subfolder: 77
# []
# Processing subfolder: 79
# []
# Processing subfolder: 80
# [['4538', 1], ['A10', 51]]
# ['A10', 51]
# Processing subfolder: 81
# [['A10', 52]]
# ['A10', 52]
# Processing subfolder: 82
# [['4999', 1], ['L1', 1], ['A18', 50]]
# ['A18', 50]
# Processing subfolder: 83
# [['4872', 52]]
# ['4872', 52]
# Processing subfolder: 84
# [['4816', 1], ['4567', 3], ['4990', 44], ['4381', 1], ['4624', 1]]
# ['4990', 44]
# Processing subfolder: 85
# []
# Processing subfolder: 86
# []
# Processing subfolder: 87
# [['4176', 1], ['4350', 1], ['4990', 50]]
# ['4990', 50]
# Processing subfolder: 88
# [['4815', 52]]
# ['4815', 52]
# Processing subfolder: 89
# [['4872', 1], ['4805', 49]]
# ['4805', 49]
# Processing subfolder: 9
# [['4974', 10], ['4872', 41]]
# ['4872', 41]
# Processing subfolder: 90
# [['4987', 1], ['L3', 2], ['L6', 1], ['4872', 1], ['unknown', 1], ['4608', 1], ['L11', 3], ['4990', 1], ['L5', 2], ['A10', 37]]
# ['A10', 37]
# Processing subfolder: 93
# [['4987', 3], ['L6', 49]]
# ['L6', 49]
# Processing subfolder: 94
# [['4554', 8], ['L3', 13], ['4987', 3], ['4838', 21], ['4307', 7]]
# ['4838', 21]
# Processing subfolder: 97
# [['L6', 52]]
# ['L6', 52]
# Processing subfolder: 98
# [['4872', 48], ['4420', 2]]
# ['4872', 48]
# Processing subfolder: 99
# [['4872', 4], ['4816', 44], ['4608', 4]]
# ['4816', 44]
# finalized_pdf.csv is not a directory.
# frame_data.json is not a directory.
# missed_count.csv is not a directory.
# program_accuracy.csv is not a directory.
# Results saved to H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch007_Camera 007_E2/2025-12-24_0023_part 1/ConvNextV2_Arcface_Result.csv

# %%
import csv
import os
from datetime import timedelta, datetime

FPS = 5
DAY_START = datetime.strptime("00:00:00", "%H:%M:%S")
NIGHT_START = datetime.strptime("22:00:00", "%H:%M:%S")
FIVE_HOURS = timedelta(hours=6)

def frame_to_time(frame_number):
    seconds = frame_number / FPS
    return timedelta(seconds=seconds)

def adjust_time_window(duration):
    if duration <= FIVE_HOURS:
        return DAY_START + duration
    else:
        return NIGHT_START + (duration - FIVE_HOURS)

def process_tracking_folder(base_dir, tracking_id):
    folder = os.path.join(base_dir, str(tracking_id))

    filenames = sorted(os.listdir(folder))

    #files = [entry.name for entry in entries if entry.is_file()]
            # Sort the files based on the numeric part of the filenames (assuming filenames contain numbers)
    filenames.sort(key=lambda x: int(x.split('_')[0]), reverse=False)
    #print(filenames[0])
    #print(filenames[-1])
    try:

        start_frame = int(filenames[0].split("_")[2])
        end_frame = int(filenames[-1].split("_")[2])
    except Exception as ex:
        print(filenames[0])
        raise ex
    #print(start_frame, end_frame, ' start : end frame for tracking id ', tracking_id)
    #print(start_frame, end_frame, ' start end frame for tracking id ', tracking_id)
    start_time = adjust_time_window(frame_to_time(start_frame))
    end_time = adjust_time_window(frame_to_time(end_frame))

    duration = end_time - start_time
    return start_time, end_time, duration

def process_csv(csv_path, base_dir, output_path):
    csv_path = base_dir + csv_path
    output_path = base_dir + output_path
    with open(csv_path, newline='') as f:
        reader = csv.DictReader(f)
        rows = list(reader)

    results = []

    for row in rows:
        tracking_id = row["TrackingID"]
        cattle_raw = row["Cattle ID"]

        # extract GT ID from list format "['1234', 12]"
        gt_id = cattle_raw

        # predicted id = gt id (your requirement)
        predicted_id = gt_id

        start_time, end_time, duration = process_tracking_folder(base_dir, tracking_id)

        results.append({
            "TrackingID": tracking_id,
            "Ground-Truth": gt_id,
            "Predicted ID": predicted_id,
            "StartTime": start_time.strftime("%H:%M:%S"),
            "EndTime": end_time.strftime("%H:%M:%S"),
            "Duration": str(duration)
        })

    # write output CSV
    with open(output_path, "w", newline='') as f:
        writer = csv.DictWriter(
            f, 
            fieldnames=["TrackingID", "Ground-Truth", "Predicted ID", "StartTime", "EndTime", "Duration"]
        )
        writer.writeheader()
        writer.writerows(results)

    print("Done:", output_path)


# base_dir = r'H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1'
# cameras = [
#     '/Ch001_Camera 001_E2/2025-12-26_0023_part 2/',
#     #  '/Ch002_Camera 002_E2/2025-12-26_0023_part 1/',
#     #  '/Ch003_Camera 003_E2/2025-12-26_0023_part 1/',
#     # '/Ch004_Camera 004_E2/2025-12-26_0023_part 1/',
#     #  '/Ch005_Camera 005_E2/2025-12-26_0023_part 1/',
#     #  '/Ch006_Camera 006_E2/2025-12-26_0023_part 1/',
#     #  '/Ch007_Camera 007_E2/2025-12-26_0023_part 1/',
#     ]
#base_dir = r'E:\Output\runs\KUNNEPPU_identification\EF_vector 8 Jan 2026\KNP\Base_rtx8000_December_2025_20000_v2'
base_dir = r'H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1'
cameras = [
    '/Ch001_Camera 001_E2/2025-12-24_0023_part 1/',
     '/Ch002_Camera 002_E2/2025-12-24_0023_part 1/',
     '/Ch003_Camera 003_E2/2025-12-24_0023_part 1/',
    '/Ch004_Camera 004_E2/2025-12-24_0023_part 1/',
     '/Ch005_Camera 005_E2/2025-12-24_0023_part 1/',
     '/Ch006_Camera 006_E2/2025-12-24_0023_part 1/',
     '/Ch007_Camera 007_E2/2025-12-24_0023_part 1/',
    ]

csv_path = "ConvNextV2_Arcface_Result.csv"
output_path = "ConvNextV2_Arcface_Result.csv"
for camera in cameras:
    camName = camera.split('/')[1].split(' ')[1]
    output_path = f"{camName}_ConvNextV2_Arcface_Result.csv"
    #print("Processing camera: ", output_path)
    process_csv(csv_path, base_dir + camera, output_path)
# Out:
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch001_Camera 001_E2/2025-12-24_0023_part 1/001_E2_ConvNextV2_Arcface_Result.csv
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch002_Camera 002_E2/2025-12-24_0023_part 1/002_E2_ConvNextV2_Arcface_Result.csv
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch003_Camera 003_E2/2025-12-24_0023_part 1/003_E2_ConvNextV2_Arcface_Result.csv
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch004_Camera 004_E2/2025-12-24_0023_part 1/004_E2_ConvNextV2_Arcface_Result.csv
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch005_Camera 005_E2/2025-12-24_0023_part 1/005_E2_ConvNextV2_Arcface_Result.csv
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch006_Camera 006_E2/2025-12-24_0023_part 1/006_E2_ConvNextV2_Arcface_Result.csv
# Done: H:\Output\runs\KUNNEPPU_identification\ConvNext_ArcFace 22 Jan 2026\KNP\Base_rtx8000_10_August_2025_20000_v1/Ch007_Camera 007_E2/2025-12-24_0023_part 1/007_E2_ConvNextV2_Arcface_Result.csv

# %%
resultToCsv(result)

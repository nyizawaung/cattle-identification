# %%
# train_and_proto.py
import os
import json
from pathlib import Path
from collections import defaultdict, Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score
from tqdm import tqdm
import timm
from helpers.helper import Helper
from torch.optim.lr_scheduler import CosineAnnealingLR
from PIL import Image
from datetime import datetime
import pandas as pd

class ProtoInfer:
    def __init__(self, model, device, proto_ckpt_path, class_mapping_path=None):
        """
        class_mapping_path: path to class_mappings.json (optional)
        Supports:
          - dict index->name  (keys int or numeric strings)
          - list              (index->name)
          - dict protoLabel->name (keys are strings that match checkpoint proto_labels)
        """
        self.model = model.eval().to(device)
        self.device = device
        ckpt = torch.load(proto_ckpt_path, map_location=device)

        self.prototypes  = ckpt["prototypes"].to(device)   # [K,D] L2-normalized
        self.proto_labels = ckpt["proto_labels"]           # list[str]
        self.tau = float(ckpt["tau"])
        emb_dim = ckpt.get("embedding_dim", None)

        if emb_dim is not None and self.prototypes.shape[1] != emb_dim:
            raise ValueError(
                f"Embedding dim mismatch: ckpt={emb_dim}, prototypes D={self.prototypes.shape[1]}"
            )

        # ---- Load optional class mapping
        self.idx_to_name = None         # list or dict[int]->str
        self.label_to_name = None       # dict[str]->str

        if class_mapping_path is not None:
            with open(class_mapping_path, "r", encoding="utf-8") as f:
                mapping = json.load(f)

            # list -> index mapping
            if isinstance(mapping, list):
                self.idx_to_name = list(mapping)

            # dict -> either index->name or protoLabel->name
            elif isinstance(mapping, dict):
                # detect if keys are index-like (ints or numeric strings)
                def _is_int_like(k):
                    if isinstance(k, int): return True
                    if isinstance(k, str) and k.isdigit(): return True
                    return False

                if all(_is_int_like(k) for k in mapping.keys()):
                    # build int-keyed dict (normalize str keys -> int)
                    self.idx_to_name = {int(k): v for k, v in mapping.items()}
                else:
                    # assume keys are proto label strings
                    self.label_to_name = dict(mapping)

        # Precompute a set for quick membership
        self._have_idx_map = self.idx_to_name is not None
        self._have_lbl_map = self.label_to_name is not None

    @torch.no_grad()
    def predict_stack(self, images_tensors, tau=None):
        """
        images_tensors: list[Tensor[C,H,W]] transformed like val_transform
        returns: list[[class_name, count], ...] (includes 'unknown')
        """
        if tau is None:
            tau = self.tau

        x = torch.stack(images_tensors).to(self.device)  # [B,C,H,W]
        feats = get_embeddings(self.model, x)            # [B,D]
        sims  = feats @ self.prototypes.T                # [B,K]
        max_sims, idxs = sims.max(dim=1)

        labels = []
        for s, i in zip(max_sims.tolist(), idxs.tolist()):
            if s >= tau:
                # try index mapping first
                if self._have_idx_map and i in self.idx_to_name:
                    name = self.idx_to_name[i]
                else:
                    # try proto-label mapping
                    proto_lbl = self.proto_labels[i]
                    if self._have_lbl_map and proto_lbl in self.label_to_name:
                        name = self.label_to_name[proto_lbl]
                    else:
                        # fallback to original proto label
                        name = proto_lbl
                labels.append(name)
            else:
                labels.append("unknown")

        counts = Counter(labels)
        return [[k, v] for k, v in counts.items()]


# =========================
# EMBEDDINGS / PROTOTYPES
# =========================
@torch.no_grad()
def get_embeddings(model, x):
    """
    Get L2-normalized pre-logits embeddings from ConvNeXtV2.
    timm convnextv2: forward_features -> forward_head(pre_logits=True).
    """
    feats = model.forward_features(x)                  # pre-classifier features
    emb  = model.forward_head(feats, pre_logits=True)  # pooled pre-logits
    return F.normalize(emb, dim=1)

# %%
import random
import cv2
import numpy as np

class CATTLE_IDENTIFICATION():

    data_transforms = {
        'train': transforms.Compose([
        #    transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(0.2),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'validation': transforms.Compose([
        #   transforms.Resize(256),
        #   transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }
    def get_files_from_folder_scan_sort(self,path, limitX=20):
    # Use os.scandir() for faster directory scanning
        with os.scandir(path) as entries:
        # Collect all filenames into a list
            files = [entry.name for entry in entries if entry.is_file()]
            
            # Sort the files based on the numeric part of the filenames (assuming filenames contain numbers)
            files.sort(key=lambda x: int(x.split('_')[0]), reverse=False)  # Adjust as needed for your filenames
            
            # Return the top 'limitX' files
            return files [:limitX]
    
    def enhance_ir_fast(self,frame_bgr, *,
                        bilateral_d=7, bilateral_sigma_color=35, bilateral_sigma_space=35,
                        clahe_clip=2.0, clahe_tile=8,
                        unsharp_sigma=1.2, unsharp_amount=0.9):
        # Enable OpenCV CPU optimizations
        cv2.setUseOptimized(True)
        cv2.setNumThreads(0)  # let OpenCV decide (or set to your core count)

        # --- Work in YCrCb so we touch only luminance ---
        ycrcb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2YCrCb)
        Y, Cr, Cb = cv2.split(ycrcb)

        # --- Fast denoise on Y (bilateral) ---
        # ~10–30x faster than NLM for typical params
        Y = cv2.bilateralFilter(Y, d=bilateral_d,
                                sigmaColor=bilateral_sigma_color,
                                sigmaSpace=bilateral_sigma_space)

        # Optional: if you have ximgproc, guided filter is even faster/cleaner on edges
        # from cv2.ximgproc import guidedFilter
        # Y = guidedFilter(guide=Y, src=Y, radius=4, eps=1e-4)

        # --- Local contrast (CLAHE) on Y ---
        clahe = cv2.createCLAHE(clipLimit=clahe_clip,
                                tileGridSize=(clahe_tile, clahe_tile))
        Y = clahe.apply(Y)

        # --- Merge back to color ---
        ycrcb = cv2.merge([Y, Cr, Cb])
        out = cv2.cvtColor(ycrcb, cv2.COLOR_YCrCb2BGR)

        # --- Unsharp mask (Gaussian is separable, very fast on CPU) ---
        blur = cv2.GaussianBlur(out, (0, 0), unsharp_sigma)
        out = cv2.addWeighted(out, 1.0 + unsharp_amount, blur, -unsharp_amount, 0)

        return out
    

    def unsharp_mask(self, bgr, radius=1.4, amount=1.0):
        blurred = cv2.GaussianBlur(bgr, (0,0), radius)
        sharp = cv2.addWeighted(bgr, 1+amount, blurred, -amount, 0)
        return np.clip(sharp, 0, 255).astype(np.uint8)

    def apply_clahe_ycrcb(self, bgr, clip=2.5, tile=8):
        ycrcb = cv2.cvtColor(bgr, cv2.COLOR_BGR2YCrCb)
        y, cr, cb = cv2.split(ycrcb)
        clahe = cv2.createCLAHE(clipLimit=clip, tileGridSize=(tile, tile))
        y2 = clahe.apply(y)
        merged = cv2.merge([y2, cr, cb])
        return cv2.cvtColor(merged, cv2.COLOR_YCrCb2BGR)

    def predict_stack_cattle_id(self, images, threshold=0.85):
        """
        Predict cattle IDs from a stack of images.
        
        Args:
            images: List of PIL Images or numpy arrays
            threshold: Confidence threshold for predictions
        
        Returns:
            List of [class_name, count] pairs for predictions above threshold
        """
        self.model.eval()

        # Preprocess all images
        #processed_images = [self.preprocess_image(img) for img in images]
        
        # Stack images into a single tensor
        image_tensor = torch.stack(images).to(self.device)

        with torch.no_grad():
            # Get model predictions
            outputs = self.model(image_tensor)
            probabilities = torch.softmax(outputs, dim=1)
            max_probs, preds = torch.max(probabilities, 1)

            # Filter predictions based on threshold
            filtered_classes = [
                self.class_names[str(pred.item())] 
                for pred, prob in zip(preds, max_probs) 
                if prob.item() >= threshold
            ]

            # Count occurrences of filtered classes
            class_counts = Counter(filtered_classes)
            filtered_counts = [[key, count] for key, count in class_counts.items()]

        return filtered_counts

    def predict_stack_cattle_id_conf(self, images, threshold=0.7):
        """
        Predict cattle IDs from a stack of images.

        Args:
            images: List of preprocessed torch tensors
            threshold: Confidence threshold for filtering final results

        Returns:
            filtered_counts: List of [class_name, count] pairs for predictions above threshold
            predictions: List of [class_name, confidence_score] for each image
        """
        self.model.eval()

        # Stack images into a single tensor
        image_tensor = torch.stack(images).to(self.device)

        with torch.no_grad():
            outputs = self.model(image_tensor)
            probabilities = torch.softmax(outputs, dim=1)
            max_probs, preds = torch.max(probabilities, 1)

            predictions = []
            filtered_classes = []

            for pred, prob in zip(preds, max_probs):
                class_name = self.class_names[str(pred.item())]
                confidence = prob.item()
                predictions.append([class_name, confidence])
                if confidence >= threshold:
                    filtered_classes.append(class_name)

            # Count occurrences of filtered classes
            class_counts = Counter(filtered_classes)
            filtered_counts = [[key, count] for key, count in class_counts.items()]

        print("Predictions:", predictions)

        return filtered_counts

    def _load_model(classLen, model_path,device):
        # Create model architecture
        # model = timm.create_model("tf_efficientnetv2_s", pretrained=False, num_classes=classLen)
        # model.load_state_dict(torch.load(model_path, map_location=device))
        # model.eval()
        
        model = timm.create_model('convnextv2_base.fcmae_ft_in22k_in1k', pretrained=False, num_classes=classLen)
         # Load the trained weights
        # torch.load handles map_location
        state_dict = torch.load(model_path, map_location=device)

        # Now load into model
        model.load_state_dict(state_dict)

        # model.load_state_dict(torch.load(model_path, map_location=device))
        # model.to(device)
        # model.eval()
        
        
        return model.to(device)

    def _load_model_resnet(classLen, model_path,device):
        # Create model architecture
        # model = timm.create_model('resnet101', pretrained=False)
        # # model.fc = nn.Sequential(
        # #     nn.Linear(model.fc.in_features, 512),
        # #     nn.ReLU(),
        # #     nn.Dropout(0.3),
        # #     nn.Linear(512, classLen)
        # # )
        model = timm.create_model('resnet101', pretrained=False, num_classes=classLen)
        state = torch.load(model_path, map_location=device)  # handles CPU/GPU safely
        model.load_state_dict(state, strict=True)
        model.eval()

        # Load trained weights
        model.load_state_dict(torch.load(model_path))
        model.eval()
        return model.to(device)


    SAVE_PATH = Path("identification_models_KNP") / "KNP_CONVNEXT_Nighttime_01"
    #SAVE_PATH = Path("identification_models_KNP") / "KNP_CONVNEXT_Gray_03"
    #SAVE_PATH = Path("identification_models_Sumi") / "SUMI_CONVNEXT_2_03"
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    class_mapping_path = f'{SAVE_PATH}\\class_mappings.json'
    # Load model + weights
    NUM_CLASSES = len(json.load(open(SAVE_PATH / "class_mappings.json")))  # dynamic
    model = timm.create_model('convnextv2_base.fcmae_ft_in22k_in1k',
                            pretrained=False, num_classes=NUM_CLASSES).to(device)
    model.load_state_dict(torch.load(SAVE_PATH / "last_model.pth", map_location=device))
    model.eval()

    infer = ProtoInfer(model, device, proto_ckpt_path=SAVE_PATH / "prototypes.pt", class_mapping_path=class_mapping_path )

    val_transform = transforms.Compose([
        #transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                            [0.229, 0.224, 0.225]),
    ])

    def batch_identification(self,save_dir,tracking_id,FORCE_MISSED_DETECTION = False,path = None, batch_size = 50, showCon = False):
        start_time = datetime.now()
        
        save_path = path
        #global batch_size 
        if path is None:
            save_path = f"{save_dir}//{tracking_id}"
        
        images = self.get_files_from_folder_scan_sort(save_path,batch_size)
        if len(images) < 20:
            return []
        stacked_images = []
        
        for image in images:
            #if counter < 1:
                #break
            #print(image)
            img_path = os.path.join(save_path, image)
            frame = cv2.imread(img_path)
            #predict_cattle_id(frame)
            # Ensure the image is in RGB format
            #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = self.apply_clahe_ycrcb(frame, clip=2.5, tile=8)  #B
            frame = self.unsharp_mask(frame, radius=1.4, amount=1.0)  #B

            # a = cv2.fastNlMeansDenoisingColored(frame, None, h=5, hColor=5, templateWindowSize=7, searchWindowSize=21)
            # a = self.apply_clahe_ycrcb(a, clip=2.0, tile=8)
            # a = self.unsharp_mask(a, radius=1.2, amount=0.9)
            #frame = self.enhance_ir_fast(frame)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # === Random mid-grey background replacement ===
            # lower_black = np.array([0, 0, 0], dtype=np.uint8)
            # upper_black = np.array([5, 5, 5], dtype=np.uint8)
            # grey_val = random.randint(110, 160)  # random shade
            # random_grey = (grey_val, grey_val, grey_val)  # BGR
            # mask_black = cv2.inRange(frame, lower_black, upper_black)
            # frame[mask_black > 0] = random_grey
            # ==============================================
            # Preprocess the image using the defined transforms
            input_tensor = self.data_transforms['validation'](frame).unsqueeze(0)  # Add batch dimension
            input_tensor = input_tensor.to(self.device)

            # Append the processed image tensor to the list
            stacked_images.append(input_tensor[0])  # Append the first element to keep it as (C, H, W)
            #counter -= 1
        
        # Call predict_stack_cattle_id with the stacked_images
        #return self.predict_stack_cattle_id(stacked_images)
        #if showCon:
        #   return self.predict_stack_cattle_id_conf(stacked_images)
        return self.infer.predict_stack(stacked_images,0.3)
        #return self.predict_by_arcface_batch(stacked_images)
    #model = _load_model_resnet(len(class_names),identification_model_path,device)
    #model = _load_arcface_model(len(class_names),identification_model_path,device)
    
    #print(class_names)
begin_identification = CATTLE_IDENTIFICATION()

#identification_model_path = "identification_model|s\\resnet50V5\\best_model.pth" 
#model = _load_model(len(class_names),identification_model_path,device)

# %%
begin_identification.batch_identification(r'E:\Output\runs\KUNNEPPU_identification\KNP_Merge_and_Batch_identification\29 Oct Report 2025\reuse tetris_Sumiyoshi-44\Base_rtx8000_10_August_2025_20000_v1\testris_Ch003_Camera 003_E2\2025-10-11_0023_part 2',
    "326", batch_size = 100,showCon = True)
#begin_identification.batch_identification(r'G:\Output\runs\KUNNEPPU_identification\KNP_Merge_and_Batch_identification\1 Sept Report 2025\reuse tetris_Sumiyoshi-44\Base_rtx8000_June_15000_v2\testris_Ch007_Camera 007_E2\2025-08-27_0514_part 2',"2", batch_size = 100)
# Out:
# [['4783', 5],
#  ['4413', 2],
#  ['4381', 1],
#  ['4598', 57],
#  ['4999', 3],
#  ['3875', 31],
#  ['4548', 1]]

# %%
path = r'G:\Output\runs\KUNNEPPU_identification\KNP_Merge_and_Batch_identification\IR collect Oct Report 2025\reuse tetris_Sumiyoshi-44\Base_rtx8000_10_August_2025_20000_v1\testris_Ch004_Camera 004_E2\2025-10-14_0023_part 1'
#path = r'E:\Output\runs\KUNNEPPU_identification\KNP_Merge_and_Batch_identification\26 Sept Report 2025\reuse tetris_Sumiyoshi-44\Base_rtx8000_10_August_2025_20000_v1\testris_Ch005_KP-FHDD-4-05\2025-09-20_0514_part 27'
result = []
for subfolder in os.listdir(path):
    subfolder_path = os.path.join(path, subfolder)
    if os.path.isdir(subfolder_path):
        # Process each subfolder
        print(f"Processing subfolder: {subfolder}")
        # Call your function here with the subfolder path
        #begin_identification.batch_identification(subfolder_path)
        #break
        try:

            batch_result = begin_identification.batch_identification(path,subfolder,batch_size = 100)
            print(batch_result)
            if(len(batch_result)>0):
                maxResult = max(batch_result,key=lambda x:x[1])
                print(maxResult)
                result.append([subfolder,maxResult]) 

        except Exception as e:
            print(f"Error processing subfolder {subfolder}: {e}")
    else:
        print(f"{subfolder} is not a directory.")

def resultToCsv(result):
    # Create a DataFrame from the result list
    df = pd.DataFrame(result, columns=['TrackingID', 'Cattle ID'])
    
    # Save the DataFrame to a CSV file
    
    csv_path = os.path.join(path, 'manual_result_feature.csv')
    df.to_csv(csv_path, index=False)
    
    print(f"Results saved to {csv_path}")


resultToCsv(result)
# Out:
# 0023_identification.mp4 is not a directory.
# Processing subfolder: 1
# [['4533', 75], ['4842', 25]]
# ['4533', 75]
# Processing subfolder: 10
# []
# Processing subfolder: 100
# []
# Processing subfolder: 1000
# [['4783', 29], ['4367', 1], ['4838', 1], ['4350', 1]]
# ['4783', 29]
# Processing subfolder: 1001
# [['4815', 1], ['4635', 5], ['4987', 50], ['4554', 3], ['4548', 37], ['4527', 1], ['4142', 2], ['4551', 1]]
# ['4987', 50]
# Processing subfolder: 1005
# [['4142', 21], ['4815', 10], ['4527', 12], ['4548', 52], ['4553', 5]]
# ['4548', 52]
# Processing subfolder: 1007
# []
# Processing subfolder: 1008
# [['1374', 99], ['4635', 1]]
# ['1374', 99]
# Processing subfolder: 101
# []
# Processing subfolder: 1017
# [['4826', 6], ['4816', 2], ['4161', 16], ['4598', 30], ['4628', 1], ['4635', 1], ['4853', 1], ['9697', 1]]
# ['4598', 30]
# Processing subfolder: 1018
# []
# Processing subfolder: 102
# []
# Processing subfolder: 1020
# []
# Processing subfolder: 1021
# []
# Processing subfolder: 1022
# []
# Processing subfolder: 1023
# []
# Processing subfolder: 1024
# []
# Processing subfolder: 1025
# []
# Processing subfolder: 1026
# []
# Processing subfolder: 1028
# [['4815', 14], ['4635', 1], ['4142', 7], ['4987', 1], ['4548', 3]]
# ['4815', 14]
# Processing subfolder: 1029
# []
# Processing subfolder: 1030
# [['4999', 1], ['4142', 1], ['4548', 98]]
# ['4548', 98]
# Processing subfolder: 1033
# [['1374', 18], ['4815', 7], ['4142', 2], ['4554', 1], ['4635', 2], ['4533', 3], ['4987', 1]]
# ['1374', 18]
# Processing subfolder: 1034
# []
# Processing subfolder: 1035
# []
# Processing subfolder: 1037
# [['4748', 1], ['4541', 1], ['4142', 5], ['4548', 36], ['4815', 2], ['4553', 11], ['4781', 1], ['4999', 43]]
# ['4999', 43]
# Processing subfolder: 1038
# []
# Processing subfolder: 104
# []
# Processing subfolder: 1041
# []
# Processing subfolder: 1044
# []
# Processing subfolder: 1045
# [['4999', 1], ['4783', 98], ['4627', 1]]
# ['4783', 98]
# Processing subfolder: 1046
# [['4635', 6], ['1374', 14]]
# ['1374', 14]
# Processing subfolder: 1048
# []
# Processing subfolder: 1055
# []
# Processing subfolder: 1056
# []
# Processing subfolder: 1057
# [['4842', 1], ['4783', 99]]
# ['4783', 99]
# Processing subfolder: 1058
# []
# Processing subfolder: 1059
# []
# Processing subfolder: 106
# []
# Processing subfolder: 1061
# []
# Processing subfolder: 1069
# []
# Processing subfolder: 1070
# [['4635', 4], ['1374', 64]]
# ['1374', 64]
# Processing subfolder: 1073
# []
# Processing subfolder: 1074
# []
# Processing subfolder: 1075
# []
# Processing subfolder: 1077
# []
# Processing subfolder: 1078
# []
# Processing subfolder: 1079
# []
# Processing subfolder: 108
# []
# Processing subfolder: 1080
# []
# Processing subfolder: 1081
# []
# Processing subfolder: 1082
# [['4142', 2], ['1374', 2], ['4627', 1], ['4635', 13], ['4581', 1], ['4987', 5], ['4382', 1], ['4564', 1], ['4554', 1], ['4993', 1]]
# ['4635', 13]
# Processing subfolder: 1084
# []
# Processing subfolder: 1093
# [['1374', 27], ['4635', 10]]
# ['1374', 27]
# Processing subfolder: 1096
# []
# Processing subfolder: 1097
# []
# Processing subfolder: 1098
# [['4142', 2], ['4548', 5], ['4527', 6], ['4553', 1], ['4538', 1], ['4554', 1], ['4815', 1], ['4635', 3]]
# ['4527', 6]
# Processing subfolder: 1099
# []
# Processing subfolder: 11
# [['4391', 8], ['4104', 13], ['4420', 1], ['4533', 3], ['4872', 32], ['4776', 42], ['4816', 1]]
# ['4776', 42]
# Processing subfolder: 1103
# [['4803', 1], ['4816', 3], ['4826', 9], ['4564', 1], ['4391', 9], ['4523', 1], ['4382', 1]]
# ['4826', 9]
# Processing subfolder: 1105
# []
# Processing subfolder: 1106
# []
# Processing subfolder: 1107
# [['4635', 3], ['4533', 10], ['4987', 1], ['4382', 4], ['4815', 4], ['4551', 2], ['4391', 3], ['4842', 1], ['4367', 1], ['4381', 69], ['4532', 2]]
# ['4381', 69]
# Processing subfolder: 1108
# [['4826', 18], ['4564', 2], ['4783', 1], ['4142', 2], ['4993', 1], ['4974', 1], ['4533', 2], ['4608', 1], ['4381', 12], ['4627', 1], ['4803', 2], ['4781', 2], ['4525', 1], ['4161', 5], ['4311', 1], ['4816', 20], ['4853', 2], ['4598', 2], ['4391', 18], ['4416', 1], ['4382', 2], ['4748', 2], ['4599', 1]]
# ['4816', 20]
# Processing subfolder: 111
# [['4416', 6], ['4311', 1], ['4161', 7], ['4381', 7], ['4534', 1], ['4628', 1], ['4142', 1]]
# ['4161', 7]
# Processing subfolder: 1111
# []
# Processing subfolder: 1112
# [['4627', 10], ['4142', 1], ['4974', 2], ['4525', 1], ['4783', 9]]
# ['4627', 10]
# Processing subfolder: 1113
# [['4627', 18], ['4974', 4], ['4525', 1], ['4783', 1]]
# ['4627', 18]
# Processing subfolder: 1114
# [['4783', 88], ['4142', 2], ['4974', 2], ['4628', 3], ['4627', 4], ['4367', 1]]
# ['4783', 88]
# Processing subfolder: 1115
# []
# Processing subfolder: 1116
# [['4627', 25], ['4525', 1]]
# ['4627', 25]
# Processing subfolder: 1117
# []
# Processing subfolder: 1118
# [['4161', 1], ['4803', 99]]
# ['4803', 99]
# Processing subfolder: 1122
# []
# Processing subfolder: 1126
# []
# Processing subfolder: 1127
# [['4628', 1], ['4872', 1], ['4548', 8], ['4527', 7], ['4554', 1], ['4635', 2]]
# ['4548', 8]
# Processing subfolder: 1128
# []
# Processing subfolder: 1129
# []
# Processing subfolder: 113
# [['4815', 12], ['4974', 5], ['4391', 19], ['4420', 4]]
# ['4391', 19]
# Processing subfolder: 1130
# []
# Processing subfolder: 1131
# []
# Processing subfolder: 1134
# [['4590', 23], ['4554', 34], ['4791', 1], ['4142', 3], ['4548', 3], ['4416', 1], ['4627', 1]]
# ['4554', 34]
# Processing subfolder: 1137
# []
# Processing subfolder: 114
# []
# Processing subfolder: 1143
# [['1374', 19], ['4635', 7]]
# ['1374', 19]
# Processing subfolder: 1144
# []
# Processing subfolder: 1145
# []
# Processing subfolder: 1146
# []
# Processing subfolder: 1147
# []
# Processing subfolder: 1148
# [['4142', 61], ['4161', 34], ['4548', 4], ['4974', 1]]
# ['4142', 61]
# Processing subfolder: 1149
# []
# Processing subfolder: 1150
# []
# Processing subfolder: 1151
# [['4142', 2], ['4554', 16], ['4590', 5], ['4538', 2], ['4381', 9], ['4548', 5]]
# ['4554', 16]
# Processing subfolder: 1157
# []
# Processing subfolder: 1158
# []
# Processing subfolder: 1159
# [['4635', 8], ['1374', 41]]
# ['1374', 41]
# Processing subfolder: 1160
# []
# Processing subfolder: 1161
# []
# Processing subfolder: 1165
# []
# Processing subfolder: 1169
# [['4816', 1], ['4391', 29], ['4608', 69], ['4357', 1]]
# ['4608', 69]
# Processing subfolder: 1170
# []
# Processing subfolder: 1176
# [['4391', 67], ['4382', 24], ['4357', 1], ['4635', 1], ['4842', 2], ['4815', 4], ['4533', 1]]
# ['4391', 67]
# Processing subfolder: 1177
# []
# Processing subfolder: 1178
# []
# Processing subfolder: 1179
# []
# Processing subfolder: 1180
# []
# Processing subfolder: 1182
# [['4420', 5], ['4357', 1], ['4872', 3], ['4391', 1], ['4533', 5], ['4104', 2], ['4628', 1], ['4974', 4]]
# ['4420', 5]
# Processing subfolder: 1183
# []
# Processing subfolder: 1185
# []
# Processing subfolder: 1186
# []
# Processing subfolder: 1188
# [['4815', 3], ['4548', 97]]
# ['4548', 97]
# Processing subfolder: 1189
# []
# Processing subfolder: 1190
# []
# Processing subfolder: 1191
# [['4391', 45], ['4816', 5], ['4382', 50]]
# ['4382', 50]
# Processing subfolder: 12
# []
# Processing subfolder: 1200
# []
# Processing subfolder: 121
# [['1374', 9], ['4987', 46], ['4635', 6], ['4533', 2], ['4815', 12], ['4791', 8], ['4307', 16], ['4974', 1]]
# ['4987', 46]
# Processing subfolder: 1210
# []
# Processing subfolder: 1214
# []
# Processing subfolder: 1215
# []
# Processing subfolder: 1216
# []
# Processing subfolder: 1217
# []
# Processing subfolder: 1218
# [['4391', 73], ['4608', 1], ['4826', 1], ['4872', 1], ['4974', 1], ['4533', 4], ['4176', 1], ['4815', 3], ['4987', 1], ['4382', 14]]
# ['4391', 73]
# Processing subfolder: 1219
# []
# Processing subfolder: 122
# [['4974', 1], ['4142', 49], ['4815', 12], ['4987', 38]]
# ['4142', 49]
# Processing subfolder: 1220
# []
# Processing subfolder: 1221
# []
# Processing subfolder: 1222
# []
# Processing subfolder: 1223
# []
# Processing subfolder: 1224
# []
# Processing subfolder: 1225
# [['4815', 89], ['4533', 11]]
# ['4815', 89]
# Processing subfolder: 1228
# []
# Processing subfolder: 123
# []
# Processing subfolder: 1230
# [['4791', 45], ['4815', 55]]
# ['4815', 55]
# Processing subfolder: 1234
# []
# Processing subfolder: 1235
# [['4382', 31], ['4391', 4], ['4815', 1], ['4974', 5]]
# ['4382', 31]
# Processing subfolder: 1236
# [['4826', 11], ['4974', 10], ['4533', 13], ['4382', 66]]
# ['4382', 66]
# Processing subfolder: 124
# []
# Processing subfolder: 1241
# [['4815', 98], ['4533', 2]]
# ['4815', 98]
# Processing subfolder: 1242
# []
# Processing subfolder: 1243
# []
# Processing subfolder: 1244
# []
# Processing subfolder: 1245
# []
# Processing subfolder: 1246
# [['4872', 6], ['4533', 5], ['4628', 9], ['4420', 4], ['4382', 1], ['4975', 3]]
# ['4628', 9]
# Processing subfolder: 1247
# []
# Processing subfolder: 1248
# [['4527', 3], ['4548', 16], ['4553', 3], ['4635', 3]]
# ['4548', 16]
# Processing subfolder: 1249
# []
# Processing subfolder: 1250
# []
# Processing subfolder: 1251
# []
# Processing subfolder: 1253
# []
# Processing subfolder: 1255
# [['4815', 17], ['4391', 32], ['4533', 20], ['4872', 4], ['4382', 21], ['4608', 3], ['4816', 1], ['4842', 2]]
# ['4391', 32]
# Processing subfolder: 1256
# []
# Processing subfolder: 1257
# [['4420', 2], ['4872', 11], ['4357', 6], ['4628', 2], ['4382', 4], ['4975', 3], ['4533', 2], ['4842', 1], ['4993', 1], ['4627', 1], ['4311', 1]]
# ['4872', 11]
# Processing subfolder: 1258
# []
# Processing subfolder: 1259
# [['4815', 11], ['4548', 85], ['4142', 1], ['4553', 3]]
# ['4548', 85]
# Processing subfolder: 126
# [['4815', 5], ['4987', 44], ['4142', 50], ['4391', 1]]
# ['4142', 50]
# Processing subfolder: 1260
# []
# Processing subfolder: 1263
# []
# Processing subfolder: 1265
# [['4815', 28], ['4533', 15], ['unknown', 1], ['4628', 1], ['4104', 2], ['4142', 36], ['4987', 1], ['4975', 1], ['4161', 11], ['4527', 4]]
# ['4142', 36]
# Processing subfolder: 1266
# [['4533', 10], ['4872', 6], ['4776', 2], ['4357', 3], ['4816', 5], ['4842', 1], ['4311', 5], ['4104', 36], ['4974', 24], ['4161', 1], ['4391', 4], ['4422', 2], ['4176', 1]]
# ['4104', 36]
# Processing subfolder: 1267
# [['4872', 2], ['4391', 9], ['4104', 6], ['4382', 2], ['4420', 4], ['4816', 1], ['4142', 2], ['4548', 3], ['4527', 1]]
# ['4391', 9]
# Processing subfolder: 1269
# []
# Processing subfolder: 1270
# []
# Processing subfolder: 1271
# []
# Processing subfolder: 1272
# []
# Processing subfolder: 1273
# []
# Processing subfolder: 1275
# []
# Processing subfolder: 1277
# [['4783', 80], ['4838', 2], ['4142', 1]]
# ['4783', 80]
# Processing subfolder: 1278
# []
# Processing subfolder: 128
# [['4816', 1], ['4987', 24], ['4142', 16], ['4815', 3], ['4104', 1]]
# ['4987', 24]
# Processing subfolder: 1280
# [['4367', 1], ['4627', 2], ['4783', 96], ['4142', 1]]
# ['4783', 96]
# Processing subfolder: 1281
# []
# Processing subfolder: 1282
# []
# Processing subfolder: 1283
# []
# Processing subfolder: 1284
# []
# Processing subfolder: 1285
# [['1374', 90], ['4635', 9], ['4654', 1]]
# ['1374', 90]
# Processing subfolder: 1286
# []
# Processing subfolder: 1287
# [['4420', 6], ['4422', 2], ['4974', 34], ['4533', 11], ['4987', 7], ['4311', 2], ['4628', 1], ['4842', 1], ['4815', 4], ['4975', 6], ['4104', 1], ['4872', 2], ['4382', 2], ['4816', 1]]
# ['4974', 34]
# Processing subfolder: 1289
# []
# Processing subfolder: 1290
# []
# Processing subfolder: 1291
# []
# Processing subfolder: 1292
# []
# Processing subfolder: 1293
# []
# Processing subfolder: 1294
# [['4872', 1], ['4420', 2], ['4533', 6], ['4104', 33]]
# ['4104', 33]
# Processing subfolder: 1295
# []
# Processing subfolder: 1296
# []
# Processing subfolder: 1297
# [['4815', 5], ['4548', 73], ['4553', 7], ['4999', 11], ['4781', 2], ['4554', 1], ['4142', 1]]
# ['4548', 73]
# Processing subfolder: 1298
# []
# Processing subfolder: 13
# []
# Processing subfolder: 130
# []
# Processing subfolder: 1301
# [['4628', 1], ['4367', 1], ['4311', 2], ['4999', 9], ['4627', 53], ['L9', 11], ['4815', 3]]
# ['4627', 53]
# Processing subfolder: 1302
# []
# Processing subfolder: 1303
# []
# Processing subfolder: 1304
# []
# Processing subfolder: 1305
# [['4420', 6], ['4104', 1], ['4872', 9], ['4357', 1], ['4773', 1], ['4975', 6], ['4533', 2]]
# ['4872', 9]
# Processing subfolder: 1307
# []
# Processing subfolder: 1308
# []
# Processing subfolder: 131
# [['4142', 35], ['4974', 1], ['4815', 14], ['4987', 49], ['4525', 1]]
# ['4987', 49]
# Processing subfolder: 1310
# []
# Processing subfolder: 1311
# []
# Processing subfolder: 1312
# [['4627', 10], ['4525', 3], ['4783', 87]]
# ['4783', 87]
# Processing subfolder: 1313
# []
# Processing subfolder: 1316
# []
# Processing subfolder: 1318
# []
# Processing subfolder: 1319
# []
# Processing subfolder: 132
# [['4815', 1], ['4142', 22], ['4987', 77]]
# ['4987', 77]
# Processing subfolder: 1321
# [['4773', 41], ['4533', 51], ['4357', 5], ['4382', 1], ['4872', 2]]
# ['4533', 51]
# Processing subfolder: 1322
# []
# Processing subfolder: 1323
# []
# Processing subfolder: 1324
# []
# Processing subfolder: 1325
# []
# Processing subfolder: 1326
# []
# Processing subfolder: 1327
# []
# Processing subfolder: 1330
# []
# Processing subfolder: 1331
# []
# Processing subfolder: 1332
# []
# Processing subfolder: 1333
# [['4554', 4], ['4142', 5], ['4548', 43], ['4382', 20], ['4635', 1], ['4987', 1]]
# ['4548', 43]
# Processing subfolder: 1336
# [['4548', 1], ['4987', 43], ['4382', 3], ['4635', 11], ['4554', 7], ['1374', 1], ['4161', 1], ['4815', 4], ['4816', 1]]
# ['4987', 43]
# Processing subfolder: 1338
# []
# Processing subfolder: 1342
# [['4974', 1], ['4815', 3], ['4142', 7], ['4548', 44], ['4553', 1]]
# ['4548', 44]
# Processing subfolder: 1344
# []
# Processing subfolder: 1345
# [['4635', 48], ['4987', 23], ['1374', 29]]
# ['4635', 48]
# Processing subfolder: 1346
# [['4815', 12], ['4635', 2], ['4974', 2], ['4422', 1], ['4142', 24], ['4527', 59]]
# ['4527', 59]
# Processing subfolder: 1347
# [['4987', 2], ['4142', 41], ['4548', 44], ['4815', 10], ['4553', 3]]
# ['4548', 44]
# Processing subfolder: 1348
# []
# Processing subfolder: 1349
# []
# Processing subfolder: 135
# []
# Processing subfolder: 1350
# [['4533', 16], ['4974', 46], ['4628', 5], ['4104', 3], ['4420', 2], ['4987', 2], ['4551', 2], ['4361', 1], ['4599', 1], ['4635', 1], ['4391', 1], ['4382', 6], ['4527', 1], ['4815', 2]]
# ['4974', 46]
# Processing subfolder: 1352
# []
# Processing subfolder: 1353
# [['4548', 52], ['4527', 3], ['4538', 1], ['4815', 1], ['4307', 1], ['4554', 1], ['4142', 1], ['4635', 1]]
# ['4548', 52]
# Processing subfolder: 1356
# [['4635', 5], ['4783', 1], ['4791', 63], ['1374', 31]]
# ['4791', 63]
# Processing subfolder: 1357
# []
# Processing subfolder: 1358
# []
# Processing subfolder: 1359
# [['4815', 17], ['4554', 4], ['4987', 12], ['4307', 2], ['4142', 6], ['4391', 1], ['4527', 1]]
# ['4815', 17]
# Processing subfolder: 136
# [['4161', 99], ['4554', 1]]
# ['4161', 99]
# Processing subfolder: 1360
# []
# Processing subfolder: 1361
# []
# Processing subfolder: 1362
# []
# Processing subfolder: 1363
# [['4142', 62], ['4391', 1], ['4974', 2], ['4527', 35]]
# ['4142', 62]
# Processing subfolder: 1364
# []
# Processing subfolder: 1365
# []
# Processing subfolder: 1366
# []
# Processing subfolder: 1367
# []
# Processing subfolder: 137
# [['4533', 3], ['4815', 25], ['4142', 15], ['4791', 2], ['4548', 3], ['4628', 52]]
# ['4628', 52]
# Processing subfolder: 1370
# []
# Processing subfolder: 1372
# []
# Processing subfolder: 1373
# []
# Processing subfolder: 1374
# []
# Processing subfolder: 1375
# []
# Processing subfolder: 1376
# []
# Processing subfolder: 1377
# []
# Processing subfolder: 1378
# [['4554', 1], ['4815', 2], ['4142', 3], ['4548', 94]]
# ['4548', 94]
# Processing subfolder: 1379
# []
# Processing subfolder: 138
# [['4382', 7], ['4357', 9], ['4533', 13], ['4872', 23], ['4842', 1], ['4975', 1], ['4816', 3]]
# ['4872', 23]
# Processing subfolder: 1380
# []
# Processing subfolder: 1381
# []
# Processing subfolder: 1382
# [['4548', 36], ['4815', 9], ['4635', 41], ['4987', 3], ['4307', 3], ['1374', 3], ['4791', 2], ['4554', 2], ['4142', 1]]
# ['4635', 41]
# Processing subfolder: 1383
# []
# Processing subfolder: 1384
# []
# Processing subfolder: 1385
# [['4533', 25], ['4420', 27], ['4872', 6], ['4581', 3], ['4382', 1], ['4773', 1]]
# ['4420', 27]
# Processing subfolder: 1386
# []
# Processing subfolder: 1387
# []
# Processing subfolder: 1388
# [['4548', 32], ['4527', 1]]
# ['4548', 32]
# Processing subfolder: 1389
# []
# Processing subfolder: 139
# [['4773', 3], ['4815', 36], ['4816', 2], ['4533', 3], ['4872', 38], ['4382', 4], ['4391', 7], ['4975', 1], ['4420', 2], ['4104', 4]]
# ['4872', 38]
# Processing subfolder: 1390
# [['1374', 38], ['4635', 7]]
# ['1374', 38]
# Processing subfolder: 1391
# [['4548', 53], ['4142', 12], ['4635', 11], ['4815', 4], ['4382', 1], ['4816', 1]]
# ['4548', 53]
# Processing subfolder: 1392
# []
# Processing subfolder: 1393
# []
# Processing subfolder: 1394
# []
# Processing subfolder: 1395
# []
# Processing subfolder: 1396
# []
# Processing subfolder: 1397
# [['4538', 1], ['4783', 99]]
# ['4783', 99]
# Processing subfolder: 1398
# []
# Processing subfolder: 1399
# []
# Processing subfolder: 14
# []
# Processing subfolder: 140
# [['4527', 21], ['4815', 6], ['4548', 55], ['4554', 1]]
# ['4548', 55]
# Processing subfolder: 1400
# []
# Processing subfolder: 1401
# []
# Processing subfolder: 1402
# []
# Processing subfolder: 1403
# []
# Processing subfolder: 1404
# []
# Processing subfolder: 1405
# []
# Processing subfolder: 1406
# []
# Processing subfolder: 1407
# []
# Processing subfolder: 1408
# [['4815', 6], ['4527', 1], ['4548', 39], ['4999', 1]]
# ['4548', 39]
# Processing subfolder: 1409
# []
# Processing subfolder: 1410
# [['4872', 2], ['4357', 3], ['4420', 7], ['4842', 2], ['4993', 2], ['4975', 2], ['4311', 1], ['4628', 3], ['4104', 3], ['4382', 1], ['4533', 1]]
# ['4420', 7]
# Processing subfolder: 1411
# [['4527', 2], ['4815', 8], ['4142', 1], ['4548', 89]]
# ['4548', 89]
# Processing subfolder: 1412
# []
# Processing subfolder: 1414
# [['4533', 3], ['4872', 32], ['4357', 14], ['4382', 17], ['4842', 2], ['4176', 3], ['4993', 1], ['4975', 8], ['4420', 3], ['4599', 1], ['4974', 1], ['4104', 1]]
# ['4872', 32]
# Processing subfolder: 1415
# []
# Processing subfolder: 1416
# []
# Processing subfolder: 1417
# [['4791', 17], ['4815', 5], ['1374', 2], ['4554', 1]]
# ['4791', 17]
# Processing subfolder: 1420
# [['4635', 2], ['4831', 3], ['4815', 3], ['1374', 36]]
# ['1374', 36]
# Processing subfolder: 1421
# []
# Processing subfolder: 1423
# []
# Processing subfolder: 1425
# []
# Processing subfolder: 1427
# []
# Processing subfolder: 1428
# []
# Processing subfolder: 143
# []
# Processing subfolder: 1430
# [['4533', 30], ['4382', 6], ['1374', 4], ['4635', 1], ['4357', 3], ['4551', 7], ['4598', 1]]
# ['4533', 30]
# Processing subfolder: 1432
# []
# Processing subfolder: 1434
# [['1374', 28], ['4987', 3], ['4635', 11]]
# ['1374', 28]
# Processing subfolder: 1439
# []
# Processing subfolder: 144
# []
# Processing subfolder: 1440
# []
# Processing subfolder: 1441
# [['4791', 14], ['4551', 1], ['4635', 4], ['4554', 7], ['4142', 2], ['4987', 34], ['4598', 1], ['4307', 29]]
# ['4987', 34]
# Processing subfolder: 1444
# [['1374', 73], ['4104', 1], ['4533', 8], ['4987', 1]]
# ['1374', 73]
# Processing subfolder: 1445
# []
# Processing subfolder: 1446
# []
# Processing subfolder: 1448
# [['4815', 8], ['4548', 46], ['4554', 4], ['4142', 2], ['4635', 1]]
# ['4548', 46]
# Processing subfolder: 1450
# []
# Processing subfolder: 1451
# []
# Processing subfolder: 1452
# [['4815', 10], ['4831', 1], ['4548', 11], ['4142', 8], ['4635', 3], ['4987', 1], ['4554', 2], ['4307', 1]]
# ['4548', 11]
# Processing subfolder: 1453
# []
# Processing subfolder: 1458
# [['4311', 3], ['4142', 8], ['4974', 2], ['4987', 5], ['4815', 4], ['4104', 1]]
# ['4142', 8]
# Processing subfolder: 1459
# []
# Processing subfolder: 146
# []
# Processing subfolder: 1460
# []
# Processing subfolder: 1461
# []
# Processing subfolder: 1462
# []
# Processing subfolder: 1463
# []
# Processing subfolder: 1464
# []
# Processing subfolder: 1465
# [['4142', 12], ['4311', 3], ['4815', 3], ['4104', 4]]
# ['4142', 12]
# Processing subfolder: 1466
# [['4815', 4], ['4142', 13], ['4987', 3], ['4104', 1]]
# ['4142', 13]
# Processing subfolder: 1468
# [['4142', 65], ['4104', 14], ['4987', 12], ['4815', 8], ['4311', 1]]
# ['4142', 65]
# Processing subfolder: 147
# []
# Processing subfolder: 1475
# []
# Processing subfolder: 1476
# []
# Processing subfolder: 1477
# []
# Processing subfolder: 1479
# []
# Processing subfolder: 148
# []
# Processing subfolder: 1480
# []
# Processing subfolder: 1481
# []
# Processing subfolder: 1482
# []
# Processing subfolder: 1483
# []
# Processing subfolder: 1484
# []
# Processing subfolder: 1485
# [['4527', 2], ['4815', 4], ['4548', 12], ['4142', 2], ['4553', 3]]
# ['4548', 12]
# Processing subfolder: 1486
# []
# Processing subfolder: 1487
# []
# Processing subfolder: 1488
# [['4553', 1], ['4527', 3], ['4842', 2], ['4853', 2], ['4628', 1], ['4993', 1], ['4142', 10], ['4856', 1], ['4783', 4], ['4611', 1], ['4532', 1]]
# ['4142', 10]
# Processing subfolder: 1490
# []
# Processing subfolder: 1491
# [['4635', 5], ['4815', 3], ['4554', 73], ['4791', 1], ['4831', 17], ['4987', 1]]
# ['4554', 73]
# Processing subfolder: 1492
# [['1374', 78], ['4635', 4]]
# ['1374', 78]
# Processing subfolder: 1495
# [['4815', 2], ['4791', 27], ['4554', 1]]
# ['4791', 27]
# Processing subfolder: 1499
# []
# Processing subfolder: 15
# []
# Processing subfolder: 150
# []
# Processing subfolder: 1501
# [['4974', 1], ['4975', 10], ['4816', 3], ['4420', 1], ['4628', 1], ['4815', 47], ['4872', 36], ['4551', 1]]
# ['4815', 47]
# Processing subfolder: 1502
# []
# Processing subfolder: 1503
# [['1374', 18], ['4635', 1], ['4987', 1]]
# ['1374', 18]
# Processing subfolder: 1504
# []
# Processing subfolder: 1505
# []
# Processing subfolder: 1506
# []
# Processing subfolder: 1508
# []
# Processing subfolder: 1509
# []
# Processing subfolder: 151
# [['4142', 1], ['4548', 59], ['4527', 3], ['1374', 1]]
# ['4548', 59]
# Processing subfolder: 1510
# []
# Processing subfolder: 1513
# [['4872', 33], ['4815', 25], ['4391', 1], ['4382', 2], ['4551', 1], ['4975', 29], ['4357', 1], ['4420', 1], ['4628', 2], ['4773', 5]]
# ['4872', 33]
# Processing subfolder: 152
# []
# Processing subfolder: 1523
# []
# Processing subfolder: 1525
# [['4815', 2], ['4783', 1], ['4791', 18], ['1374', 1]]
# ['4791', 18]
# Processing subfolder: 1526
# [['4142', 9], ['4382', 1], ['4416', 1], ['4831', 2], ['4527', 7], ['4815', 4], ['4538', 12], ['4548', 10]]
# ['4538', 12]
# Processing subfolder: 153
# []
# Processing subfolder: 1533
# []
# Processing subfolder: 154
# []
# Processing subfolder: 1541
# [['4581', 1], ['4628', 2], ['4527', 3], ['4142', 5], ['4548', 9], ['4815', 2], ['4538', 10]]
# ['4538', 10]
# Processing subfolder: 1542
# [['4635', 14], ['1374', 81], ['4831', 1], ['4554', 3], ['4654', 1]]
# ['1374', 81]
# Processing subfolder: 1544
# [['4815', 7], ['4142', 7], ['4548', 84], ['4999', 2]]
# ['4548', 84]
# Processing subfolder: 1548
# [['4142', 5], ['4831', 1], ['4554', 1], ['1374', 90], ['4307', 3]]
# ['1374', 90]
# Processing subfolder: 155
# []
# Processing subfolder: 1550
# []
# Processing subfolder: 1551
# []
# Processing subfolder: 1552
# [['4382', 7], ['4627', 4], ['4993', 6], ['4142', 2], ['4999', 2], ['4357', 1], ['4791', 1], ['4872', 1], ['4420', 15], ['4975', 7]]
# ['4420', 15]
# Processing subfolder: 1558
# [['4635', 6], ['1374', 3], ['4781', 3], ['4553', 1], ['5000', 86], ['4538', 1]]
# ['5000', 86]
# Processing subfolder: 1559
# [['4635', 4], ['4974', 17], ['4391', 4], ['4627', 3], ['4533', 1], ['4975', 30], ['4420', 12], ['4628', 1], ['4993', 1], ['4987', 1], ['4142', 1]]
# ['4975', 30]
# Processing subfolder: 156
# [['4564', 3], ['4974', 16], ['4361', 2], ['4391', 9], ['4987', 1], ['L2', 1], ['4420', 1], ['4816', 2], ['4635', 2], ['4533', 2], ['4975', 1]]
# ['4974', 16]
# Processing subfolder: 1564
# []
# Processing subfolder: 1567
# [['1374', 26], ['4635', 7], ['4554', 1]]
# ['1374', 26]
# Processing subfolder: 1568
# [['4548', 96], ['4142', 4]]
# ['4548', 96]
# Processing subfolder: 1569
# [['4551', 1], ['4554', 1], ['1374', 98]]
# ['1374', 98]
# Processing subfolder: 157
# []
# Processing subfolder: 1571
# [['4532', 1], ['4416', 12], ['4598', 44], ['4142', 6], ['4525', 29], ['4534', 8]]
# ['4598', 44]
# Processing subfolder: 1573
# [['1374', 23], ['4987', 2], ['4791', 1], ['4554', 9], ['4382', 1], ['4635', 16], ['4654', 11], ['4307', 19]]
# ['1374', 23]
# Processing subfolder: 1574
# [['4548', 14], ['4142', 5], ['4554', 1], ['4541', 1]]
# ['4548', 14]
# Processing subfolder: 1578
# []
# Processing subfolder: 1579
# [['4815', 1], ['4554', 2], ['1374', 97]]
# ['1374', 97]
# Processing subfolder: 158
# []
# Processing subfolder: 1581
# []
# Processing subfolder: 1582
# [['4815', 70], ['4142', 25], ['4635', 5]]
# ['4815', 70]
# Processing subfolder: 1584
# [['4548', 77], ['4527', 2], ['4554', 5], ['4142', 1], ['1374', 9], ['4654', 6]]
# ['4548', 77]
# Processing subfolder: 1585
# [['4815', 2], ['4554', 1], ['1374', 95], ['4816', 2]]
# ['1374', 95]
# Processing subfolder: 1586
# [['4815', 15], ['4142', 2], ['4635', 3]]
# ['4815', 15]
# Processing subfolder: 1588
# []
# Processing subfolder: 159
# [['4635', 5], ['4815', 4], ['4551', 2], ['4987', 10], ['4831', 1], ['4554', 2]]
# ['4987', 10]
# Processing subfolder: 1591
# [['1374', 85], ['4987', 2], ['4815', 13]]
# ['1374', 85]
# Processing subfolder: 1593
# [['4815', 11], ['4635', 78], ['4142', 6], ['4307', 5]]
# ['4635', 78]
# Processing subfolder: 1594
# [['4815', 1], ['4554', 2], ['1374', 97]]
# ['1374', 97]
# Processing subfolder: 1595
# [['4635', 23], ['1374', 49], ['4815', 28]]
# ['1374', 49]
# Processing subfolder: 1596
# [['4553', 70], ['4548', 24], ['4142', 5], ['4527', 1]]
# ['4553', 70]
# Processing subfolder: 1597
# [['4635', 98], ['1374', 1]]
# ['4635', 98]
# Processing subfolder: 1598
# [['4527', 15], ['4548', 85]]
# ['4548', 85]
# Processing subfolder: 1599
# [['4815', 1], ['4538', 1], ['4307', 33], ['4142', 3]]
# ['4307', 33]
# Processing subfolder: 16
# []
# Processing subfolder: 160
# [['4987', 91], ['4142', 5], ['4598', 2], ['4391', 1], ['4815', 1]]
# ['4987', 91]
# Processing subfolder: 1601
# []
# Processing subfolder: 1603
# [['4307', 44], ['4142', 6], ['4815', 3]]
# ['4307', 44]
# Processing subfolder: 1604
# [['4307', 41], ['4142', 3]]
# ['4307', 41]
# Processing subfolder: 1606
# []
# Processing subfolder: 1608
# []
# Processing subfolder: 1609
# []
# Processing subfolder: 161
# [['4987', 88], ['4142', 8], ['4815', 2], ['4599', 2]]
# ['4987', 88]
# Processing subfolder: 1611
# []
# Processing subfolder: 1612
# []
# Processing subfolder: 1613
# []
# Processing subfolder: 1615
# []
# Processing subfolder: 1616
# [['4307', 98], ['4142', 1], ['4815', 1]]
# ['4307', 98]
# Processing subfolder: 1617
# [['4815', 10], ['4538', 83], ['4307', 6], ['4791', 1]]
# ['4538', 83]
# Processing subfolder: 1618
# []
# Processing subfolder: 1619
# [['5000', 96], ['4142', 4]]
# ['5000', 96]
# Processing subfolder: 1620
# [['4534', 1], ['4142', 10], ['4781', 5], ['4527', 3], ['4815', 17], ['4598', 1], ['4551', 1], ['4161', 1], ['4554', 2], ['4627', 1]]
# ['4815', 17]
# Processing subfolder: 1621
# [['4815', 32], ['4635', 36], ['1374', 5], ['4987', 2]]
# ['4635', 36]
# Processing subfolder: 1622
# [['4993', 1], ['4538', 1], ['4307', 69], ['4815', 4], ['4142', 25]]
# ['4307', 69]
# Processing subfolder: 1623
# [['4598', 1], ['4815', 43], ['4635', 46], ['4382', 9], ['4538', 1]]
# ['4635', 46]
# Processing subfolder: 1624
# [['4307', 10], ['4815', 68], ['4791', 4], ['4635', 10], ['4553', 2], ['4527', 5], ['4538', 1]]
# ['4815', 68]
# Processing subfolder: 1625
# [['4142', 46], ['4635', 8], ['4307', 31], ['4815', 15]]
# ['4142', 46]
# Processing subfolder: 1626
# [['4815', 17], ['4307', 59], ['4635', 13], ['4142', 11]]
# ['4307', 59]
# Processing subfolder: 1627
# []
# Processing subfolder: 1629
# [['4815', 90], ['4142', 7], ['4635', 3]]
# ['4815', 90]
# Processing subfolder: 163
# []
# Processing subfolder: 1631
# []
# Processing subfolder: 1632
# [['4350', 1], ['4525', 3], ['4611', 7], ['4783', 79], ['4142', 5], ['4538', 1], ['3875', 2], ['4815', 2]]
# ['4783', 79]
# Processing subfolder: 1633
# []
# Processing subfolder: 1635
# []
# Processing subfolder: 1636
# [['4548', 4], ['4815', 1], ['4541', 16], ['4142', 19], ['4553', 4]]
# ['4142', 19]
# Processing subfolder: 1637
# []
# Processing subfolder: 1638
# [['4357', 1], ['4581', 2], ['4815', 67], ['4635', 13], ['4311', 5], ['4654', 12]]
# ['4815', 67]
# Processing subfolder: 1639
# [['4307', 38]]
# ['4307', 38]
# Processing subfolder: 164
# []
# Processing subfolder: 1640
# [['4815', 96], ['4382', 1], ['4987', 3]]
# ['4815', 96]
# Processing subfolder: 1641
# [['4307', 95], ['4142', 4], ['4815', 1]]
# ['4307', 95]
# Processing subfolder: 1644
# [['4532', 1], ['4845', 1], ['4783', 78], ['4599', 3], ['4548', 4], ['4611', 1], ['3875', 2], ['4527', 1], ['4538', 6], ['4553', 2], ['4142', 1]]
# ['4783', 78]
# Processing subfolder: 1645
# [['4391', 2], ['4993', 54], ['4816', 15], ['4142', 7], ['4867', 5], ['4826', 4], ['4803', 1], ['4599', 2]]
# ['4993', 54]
# Processing subfolder: 1646
# []
# Processing subfolder: 1647
# []
# Processing subfolder: 165
# []
# Processing subfolder: 1654
# [['3875', 17], ['4538', 24], ['4611', 2], ['4142', 25], ['unknown', 1], ['4548', 13], ['4527', 1], ['4416', 1], ['4783', 8], ['4781', 1]]
# ['4142', 25]
# Processing subfolder: 1656
# [['4791', 21], ['4815', 6], ['4554', 1]]
# ['4791', 21]
# Processing subfolder: 1657
# [['4142', 8], ['4533', 10], ['4391', 3], ['4816', 2]]
# ['4533', 10]
# Processing subfolder: 1658
# [['4611', 8], ['4599', 1], ['4142', 3], ['4161', 8], ['4628', 13], ['4532', 27], ['4853', 7]]
# ['4532', 27]
# Processing subfolder: 1659
# []
# Processing subfolder: 166
# []
# Processing subfolder: 1660
# [['4635', 1], ['4142', 11], ['4816', 8], ['4533', 2], ['4554', 1]]
# ['4142', 11]
# Processing subfolder: 1661
# [['4635', 4], ['4161', 1], ['4773', 7], ['4581', 4], ['4845', 1], ['4533', 1], ['4987', 2], ['4361', 1], ['4628', 3], ['4853', 3], ['4551', 1], ['4142', 9], ['4792', 2], ['4527', 1], ['1374', 54], ['4416', 1], ['4391', 1], ['4815', 3], ['4311', 1]]
# ['1374', 54]
# Processing subfolder: 1662
# [['4532', 1], ['4627', 1], ['4598', 92], ['4142', 5], ['4527', 1]]
# ['4598', 92]
# Processing subfolder: 1663
# []
# Processing subfolder: 1664
# []
# Processing subfolder: 1665
# [['4416', 1], ['4382', 1], ['4781', 98]]
# ['4781', 98]
# Processing subfolder: 1666
# [['4581', 5], ['4391', 4], ['4416', 4], ['4382', 1], ['4815', 3], ['4635', 1], ['4773', 1], ['1374', 3], ['4867', 1], ['4142', 3], ['4816', 1], ['4781', 4]]
# ['4581', 5]
# Processing subfolder: 1668
# [['4142', 69], ['4635', 7], ['4650', 7], ['4382', 11], ['4816', 6]]
# ['4142', 69]
# Processing subfolder: 1669
# [['4142', 100]]
# ['4142', 100]
# Processing subfolder: 167
# [['4161', 19], ['4381', 1], ['4534', 1], ['4416', 1], ['4311', 1], ['4142', 1]]
# ['4161', 19]
# Processing subfolder: 1670
# []
# Processing subfolder: 1671
# []
# Processing subfolder: 1672
# [['4142', 1], ['4781', 61], ['4815', 2], ['4867', 1]]
# ['4781', 61]
# Processing subfolder: 1673
# [['4532', 11], ['4845', 7], ['4554', 4], ['4611', 4], ['4815', 1], ['5000', 5], ['4311', 3]]
# ['4532', 11]
# Processing subfolder: 1674
# []
# Processing subfolder: 1678
# [['4161', 100]]
# ['4161', 100]
# Processing subfolder: 1679
# [['4853', 96], ['4532', 4]]
# ['4853', 96]
# Processing subfolder: 168
# [['4815', 11], ['4554', 1], ['1374', 88]]
# ['1374', 88]
# Processing subfolder: 1680
# [['4838', 100]]
# ['4838', 100]
# Processing subfolder: 1681
# [['4538', 100]]
# ['4538', 100]
# Processing subfolder: 1682
# [['4815', 100]]
# ['4815', 100]
# Processing subfolder: 1683
# [['4554', 100]]
# ['4554', 100]
# Processing subfolder: 1684
# [['4553', 7], ['4815', 8], ['4999', 1], ['4527', 10], ['4142', 2], ['4548', 21]]
# ['4548', 21]
# Processing subfolder: 1685
# [['4533', 32], ['4826', 24], ['4776', 2], ['4357', 11], ['4872', 26], ['4382', 1], ['4816', 1], ['4773', 3]]
# ['4533', 32]
# Processing subfolder: 1687
# []
# Processing subfolder: 1688
# []
# Processing subfolder: 1689
# []
# Processing subfolder: 1690
# [['4872', 55], ['4533', 5], ['4826', 25], ['4357', 12], ['4773', 2], ['4382', 1]]
# ['4872', 55]
# Processing subfolder: 1694
# []
# Processing subfolder: 1695
# []
# Processing subfolder: 1696
# []
# Processing subfolder: 1699
# []
# Processing subfolder: 1701
# []
# Processing subfolder: 1706
# []
# Processing subfolder: 1707
# []
# Processing subfolder: 1708
# [['4635', 6], ['4748', 11], ['4416', 2], ['4525', 3], ['4311', 8], ['4381', 50], ['4627', 1], ['4987', 4], ['4104', 1], ['4391', 2], ['4816', 2], ['4815', 4], ['4382', 2], ['4533', 2], ['4532', 2]]
# ['4381', 50]
# Processing subfolder: 171
# [['4533', 4], ['4382', 21], ['4987', 3], ['4815', 8]]
# ['4382', 21]
# Processing subfolder: 1710
# []
# Processing subfolder: 1711
# [['4381', 100]]
# ['4381', 100]
# Processing subfolder: 1712
# [['4815', 4], ['4391', 3], ['4533', 6], ['4382', 11], ['4816', 12], ['4974', 1], ['4608', 6], ['4803', 1], ['4527', 3], ['4142', 1]]
# ['4816', 12]
# Processing subfolder: 1714
# []
# Processing subfolder: 1715
# [['4381', 100]]
# ['4381', 100]
# Processing subfolder: 1716
# [['4527', 2], ['4608', 6], ['4382', 9], ['4142', 12], ['4783', 1], ['4803', 1], ['4533', 2], ['4816', 3], ['4391', 1]]
# ['4142', 12]
# Processing subfolder: 1717
# [['4533', 11], ['4816', 22], ['4842', 5], ['4815', 2], ['4581', 3], ['4391', 2], ['4627', 4], ['4161', 1], ['4142', 1], ['4382', 3]]
# ['4816', 22]
# Processing subfolder: 1719
# []
# Processing subfolder: 172
# [['4987', 17], ['4581', 1], ['4142', 2]]
# ['4987', 17]
# Processing subfolder: 1720
# []
# Processing subfolder: 1721
# []
# Processing subfolder: 1724
# [['4142', 5], ['4871', 1], ['4381', 57], ['4599', 4], ['4161', 4], ['4842', 2], ['4311', 1], ['4533', 5]]
# ['4381', 57]
# Processing subfolder: 1727
# []
# Processing subfolder: 1728
# []
# Processing subfolder: 1729
# [['4635', 14], ['4554', 27], ['4815', 39], ['4791', 10], ['4307', 8], ['1374', 2]]
# ['4815', 39]
# Processing subfolder: 173
# [['4987', 84], ['4142', 8], ['4815', 6], ['4599', 2]]
# ['4987', 84]
# Processing subfolder: 1730
# [['4104', 34], ['4974', 2], ['4826', 60], ['4599', 2], ['4842', 2]]
# ['4826', 60]
# Processing subfolder: 1732
# [['4815', 97], ['4161', 1], ['4142', 2]]
# ['4815', 97]
# Processing subfolder: 1733
# []
# Processing subfolder: 1734
# []
# Processing subfolder: 1736
# [['4974', 13], ['4104', 8], ['4533', 2], ['4815', 1], ['4161', 3], ['4391', 2], ['4525', 2], ['4311', 1], ['4142', 2]]
# ['4974', 13]
# Processing subfolder: 1737
# []
# Processing subfolder: 1738
# []
# Processing subfolder: 1739
# [['4815', 15], ['4987', 2], ['4142', 2], ['4161', 4], ['4608', 1], ['4311', 1], ['4816', 1], ['4628', 1]]
# ['4815', 15]
# Processing subfolder: 1740
# []
# Processing subfolder: 1741
# [['4391', 3], ['4104', 12], ['4974', 1], ['4142', 8], ['4161', 3], ['4525', 1], ['4533', 2]]
# ['4104', 12]
# Processing subfolder: 1743
# []
# Processing subfolder: 1744
# [['4608', 50], ['4635', 1], ['4311', 8], ['4987', 3], ['4538', 5], ['4161', 27], ['4815', 3], ['4142', 1], ['4391', 1], ['4567', 1]]
# ['4608', 50]
# Processing subfolder: 1745
# []
# Processing subfolder: 1746
# []
# Processing subfolder: 1747
# []
# Processing subfolder: 1748
# []
# Processing subfolder: 1749
# []
# Processing subfolder: 175
# [['4815', 18], ['4635', 81], ['4987', 1]]
# ['4635', 81]
# Processing subfolder: 1750
# []
# Processing subfolder: 1751
# [['4816', 4], ['4628', 2], ['4608', 60], ['4815', 6], ['4391', 3], ['4161', 12], ['4142', 4], ['4525', 1], ['4538', 2], ['4311', 5], ['4551', 1]]
# ['4608', 60]
# Processing subfolder: 1752
# []
# Processing subfolder: 1754
# []
# Processing subfolder: 1755
# []
# Processing subfolder: 1756
# [['4142', 9], ['4357', 11]]
# ['4357', 11]
# Processing subfolder: 1757
# []
# Processing subfolder: 176
# []
# Processing subfolder: 1761
# []
# Processing subfolder: 1762
# [['4628', 2], ['4872', 6], ['4382', 2], ['4104', 72], ['4975', 2], ['4361', 1], ['4533', 4], ['4357', 1], ['4842', 2], ['4391', 1]]
# ['4104', 72]
# Processing subfolder: 1763
# []
# Processing subfolder: 1765
# []
# Processing subfolder: 1767
# [['4533', 5], ['4104', 91], ['4599', 1], ['4628', 1], ['4357', 2]]
# ['4104', 91]
# Processing subfolder: 177
# [['4599', 3], ['4815', 2], ['4987', 88], ['4598', 1], ['4142', 5], ['4391', 1]]
# ['4987', 88]
# Processing subfolder: 1770
# []
# Processing subfolder: 1772
# []
# Processing subfolder: 1773
# []
# Processing subfolder: 1774
# [['4551', 24], ['4391', 3], ['4161', 9], ['4608', 47], ['4987', 2], ['4816', 2], ['4142', 7], ['4628', 3], ['4538', 1], ['4815', 1], ['4311', 1]]
# ['4608', 47]
# Processing subfolder: 1777
# []
# Processing subfolder: 1778
# [['4551', 17], ['4608', 55], ['4142', 15], ['4527', 1], ['4311', 1], ['4538', 1], ['4161', 8], ['4816', 2]]
# ['4608', 55]
# Processing subfolder: 1779
# []
# Processing subfolder: 1780
# []
# Processing subfolder: 1781
# []
# Processing subfolder: 1782
# [['4142', 23], ['4161', 4], ['4391', 1]]
# ['4142', 23]
# Processing subfolder: 1783
# []
# Processing subfolder: 1784
# []
# Processing subfolder: 1785
# []
# Processing subfolder: 1786
# [['4161', 29], ['4142', 2], ['4551', 7], ['4533', 1], ['4987', 1]]
# ['4161', 29]
# Processing subfolder: 1787
# []
# Processing subfolder: 1789
# [['4104', 24], ['4533', 2], ['4142', 14], ['4161', 10]]
# ['4104', 24]
# Processing subfolder: 1790
# []
# Processing subfolder: 1791
# [['4161', 63], ['4608', 14], ['4551', 4], ['4142', 6], ['4816', 5], ['4987', 3], ['4635', 1], ['4815', 4]]
# ['4161', 63]
# Processing subfolder: 1793
# []
# Processing subfolder: 1794
# []
# Processing subfolder: 1795
# [['4872', 1], ['4382', 8], ['4816', 89], ['4391', 1], ['4974', 1]]
# ['4816', 89]
# Processing subfolder: 1796
# []
# Processing subfolder: 1797
# []
# Processing subfolder: 1798
# []
# Processing subfolder: 1799
# []
# Processing subfolder: 1800
# []
# Processing subfolder: 1801
# []
# Processing subfolder: 1802
# [['4142', 2], ['4161', 38], ['4987', 2], ['4525', 1], ['4816', 1], ['4608', 1]]
# ['4161', 38]
# Processing subfolder: 1803
# []
# Processing subfolder: 1804
# [['4161', 64], ['4608', 2], ['4142', 12], ['4391', 2], ['4551', 3], ['4815', 11], ['4635', 4], ['4554', 1], ['4381', 1]]
# ['4161', 64]
# Processing subfolder: 1805
# []
# Processing subfolder: 1807
# []
# Processing subfolder: 1808
# [['4974', 10], ['4987', 1], ['4815', 9], ['4161', 5], ['4391', 14], ['4816', 4], ['4628', 2], ['4142', 1], ['4783', 1], ['4773', 1]]
# ['4391', 14]
# Processing subfolder: 1810
# []
# Processing subfolder: 1811
# []
# Processing subfolder: 1812
# [['4142', 17], ['4816', 11], ['4161', 58], ['4533', 5], ['4391', 6], ['4551', 1], ['4815', 2]]
# ['4161', 58]
# Processing subfolder: 1813
# []
# Processing subfolder: 1814
# []
# Processing subfolder: 1816
# []
# Processing subfolder: 1817
# [['4987', 1], ['4525', 2], ['4161', 27], ['4628', 1], ['4627', 2], ['4598', 33], ['4416', 2], ['4142', 5], ['4974', 1], ['4815', 26]]
# ['4598', 33]
# Processing subfolder: 1818
# []
# Processing subfolder: 1819
# []
# Processing subfolder: 1820
# []
# Processing subfolder: 1821
# []
# Processing subfolder: 1822
# []
# Processing subfolder: 1823
# [['4815', 2], ['4311', 1], ['4161', 19]]
# ['4161', 19]
# Processing subfolder: 1824
# []
# Processing subfolder: 1825
# []
# Processing subfolder: 1827
# []
# Processing subfolder: 1828
# [['4815', 1], ['4635', 1], ['4533', 2], ['4104', 1], ['4142', 9], ['4161', 26], ['4783', 7]]
# ['4161', 26]
# Processing subfolder: 1829
# []
# Processing subfolder: 1830
# []
# Processing subfolder: 1831
# [['4311', 1], ['4815', 4], ['4533', 12], ['4142', 38]]
# ['4142', 38]
# Processing subfolder: 1837
# [['4533', 35], ['4357', 9], ['4816', 1], ['4872', 5], ['4581', 3]]
# ['4533', 35]
# Processing subfolder: 1839
# []
# Processing subfolder: 1842
# [['4161', 77], ['4142', 1], ['4311', 1], ['4416', 6], ['4993', 1], ['4815', 11], ['4627', 2], ['4748', 1]]
# ['4161', 77]
# Processing subfolder: 1843
# [['4815', 88], ['4987', 1], ['4635', 2], ['4142', 2], ['4527', 3], ['4548', 4]]
# ['4815', 88]
# Processing subfolder: 1852
# []
# Processing subfolder: 1853
# []
# Processing subfolder: 1858
# []
# Processing subfolder: 1859
# [['4391', 95], ['4872', 3], ['4627', 1], ['4803', 1]]
# ['4391', 95]
# Processing subfolder: 1867
# []
# Processing subfolder: 187
# []
# Processing subfolder: 1872
# []
# Processing subfolder: 1876
# []
# Processing subfolder: 1877
# []
# Processing subfolder: 1878
# [['4845', 15], ['4628', 5], ['4974', 1]]
# ['4845', 15]
# Processing subfolder: 1879
# []
# Processing subfolder: 1881
# [['4533', 1], ['4391', 76], ['4357', 2], ['4581', 1], ['4608', 20]]
# ['4391', 76]
# Processing subfolder: 1882
# []
# Processing subfolder: 1883
# []
# Processing subfolder: 1884
# []
# Processing subfolder: 1885
# []
# Processing subfolder: 1886
# []
# Processing subfolder: 1888
# []
# Processing subfolder: 1889
# [['4975', 59], ['4872', 40], ['4974', 1]]
# ['4975', 59]
# Processing subfolder: 189
# [['4987', 39], ['4815', 16], ['4142', 2], ['4748', 34], ['4382', 5], ['4635', 2], ['4391', 1], ['4783', 1]]
# ['4987', 39]
# Processing subfolder: 1894
# [['4826', 12], ['4816', 43], ['4975', 1], ['4974', 2], ['4533', 1]]
# ['4816', 43]
# Processing subfolder: 1895
# []
# Processing subfolder: 1898
# []
# Processing subfolder: 1899
# []
# Processing subfolder: 190
# [['4635', 80], ['4815', 15], ['4987', 5]]
# ['4635', 80]
# Processing subfolder: 1900
# []
# Processing subfolder: 1902
# [['4999', 1], ['4382', 1], ['4564', 2], ['4311', 96]]
# ['4311', 96]
# Processing subfolder: 1903
# []
# Processing subfolder: 1904
# [['4533', 1], ['4142', 1], ['1374', 97], ['4554', 1]]
# ['1374', 97]
# Processing subfolder: 1906
# []
# Processing subfolder: 1907
# []
# Processing subfolder: 1908
# []
# Processing subfolder: 1911
# [['4533', 1], ['4142', 2], ['4391', 3], ['4993', 18], ['4382', 2], ['4867', 1], ['4783', 1], ['4350', 1], ['4311', 2], ['4416', 1]]
# ['4993', 18]
# Processing subfolder: 1912
# []
# Processing subfolder: 1913
# [['4635', 5], ['4748', 3], ['4142', 1], ['4999', 7], ['4525', 4], ['4628', 2], ['4815', 7], ['4382', 3], ['4307', 1]]
# ['4999', 7]
# Processing subfolder: 1914
# []
# Processing subfolder: 1915
# []
# Processing subfolder: 1916
# []
# Processing subfolder: 1917
# []
# Processing subfolder: 1918
# []
# Processing subfolder: 1919
# []
# Processing subfolder: 1920
# []
# Processing subfolder: 1921
# [['4533', 4], ['4815', 83], ['4635', 1], ['4382', 11], ['4783', 1]]
# ['4815', 83]
# Processing subfolder: 1922
# []
# Processing subfolder: 1923
# []
# Processing subfolder: 1925
# []
# Processing subfolder: 1930
# [['4533', 6], ['4104', 12], ['4391', 3], ['4581', 6], ['4974', 5], ['4826', 8], ['4357', 1], ['4816', 51], ['4872', 3], ['4628', 4], ['4176', 1]]
# ['4816', 51]
# Processing subfolder: 1932
# [['4391', 87], ['4608', 13]]
# ['4391', 87]
# Processing subfolder: 1933
# []
# Processing subfolder: 1948
# []
# Processing subfolder: 1949
# []
# Processing subfolder: 195
# []
# Processing subfolder: 1950
# []
# Processing subfolder: 1951
# []
# Processing subfolder: 1953
# []
# Processing subfolder: 1954
# [['4381', 8], ['4853', 8], ['4391', 5], ['4979', 8], ['4845', 1], ['4856', 1]]
# ['4381', 8]
# Processing subfolder: 1955
# []
# Processing subfolder: 1956
# []
# Processing subfolder: 1958
# [['4853', 14], ['4391', 7], ['4979', 4], ['4856', 3], ['4381', 3]]
# ['4853', 14]
# Processing subfolder: 1959
# []
# Processing subfolder: 196
# [['4748', 39], ['4987', 26], ['4815', 9], ['4382', 19], ['4142', 1], ['4311', 1], ['4635', 1], ['4783', 4]]
# ['4748', 39]
# Processing subfolder: 1960
# [['4381', 31], ['4853', 5], ['4979', 4], ['4391', 8], ['4856', 3], ['4367', 1]]
# ['4381', 31]
# Processing subfolder: 1961
# []
# Processing subfolder: 1962
# []
# Processing subfolder: 1963
# []
# Processing subfolder: 1964
# [['4979', 1], ['4391', 4], ['4853', 5], ['4381', 11], ['4856', 2]]
# ['4381', 11]
# Processing subfolder: 1965
# [['4628', 1], ['4979', 3], ['4853', 12], ['4381', 21], ['4993', 1], ['4391', 8], ['4856', 3], ['4845', 1]]
# ['4381', 21]
# Processing subfolder: 1966
# []
# Processing subfolder: 1967
# []
# Processing subfolder: 1968
# [['4381', 48], ['4853', 4], ['4391', 13], ['4856', 7], ['4979', 1]]
# ['4381', 48]
# Processing subfolder: 1969
# [['4581', 7], ['4628', 14], ['4853', 4], ['4532', 2], ['4654', 1]]
# ['4628', 14]
# Processing subfolder: 197
# [['4987', 8], ['4142', 88], ['4815', 3], ['4598', 1]]
# ['4142', 88]
# Processing subfolder: 1970
# [['4853', 4], ['4979', 2], ['4391', 3], ['4381', 29], ['4161', 1], ['4856', 1]]
# ['4381', 29]
# Processing subfolder: 1971
# []
# Processing subfolder: 1972
# []
# Processing subfolder: 1973
# []
# Processing subfolder: 202
# []
# Processing subfolder: 203
# []
# Processing subfolder: 205
# []
# Processing subfolder: 207
# [['4987', 7], ['4382', 56], ['4815', 5], ['4748', 27], ['4142', 4], ['4391', 1]]
# ['4382', 56]
# Processing subfolder: 208
# [['4533', 26]]
# ['4533', 26]
# Processing subfolder: 209
# [['4635', 2], ['4628', 3], ['4783', 75], ['4627', 1], ['4391', 2], ['4307', 2], ['4142', 3], ['4161', 1], ['4367', 11]]
# ['4783', 75]
# Processing subfolder: 210
# []
# Processing subfolder: 211
# [['4987', 96], ['4142', 2], ['4598', 1], ['4815', 1]]
# ['4987', 96]
# Processing subfolder: 212
# []
# Processing subfolder: 215
# []
# Processing subfolder: 216
# []
# Processing subfolder: 217
# [['4816', 1], ['4142', 12], ['4104', 3], ['4974', 2], ['4598', 1], ['4815', 1]]
# ['4142', 12]
# Processing subfolder: 218
# []
# Processing subfolder: 219
# []
# Processing subfolder: 22
# [['4815', 5], ['4816', 2], ['4142', 8], ['4999', 2], ['4527', 1], ['4548', 82]]
# ['4548', 82]
# Processing subfolder: 220
# [['4142', 17], ['4987', 75], ['4598', 7], ['4581', 1]]
# ['4987', 75]
# Processing subfolder: 223
# [['4872', 27], ['4104', 16], ['4420', 1], ['4533', 13], ['4974', 3], ['4391', 1], ['4776', 1], ['4357', 12], ['4815', 1]]
# ['4872', 27]
# Processing subfolder: 225
# []
# Processing subfolder: 226
# []
# Processing subfolder: 227
# []
# Processing subfolder: 229
# [['4142', 16], ['4987', 73], ['4815', 3]]
# ['4987', 73]
# Processing subfolder: 23
# []
# Processing subfolder: 230
# []
# Processing subfolder: 231
# []
# Processing subfolder: 236
# []
# Processing subfolder: 239
# [['4628', 99], ['4104', 1]]
# ['4628', 99]
# Processing subfolder: 24
# [['4381', 78], ['4161', 5], ['4532', 8], ['4627', 2], ['4548', 1], ['4999', 2], ['4628', 1], ['4357', 1], ['4974', 1], ['4533', 1]]
# ['4381', 78]
# Processing subfolder: 243
# []
# Processing subfolder: 244
# [['4999', 9], ['4773', 6], ['4627', 2], ['4532', 6]]
# ['4999', 9]
# Processing subfolder: 249
# [['4987', 19], ['4974', 2], ['4142', 2], ['4815', 2]]
# ['4987', 19]
# Processing subfolder: 250
# []
# Processing subfolder: 251
# [['4987', 21], ['4815', 5], ['4391', 1], ['4142', 2]]
# ['4987', 21]
# Processing subfolder: 253
# []
# Processing subfolder: 254
# [['4987', 77], ['4142', 20], ['4815', 2], ['4974', 1]]
# ['4987', 77]
# Processing subfolder: 259
# [['4142', 12], ['4987', 70], ['4815', 17], ['4104', 1]]
# ['4987', 70]
# Processing subfolder: 26
# []
# Processing subfolder: 260
# [['4872', 1], ['4815', 6], ['4420', 29], ['4816', 18], ['4361', 1], ['4534', 8], ['4974', 2], ['4975', 3], ['4104', 3], ['4391', 1], ['4987', 2], ['4564', 2], ['4533', 14], ['4842', 1], ['4628', 1], ['4382', 3], ['4826', 1]]
# ['4420', 29]
# Processing subfolder: 262
# [['4974', 1], ['4527', 5], ['4142', 6], ['4548', 14], ['4635', 1]]
# ['4548', 14]
# Processing subfolder: 264
# []
# Processing subfolder: 265
# []
# Processing subfolder: 266
# []
# Processing subfolder: 267
# []
# Processing subfolder: 269
# [['4161', 58], ['4564', 1], ['4815', 2], ['4142', 4]]
# ['4161', 58]
# Processing subfolder: 27
# [['4975', 12], ['4872', 2], ['4422', 7], ['4420', 9], ['4104', 1], ['4533', 1], ['4176', 1]]
# ['4975', 12]
# Processing subfolder: 272
# []
# Processing subfolder: 273
# [['4161', 90], ['4142', 6], ['4564', 1], ['4853', 1], ['4867', 1], ['4367', 1]]
# ['4161', 90]
# Processing subfolder: 275
# []
# Processing subfolder: 277
# []
# Processing subfolder: 279
# []
# Processing subfolder: 28
# [['4999', 2], ['4548', 21], ['4553', 2], ['4142', 2], ['4815', 1]]
# ['4548', 21]
# Processing subfolder: 280
# []
# Processing subfolder: 281
# []
# Processing subfolder: 282
# [['4987', 27], ['4815', 4], ['4391', 2], ['4142', 11]]
# ['4987', 27]
# Processing subfolder: 283
# []
# Processing subfolder: 284
# [['4979', 37], ['4816', 2], ['4548', 2], ['4635', 4], ['4845', 1], ['4161', 3], ['4974', 1], ['4142', 42], ['4533', 3], ['4628', 2], ['4815', 2], ['4987', 1]]
# ['4142', 42]
# Processing subfolder: 285
# [['4548', 18], ['4142', 4], ['4815', 3], ['4553', 1], ['4527', 15], ['4538', 1], ['4635', 1]]
# ['4548', 18]
# Processing subfolder: 286
# []
# Processing subfolder: 287
# [['4533', 3], ['4311', 1], ['4420', 17], ['4104', 23], ['4391', 2], ['4974', 1], ['4975', 4], ['4551', 4]]
# ['4104', 23]
# Processing subfolder: 288
# []
# Processing subfolder: 29
# []
# Processing subfolder: 290
# [['4142', 52], ['4815', 13], ['4974', 19], ['4628', 1], ['4987', 5], ['4391', 1], ['4104', 2], ['4311', 6], ['4792', 1]]
# ['4142', 52]
# Processing subfolder: 291
# [['4975', 7], ['4104', 29], ['4420', 45], ['4628', 2], ['4974', 2], ['4551', 1], ['4357', 1], ['4311', 2]]
# ['4420', 45]
# Processing subfolder: 292
# []
# Processing subfolder: 293
# []
# Processing subfolder: 295
# [['4974', 5], ['4987', 2], ['4142', 12], ['4815', 7], ['4391', 2], ['4311', 1]]
# ['4142', 12]
# Processing subfolder: 296
# [['4104', 28], ['4533', 21], ['4420', 25], ['4975', 3], ['4856', 1], ['4391', 3], ['4872', 14], ['4974', 3], ['4628', 2]]
# ['4104', 28]
# Processing subfolder: 297
# []
# Processing subfolder: 3
# [['4816', 87], ['4599', 12], ['4826', 1]]
# ['4816', 87]
# Processing subfolder: 30
# []
# Processing subfolder: 300
# [['4142', 88], ['4838', 7], ['4781', 5]]
# ['4142', 88]
# Processing subfolder: 301
# [['4161', 100]]
# ['4161', 100]
# Processing subfolder: 303
# []
# Processing subfolder: 304
# [['4974', 19], ['4420', 11], ['4856', 1], ['4357', 1], ['4104', 1]]
# ['4974', 19]
# Processing subfolder: 305
# [['4357', 5], ['4826', 4], ['4533', 6], ['4856', 1], ['4974', 20], ['4608', 1], ['4599', 1], ['4993', 1], ['3875', 2], ['4420', 6], ['4104', 3], ['4635', 1], ['4422', 2]]
# ['4974', 20]
# Processing subfolder: 307
# []
# Processing subfolder: 308
# [['4635', 1], ['4554', 4], ['4815', 21], ['4548', 68], ['4527', 3], ['4142', 2], ['4553', 1]]
# ['4548', 68]
# Processing subfolder: 309
# []
# Processing subfolder: 31
# []
# Processing subfolder: 311
# [['4422', 36], ['4974', 24], ['4533', 24], ['4420', 5], ['4872', 1], ['4975', 3], ['4776', 2], ['4104', 3], ['4816', 1], ['4391', 1]]
# ['4422', 36]
# Processing subfolder: 312
# [['4532', 24], ['4627', 54], ['9697', 10], ['4350', 4], ['4525', 2], ['4999', 5], ['4581', 1]]
# ['4627', 54]
# Processing subfolder: 316
# ...
# Processing subfolder: 478
# [['4527', 10], ['4548', 89], ['4553', 1]]
# ['4548', 89]
# Processing subfolder: 480
# []
# Processing subfolder: 481
# []
# Processing subfolder: 482
# []
# Processing subfolder: 483
# []
# Processing subfolder: 484
# []
# Processing subfolder: 485
# []
# Processing subfolder: 486
# []
# Processing subfolder: 487
# [['4987', 30], ['4635', 14], ['4815', 1], ['4307', 1], ['1374', 1], ['4748', 1]]
# ['4987', 30]
# Processing subfolder: 489
# []
# Processing subfolder: 490
# []
# Processing subfolder: 493
# [['4381', 2], ['4161', 55], ['4367', 31], ['4853', 3], ['4773', 3], ['4783', 6]]
# ['4161', 55]
# Processing subfolder: 494
# []
# Processing subfolder: 497
# []
# Processing subfolder: 498
# []
# Processing subfolder: 5
# [['4987', 5], ['4554', 88], ['4635', 5], ['4831', 2]]
# ['4554', 88]
# Processing subfolder: 500
# [['4311', 2], ['4420', 1], ['4142', 32], ['4627', 1], ['4635', 2], ['4816', 1], ['4527', 56], ['4391', 2], ['4525', 1], ['4161', 2]]
# ['4527', 56]
# Processing subfolder: 503
# [['4142', 93], ['4748', 2], ['4381', 1], ['4391', 1], ['4627', 2], ['4567', 1]]
# ['4142', 93]
# Processing subfolder: 504
# []
# Processing subfolder: 506
# [['4783', 9], ['4311', 12], ['4391', 4], ['4161', 3], ['4599', 2], ['4816', 16], ['4856', 7], ['4979', 24], ['4628', 4], ['4548', 1]]
# ['4979', 24]
# Processing subfolder: 508
# []
# Processing subfolder: 509
# []
# Processing subfolder: 511
# []
# Processing subfolder: 512
# []
# Processing subfolder: 513
# [['1374', 100]]
# ['1374', 100]
# Processing subfolder: 515
# []
# Processing subfolder: 516
# [['4999', 13], ['4627', 76], ['4974', 1], ['4553', 3], ['4532', 6], ['4551', 1]]
# ['4627', 76]
# Processing subfolder: 518
# [['4635', 23], ['4815', 50], ['4987', 15], ['4533', 1], ['4627', 4], ['4990', 2], ['4142', 3], ['4311', 2]]
# ['4815', 50]
# Processing subfolder: 521
# []
# Processing subfolder: 522
# [['4635', 68], ['4871', 1], ['4987', 25], ['4391', 3], ['4533', 3]]
# ['4635', 68]
# Processing subfolder: 523
# []
# Processing subfolder: 524
# []
# Processing subfolder: 525
# [['4635', 20], ['4815', 7], ['4391', 1]]
# ['4635', 20]
# Processing subfolder: 526
# []
# Processing subfolder: 527
# []
# Processing subfolder: 528
# []
# Processing subfolder: 529
# [['4987', 16], ['4635', 14]]
# ['4987', 16]
# Processing subfolder: 53
# [['4999', 1], ['4311', 5], ['4554', 1], ['4532', 1], ['4161', 42], ['4635', 1], ['4815', 1]]
# ['4161', 42]
# Processing subfolder: 530
# []
# Processing subfolder: 531
# [['4635', 28], ['4815', 7], ['4748', 1], ['4987', 2], ['4391', 1], ['4142', 1]]
# ['4635', 28]
# Processing subfolder: 532
# [['4815', 24], ['4635', 63], ['4748', 5], ['4533', 5], ['4987', 2], ['4391', 1]]
# ['4635', 63]
# Processing subfolder: 533
# []
# Processing subfolder: 534
# [['1374', 23], ['4635', 2]]
# ['1374', 23]
# Processing subfolder: 536
# []
# Processing subfolder: 540
# []
# Processing subfolder: 542
# []
# Processing subfolder: 544
# []
# Processing subfolder: 545
# []
# Processing subfolder: 546
# [['4533', 2], ['4391', 12], ['4815', 6], ['4987', 29], ['4635', 4], ['4816', 1]]
# ['4987', 29]
# Processing subfolder: 547
# []
# Processing subfolder: 548
# []
# Processing subfolder: 549
# []
# Processing subfolder: 550
# []
# Processing subfolder: 551
# []
# Processing subfolder: 552
# []
# Processing subfolder: 555
# []
# Processing subfolder: 557
# [['4533', 1], ['4628', 1], ['4783', 1], ['4142', 1], ['4564', 2], ['4598', 2], ['4803', 1], ['4381', 6], ['4826', 9], ['4523', 1]]
# ['4826', 9]
# Processing subfolder: 558
# []
# Processing subfolder: 560
# [['4815', 21], ['4391', 1], ['4987', 1], ['4635', 1], ['4533', 2]]
# ['4815', 21]
# Processing subfolder: 561
# [['1374', 92], ['4635', 8]]
# ['1374', 92]
# Processing subfolder: 562
# []
# Processing subfolder: 563
# []
# Processing subfolder: 564
# []
# Processing subfolder: 565
# [['4564', 2], ['4161', 37], ['4367', 1], ['4853', 2], ['4783', 36], ['4867', 3], ['4773', 1], ['4391', 1], ['4628', 1], ['4532', 4], ['4598', 5], ['4381', 7]]
# ['4161', 37]
# Processing subfolder: 566
# [['4311', 1], ['4815', 87], ['4987', 3], ['4635', 2], ['4842', 3], ['4382', 1], ['4533', 1], ['4391', 1], ['4142', 1]]
# ['4815', 87]
# Processing subfolder: 567
# []
# Processing subfolder: 576
# []
# Processing subfolder: 578
# []
# Processing subfolder: 580
# []
# Processing subfolder: 582
# []
# Processing subfolder: 583
# []
# Processing subfolder: 584
# []
# Processing subfolder: 585
# []
# Processing subfolder: 590
# []
# Processing subfolder: 594
# []
# Processing subfolder: 596
# []
# Processing subfolder: 597
# []
# Processing subfolder: 598
# []
# Processing subfolder: 6
# [['4391', 2], ['4381', 95], ['4564', 2], ['4581', 1]]
# ['4381', 95]
# Processing subfolder: 60
# []
# Processing subfolder: 600
# []
# Processing subfolder: 601
# [['1374', 100]]
# ['1374', 100]
# Processing subfolder: 602
# []
# Processing subfolder: 603
# [['4548', 20], ['4538', 1], ['4527', 1], ['4815', 2]]
# ['4548', 20]
# Processing subfolder: 604
# []
# Processing subfolder: 605
# []
# Processing subfolder: 606
# []
# Processing subfolder: 607
# []
# Processing subfolder: 609
# []
# Processing subfolder: 614
# [['4628', 2], ['4826', 21], ['4598', 17], ['4564', 1], ['4853', 15], ['4867', 6], ['4816', 20], ['4635', 5], ['4391', 9], ['4142', 1], ['4803', 1], ['4381', 1], ['4161', 1]]
# ['4826', 21]
# Processing subfolder: 621
# [['4987', 11], ['4635', 5], ['4533', 7]]
# ['4987', 11]
# Processing subfolder: 623
# []
# Processing subfolder: 624
# [['4142', 86], ['4635', 1], ['1374', 1], ['4815', 10]]
# ['4142', 86]
# Processing subfolder: 627
# []
# Processing subfolder: 629
# [['4815', 2], ['1374', 98]]
# ['1374', 98]
# Processing subfolder: 633
# [['4791', 4], ['1374', 1], ['4554', 34], ['4142', 1], ['4815', 3], ['4382', 1], ['4564', 4], ['4307', 38], ['4548', 14]]
# ['4307', 38]
# Processing subfolder: 634
# []
# Processing subfolder: 637
# []
# Processing subfolder: 638
# [['4635', 13], ['4551', 1], ['4533', 2], ['4987', 6], ['4554', 1]]
# ['4635', 13]
# Processing subfolder: 639
# [['4803', 3], ['4979', 93], ['9697', 1]]
# ['4979', 93]
# Processing subfolder: 640
# [['4987', 1], ['4781', 9], ['4627', 31], ['4311', 4], ['4628', 21], ['4815', 26], ['4161', 8]]
# ['4627', 31]
# Processing subfolder: 641
# [['4979', 17], ['4628', 1], ['4816', 1], ['4791', 1], ['4142', 3], ['4635', 1], ['4815', 2]]
# ['4979', 17]
# Processing subfolder: 642
# []
# Processing subfolder: 643
# []
# Processing subfolder: 654
# []
# Processing subfolder: 655
# []
# Processing subfolder: 656
# []
# Processing subfolder: 658
# []
# Processing subfolder: 668
# []
# Processing subfolder: 674
# [['4842', 1], ['4564', 1], ['4815', 22], ['4999', 6], ['4142', 25], ['4635', 5], ['4781', 1], ['4382', 1], ['4974', 1], ['4628', 4], ['4987', 6], ['4161', 18], ['4581', 6], ['4307', 2], ['1374', 1]]
# ['4142', 25]
# Processing subfolder: 676
# [['1374', 21], ['4635', 1], ['4554', 1]]
# ['1374', 21]
# Processing subfolder: 677
# []
# Processing subfolder: 678
# []
# Processing subfolder: 679
# [['4142', 53], ['4548', 13], ['4781', 18], ['4161', 13], ['4815', 1], ['4627', 2]]
# ['4142', 53]
# Processing subfolder: 680
# []
# Processing subfolder: 681
# []
# Processing subfolder: 682
# []
# Processing subfolder: 683
# [['4142', 42], ['4815', 9], ['1374', 3]]
# ['4142', 42]
# Processing subfolder: 684
# []
# Processing subfolder: 7
# [['4815', 100]]
# ['4815', 100]
# Processing subfolder: 702
# []
# Processing subfolder: 706
# []
# Processing subfolder: 708
# []
# Processing subfolder: 711
# [['4853', 15], ['4867', 2], ['4161', 10], ['4598', 61], ['4826', 3], ['4816', 2], ['4564', 5], ['4783', 2]]
# ['4598', 61]
# Processing subfolder: 712
# []
# Processing subfolder: 717
# [['4382', 4], ['4872', 2], ['4161', 5], ['4416', 3], ['4311', 1], ['9697', 2], ['4525', 3], ['4627', 3], ['4391', 1], ['4815', 3], ['4635', 2]]
# ['4161', 5]
# Processing subfolder: 718
# []
# Processing subfolder: 719
# []
# Processing subfolder: 721
# []
# Processing subfolder: 726
# [['4872', 13], ['4533', 5], ['4357', 1], ['4420', 2], ['4382', 2], ['4104', 1], ['4974', 2], ['4581', 1]]
# ['4872', 13]
# Processing subfolder: 727
# []
# Processing subfolder: 736
# []
# Processing subfolder: 737
# [['4815', 2], ['4635', 1], ['4161', 5], ['4391', 1], ['4803', 84], ['4783', 2], ['4350', 1], ['4598', 1], ['4993', 2], ['9697', 1]]
# ['4803', 84]
# Processing subfolder: 741
# []
# Processing subfolder: 742
# []
# Processing subfolder: 743
# []
# Processing subfolder: 744
# []
# Processing subfolder: 745
# []
# Processing subfolder: 746
# []
# Processing subfolder: 747
# []
# Processing subfolder: 748
# []
# Processing subfolder: 749
# []
# Processing subfolder: 75
# []
# Processing subfolder: 750
# [['4548', 55], ['4142', 9], ['4527', 10], ['4554', 19], ['4791', 1], ['4815', 6]]
# ['4548', 55]
# Processing subfolder: 751
# [['4872', 2], ['4391', 20], ['4104', 2], ['4382', 8]]
# ['4391', 20]
# Processing subfolder: 755
# []
# Processing subfolder: 758
# [['4974', 14], ['4420', 7], ['4628', 1], ['4533', 1]]
# ['4974', 14]
# Processing subfolder: 76
# [['4104', 12], ['4420', 11], ['4975', 1], ['4422', 5], ['4533', 1]]
# ['4104', 12]
# Processing subfolder: 760
# []
# Processing subfolder: 761
# []
# Processing subfolder: 774
# []
# Processing subfolder: 775
# []
# Processing subfolder: 776
# []
# Processing subfolder: 777
# []
# Processing subfolder: 778
# []
# Processing subfolder: 779
# []
# Processing subfolder: 787
# [['1374', 22]]
# ['1374', 22]
# Processing subfolder: 788
# []
# Processing subfolder: 789
# []
# Processing subfolder: 79
# [['4581', 1], ['4350', 1], ['4104', 1], ['4838', 1], ['4420', 2], ['4142', 1], ['4975', 1], ['4382', 1], ['4872', 9], ['4533', 14], ['4422', 65], ['4974', 2], ['4391', 1]]
# ['4422', 65]
# Processing subfolder: 790
# []
# Processing subfolder: 791
# []
# Processing subfolder: 793
# [['1374', 100]]
# ['1374', 100]
# Processing subfolder: 80
# [['4987', 2], ['4815', 11], ['4527', 1], ['4974', 1], ['4142', 3], ['4538', 1], ['4548', 80], ['4999', 1]]
# ['4548', 80]
# Processing subfolder: 808
# [['4974', 1], ['4999', 22], ['4551', 4], ['4142', 3], ['4627', 68], ['4553', 2]]
# ['4627', 68]
# Processing subfolder: 809
# []
# Processing subfolder: 811
# []
# Processing subfolder: 812
# []
# Processing subfolder: 816
# []
# Processing subfolder: 817
# [['4142', 4], ['4826', 51], ['4599', 1], ['4391', 5], ['4803', 1], ['4816', 32], ['4311', 3], ['4381', 2], ['4525', 1]]
# ['4826', 51]
# Processing subfolder: 818
# []
# Processing subfolder: 819
# []
# Processing subfolder: 82
# [['4142', 16], ['4838', 84]]
# ['4838', 84]
# Processing subfolder: 821
# []
# Processing subfolder: 825
# []
# Processing subfolder: 828
# [['4635', 8], ['1374', 51]]
# ['1374', 51]
# Processing subfolder: 83
# []
# Processing subfolder: 831
# []
# Processing subfolder: 832
# []
# Processing subfolder: 833
# []
# Processing subfolder: 834
# []
# Processing subfolder: 835
# []
# Processing subfolder: 836
# []
# Processing subfolder: 837
# []
# Processing subfolder: 842
# []
# Processing subfolder: 844
# []
# Processing subfolder: 848
# [['4161', 51], ['4391', 21], ['4104', 6], ['4816', 8], ['4826', 3], ['4382', 11]]
# ['4161', 51]
# Processing subfolder: 849
# []
# Processing subfolder: 85
# []
# Processing subfolder: 850
# [['4635', 18], ['1374', 14]]
# ['4635', 18]
# Processing subfolder: 851
# []
# Processing subfolder: 852
# []
# Processing subfolder: 853
# []
# Processing subfolder: 854
# []
# Processing subfolder: 855
# []
# Processing subfolder: 856
# []
# Processing subfolder: 857
# [['4815', 10], ['4635', 1], ['4527', 1], ['4142', 2], ['4548', 11], ['4553', 2]]
# ['4548', 11]
# Processing subfolder: 858
# []
# Processing subfolder: 859
# []
# Processing subfolder: 860
# []
# Processing subfolder: 861
# []
# Processing subfolder: 862
# []
# Processing subfolder: 863
# []
# Processing subfolder: 864
# []
# Processing subfolder: 865
# []
# Processing subfolder: 866
# []
# Processing subfolder: 868
# [['4803', 96], ['4993', 4]]
# ['4803', 96]
# Processing subfolder: 874
# [['4554', 2], ['4628', 2], ['4816', 1], ['4783', 88], ['4142', 4], ['4311', 1], ['4815', 1], ['4974', 1]]
# ['4783', 88]
# Processing subfolder: 875
# []
# Processing subfolder: 876
# [['4367', 20], ['4628', 1]]
# ['4367', 20]
# Processing subfolder: 877
# [['4367', 93], ['4624', 2], ['4974', 3], ['4567', 1], ['4853', 1]]
# ['4367', 93]
# Processing subfolder: 879
# [['4367', 72], ['4627', 2], ['4974', 8], ['4567', 8], ['4783', 1]]
# ['4367', 72]
# Processing subfolder: 882
# [['4783', 5], ['4367', 17], ['4974', 12], ['4853', 6], ['4993', 1], ['4627', 19]]
# ['4627', 19]
# Processing subfolder: 883
# [['4783', 100]]
# ['4783', 100]
# Processing subfolder: 885
# []
# Processing subfolder: 89
# []
# Processing subfolder: 890
# []
# Processing subfolder: 891
# []
# Processing subfolder: 895
# []
# Processing subfolder: 896
# []
# Processing subfolder: 9
# [['4815', 1], ['4142', 5], ['4791', 1], ['4538', 93]]
# ['4538', 93]
# Processing subfolder: 902
# []
# Processing subfolder: 905
# [['4413', 41], ['4161', 30], ['4853', 1], ['4773', 1]]
# ['4413', 41]
# Processing subfolder: 906
# [['4357', 3], ['4420', 56], ['4104', 4], ['4816', 2], ['4974', 10], ['4815', 2], ['4422', 2], ['4311', 2], ['4872', 4], ['4533', 15]]
# ['4420', 56]
# Processing subfolder: 908
# []
# Processing subfolder: 910
# [['4142', 5], ['4548', 88], ['4553', 7]]
# ['4548', 88]
# Processing subfolder: 912
# []
# Processing subfolder: 919
# []
# Processing subfolder: 920
# [['4974', 16], ['4367', 3], ['4783', 1]]
# ['4974', 16]
# Processing subfolder: 921
# [['4142', 1], ['4553', 6], ['4548', 89], ['4527', 4]]
# ['4548', 89]
# Processing subfolder: 922
# []
# Processing subfolder: 925
# [['4815', 1], ['4635', 12], ['4987', 35], ['4548', 41], ['4382', 6], ['4532', 1], ['4142', 1], ['4533', 1], ['1374', 2]]
# ['4548', 41]
# Processing subfolder: 926
# []
# Processing subfolder: 927
# []
# Processing subfolder: 928
# [['4815', 3], ['4142', 3], ['4538', 2], ['4548', 92]]
# ['4548', 92]
# Processing subfolder: 929
# []
# Processing subfolder: 930
# []
# Processing subfolder: 931
# []
# Processing subfolder: 932
# []
# Processing subfolder: 933
# [['4367', 17], ['4783', 1], ['4974', 6]]
# ['4367', 17]
# Processing subfolder: 934
# [['4627', 78], ['4999', 16], ['4553', 6]]
# ['4627', 78]
# Processing subfolder: 935
# [['4104', 2], ['4422', 69], ['4420', 8], ['4975', 8], ['4872', 5], ['4599', 2], ['4628', 3], ['4538', 1], ['4816', 1], ['4391', 1]]
# ['4422', 69]
# Processing subfolder: 940
# []
# Processing subfolder: 941
# [['4527', 10], ['4548', 42], ['4815', 1]]
# ['4548', 42]
# Processing subfolder: 946
# []
# Processing subfolder: 951
# [['4422', 53], ['4420', 35], ['4104', 4], ['4382', 1], ['4176', 1], ['4872', 4], ['4975', 2]]
# ['4422', 53]
# Processing subfolder: 958
# [['4367', 20], ['4627', 3], ['4974', 11], ['4783', 66]]
# ['4783', 66]
# Processing subfolder: 961
# []
# Processing subfolder: 962
# [['4628', 7], ['4872', 1], ['4382', 9], ['4776', 3], ['4104', 4], ['4357', 1], ['4142', 2], ['4608', 1], ['4773', 18], ['4748', 31], ['4311', 22], ['4416', 1]]
# ['4748', 31]
# Processing subfolder: 964
# []
# Processing subfolder: 965
# [['4773', 1], ['4628', 9], ['4382', 7], ['4783', 4], ['4816', 2], ['4357', 1], ['4104', 1], ['4142', 2], ['4564', 1], ['4872', 3]]
# ['4628', 9]
# Processing subfolder: 968
# []
# Processing subfolder: 969
# [['1374', 98], ['4635', 1], ['4554', 1]]
# ['1374', 98]
# Processing subfolder: 970
# [['4142', 2], ['4815', 9], ['4554', 3], ['4999', 1], ['4548', 65]]
# ['4548', 65]
# Processing subfolder: 971
# [['4548', 64], ['4581', 1], ['4815', 12], ['3875', 2], ['4538', 3], ['4999', 10], ['4554', 3], ['L9', 1], ['4142', 4]]
# ['4548', 64]
# Processing subfolder: 975
# []
# Processing subfolder: 976
# []
# Processing subfolder: 98
# []
# Processing subfolder: 984
# []
# Processing subfolder: 985
# [['4548', 21]]
# ['4548', 21]
# Processing subfolder: 986
# [['4142', 3], ['4781', 94], ['4999', 1], ['4538', 1], ['4567', 1]]
# ['4781', 94]
# Processing subfolder: 987
# []
# Processing subfolder: 988
# []
# Processing subfolder: 989
# [['4548', 49], ['4142', 20], ['4554', 1], ['4815', 27], ['4791', 1], ['4999', 2]]
# ['4548', 49]
# Processing subfolder: 99
# []
# Processing subfolder: 991
# [['4104', 9], ['4872', 30], ['4599', 1], ['4391', 14], ['4975', 8], ['4382', 4], ['4773', 12], ['4581', 6], ['4357', 2], ['4533', 14]]
# ['4872', 30]
# Processing subfolder: 993
# [['4815', 3], ['1374', 78], ['4527', 1], ['4831', 2], ['4635', 16]]
# ['1374', 78]
# Processing subfolder: 994
# [['4627', 24], ['4142', 1]]
# ['4627', 24]
# Processing subfolder: 996
# []
# Processing subfolder: 997
# [['4838', 4], ['4783', 91], ['4367', 3], ['4974', 2]]
# ['4783', 91]
# Processing subfolder: 999
# []
# finalized_pdf.csv is not a directory.
# missed_count.csv is not a directory.
# program_accuracy.csv is not a directory.
# Results saved to G:\Output\runs\KUNNEPPU_identification\KNP_Merge_and_Batch_identification\IR collect Oct Report 2025\reuse tetris_Sumiyoshi-44\Base_rtx8000_10_August_2025_20000_v1\testris_Ch004_Camera 004_E2\2025-10-14_0023_part 1\manual_result_feature.csv

# %%
import pandas as pd

# %%
resultToCsv(result)
